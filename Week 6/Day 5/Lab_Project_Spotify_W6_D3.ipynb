# %% [markdown]
# # Importing libraries

# %%
import config
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import IFrame
import pprint
import pandas as pd

# %% [markdown]
# ## Searching 1st playlist

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
playlist = sp.user_playlist_tracks("spotify","4Dg0J0ICj9kKTGDyFu0Cv4",market="DE")

# %%
list_of_audio_features=[]
for item in range(0,1000):
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df=pd.DataFrame(list_of_audio_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.566   0.664    -5.303       0.0464      0.634000
# 1           0.768   0.820    -4.630       0.0474      0.179000
# 2           0.558   0.559    -9.222       0.0959      0.371000
# 3           0.679   0.715    -6.383       0.0407      0.075500
# 4           0.778   0.824    -5.892       0.0707      0.284000
# ..            ...     ...       ...          ...           ...
# 995         0.577   0.983    -1.821       0.0712      0.116000
# 996         0.976   0.920    -3.646       0.2260      0.015200
# 997         0.667   0.999    -4.375       0.0828      0.072600
# 998         0.516   0.714    -7.124       0.0379      0.000457
# 999         0.742   0.584    -7.482       0.0484      0.001560
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000     0.116    0.437  128.945  3dYD57lRAUcMHufyqn9GcI
# 1            0.000000     0.689    0.625  129.965  2V4bv1fNWfTcyRJKmej6Sj
# 2            0.000007     0.109    0.620   78.558  7KA4W4McWYRpgf0fWsJZWB
# 3            0.000000     0.271    0.571  127.435  4Ub8UsjWuewQrPhuepfVpd
# 4            0.000000     0.405    0.758  100.024  3ZFTkvIE7kyPt6Nu3PEa7V
# ..                ...       ...      ...      ...                     ...
# 995          0.000316     0.149    0.216  128.011  3VPNH1HKLVFFJe7KxiG07e
# 996          0.000000     0.331    0.913  128.037  2IOvpCME5BWATj3KT1WPSD
# 997          0.000041     0.238    0.566  149.875  09uma8kvpf699ailOSlzds
# 998          0.022600     0.397    0.719  156.041  2N2vT7prULYdnOeqA0XBDy
# 999          0.000067     0.584    0.364  129.989  6nw6HDH049R7j7JArouHn3
#
#      duration_ms
# 0         241688
# 1         213293
# 2         180387
# 3         214148
# 4         218093
# ..           ...
# 995       179000
# 996       184875
# 997       248533
# 998       255693
# 999       248627
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## Next Playlist (2)

# %%
def get_playlist_tracks2(username, playlist_id):
    results2 = sp.user_playlist_tracks2(username,playlist_id,market="DE")
    tracks2 = results2['items']
    while results2['next']:
        results2 = sp.next(results2)
        tracks2.extend(results2['items'])
    return tracks2

# %%
tracks2=get_playlist_tracks("spotify", "1rKNs8HKr5NPoy1KUcweFQ")

# %%
playlist2 = sp.user_playlist_tracks("spotify","1rKNs8HKr5NPoy1KUcweFQ",market="DE")

# %%
list_of_audio_features2=[]
for item in range(0,60):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features2.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df2=pd.DataFrame(list_of_audio_features2)    
df2=df2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.481  0.7380    -4.701       0.0295       0.11800
# 1          0.341  0.7680    -7.227       0.0624       0.66900
# 2          0.589  0.3590   -13.181       0.0409       0.83000
# 3          0.247  0.1860   -14.510       0.0315       0.49700
# 4          0.505  0.4910    -9.619       0.0386       0.37900
# 5          0.409  0.0145   -25.122       0.0469       0.88900
# 6          0.483  0.3210   -13.731       0.0390       0.59400
# 7          0.618  0.3900   -11.037       0.0597       0.51500
# 8          0.247  0.2950    -9.313       0.0333       0.74900
# 9          0.435  0.5780   -13.349       0.0511       0.00409
# 10         0.441  0.6370    -8.905       0.0275       0.49800
# 11         0.572  0.3980   -10.751       0.0376       0.84100
# 12         0.562  0.4060    -5.435       0.1030       0.93800
# 13         0.689  0.4680    -8.000       0.0523       0.77900
# 40          0.007620    0.1320   0.4430   91.511  3Vf3ST5bCEAwSCTnJkUBn3
# 41          0.811000    0.0672   0.8690  185.171  7gFHaxNJLo67QCIqpb1RgW
# 42          0.000000    0.0855   0.6980  116.558  45qF2E2smfkrMR47xF5QZy
# 43          0.000063    0.1130   0.9570   94.569  1ugbpaNFVVRVZqmpZw7l8e
# 44          0.059100    0.1040   0.3730   78.850  15MrK18b57Reu75doUBMxb
# 45          0.660000    0.1650   0.5980  153.063  1t824cRJQiE6qMC3Eyn0IG
# 46          0.000007    0.3140   0.6350  160.052  64IyJy8EM0dv5J5XJ6ik0R
# 47          0.000310    0.1120   0.3540  114.926  3rna56hxQIngJsu96aBfx3
# 48          0.000178    0.2300   0.8290  174.988  4BhjIxAGfp0zmp1fawlEFM
# 49          0.000364    0.0492   0.9640   93.058  2naqSVQHgiaoEpxtkVOhmK
# 50          0.000002    0.1000   0.3970   94.832  1PBPOelaauq0px37rzgyWz
# 51          0.087800    0.1100   0.6810  118.747  2V9DHDddDi2Cy3UyWEvY4o
# 52          0.003190    0.0764   0.0908   89.260  23TCWVwQGtClcXh3YPu9TX
# 53          0.000006    0.0811   0.2870   92.963  5yU0R8JLEG2jnhILIsrgxD
# 54          0.000333    0.0827   0.8020  102.652  2koS4fD3kzizdnzWzyrxyT
# 55          0.680000    0.1030   0.6010  168.378  4UFm6Kib5Jxzw9FL0F6x0q
# 56          0.002560    0.0494   0.7620  131.061  1hj6nYHeGclSY0VNTHMi27
# 57          0.000008    0.1030   0.9610  172.516  11rsK9GDZ9UdWsxtDqnMmN
# 58          0.942000    0.1140   0.7500  190.970  5srgpROEtK8KLKQl5FW7Ub
# 59          0.003170    0.1100   0.7110  128.315  6NEDvEbcNyzfm9dRuSv2Xv
#
#     duration_ms
# 0        213193
# 1        171507
# 2        272229
# 3        414840
# 4        127720
# 5        163267
# 6        133067
# 7        174573
# 8        187587
# 9        256173
# 10       200373
# 11       244867
# 12       127501
# 13       177917
# 14       180837
# 15       108960
# 16       165213
# 17       231880
# 18       179626
# 19       201640
# 20       174077
# 21       157710
# 22       253575
# 23       152206
# 24       131297
# 25       187376
# 26       116378
# 27       187211
# 28       181623
# 29       216467
# 30       147632
# 31       111360
# 32       176000
# 33       235533
# 34       100693
# 35       202293
# 36       256000
# 37       240987
# 38       227933
# 39       165240
# 40       181933
# 41       199467
# 42       199333
# 43       156427
# 44       153413
# 45       355640
# 46       121523
# 47       230120
# 48       187467
# 49       228554
# 50       150267
# 51       166573
# 52       293400
# 53       166453
# 54       313493
# 55       222680
# 56       261360
# 57       201160
# 58       216000
# 59       229000

# %% [markdown]
# ## Next Playlist (3)

# %%
#https://open.spotify.com/playlist/7vh1suA9zJijFNLGGu96oc?si=26bbc5f880244a6b
def get_playlist_tracks3(username, playlist_id):
    results3 = sp.user_playlist_tracks3(username,playlist_id,market="DE")
    tracks3 = results3['items']
    while results3['next']:
        results3 = sp.next(results3)
        tracks3.extend(results2['items'])
    return tracks3

# %%
tracks3=get_playlist_tracks("spotify", "7vh1suA9zJijFNLGGu96oc")

# %%
playlist3 = sp.user_playlist_tracks("spotify","7vh1suA9zJijFNLGGu96oc",market="DE")

# %%
list_of_audio_features3=[]
for item in range(0,128):
    list_of_audio_features3.append(sp.audio_features(tracks3[item]["track"]["id"])[0])

# %%
df3=pd.DataFrame(list_of_audio_features3)    
df3=df3[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df3
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.877   0.544   -11.189       0.0699      0.607000
# 1           0.817   0.648    -9.717       0.1580      0.070600
# 2           0.292   0.890   -12.649       0.0621      0.037900
# 3           0.801   0.528   -16.709       0.0602      0.489000
# 4           0.800   0.825   -12.991       0.0485      0.000006
# ..            ...     ...       ...          ...           ...
# 123         0.703   0.566   -10.540       0.7390      0.000070
# 124         0.664   0.925    -9.177       0.0473      0.000066
# 125         0.553   0.791   -10.757       0.1130      0.495000
# 126         0.696   0.594   -11.362       0.0701      0.000138
# 127         0.635   0.752   -13.057       0.0404      0.016200
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0               0.825    0.1730    0.349  130.029  6tSfEoK9R3hJe9MhmS0D6U
# 1               0.825    0.1020    0.378  127.007  3gN9mMN8bbluk7V9g5P0XG
# 2               0.797    0.6030    0.103  170.660  51vItd7ccBecSanoGRGvTc
# 3               0.955    0.1120    0.243  125.007  4FY6wndBNR0kvwwp09UUBu
# 4               0.886    0.0608    0.700  126.011  06xYcZSr9LpDlqL6TsIl1e
# ..                ...       ...      ...      ...                     ...
# 123             0.463    0.3520    0.417  137.961  3B9XvmwuYiiXRVC3cejRmi
# 124             0.920    0.3100    0.033  133.113  5lQilmQMgjAbgZGf5PfX31
# 125             0.812    0.1520    0.210   80.092  0izSidgmpwyPTqlpVZmxIZ
# 126             0.867    0.2630    0.123  112.057  0CJKU3HMTwwocYOVVPiCwz
# 127             0.853    0.1110    0.167  129.278  66IL2y5EmdkRzi81SrtU9H
#
#      duration_ms
# 0         130084
# 1         470764
# 2         335839
# 3         526436
# 4         339133
# ..           ...
# 123       403840
# 124       404600
# 125       130024
# 126       181042
# 127       343280
#
# [128 rows x 11 columns]

# %% [markdown]
# ## Next Playlist (4)

# %%
#https://open.spotify.com/playlist/0KTFRDfUNyE0Q6LHz9JL2O?si=0791bd234792445c
def get_playlist_tracks4(username, playlist_id):
    results4 = sp.user_playlist_tracks4(username,playlist_id,market="DE")
    tracks4 = results4['items']
    while results4['next']:
        results4 = sp.next(results4)
        tracks4.extend(results3['items'])
    return tracks4

# %%
tracks4=get_playlist_tracks("spotify", "0KTFRDfUNyE0Q6LHz9JL2O")

# %%
playlist4 = sp.user_playlist_tracks("spotify","7vh1suA9zJijFNLGGu96oc",market="DE")

# %%
list_of_audio_features4=[]
for item in range(0,65):
    list_of_audio_features4.append(sp.audio_features(tracks4[item]["track"]["id"])[0])

# %%
df4=pd.DataFrame(list_of_audio_features4)    
df4=df4[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df4
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.853   0.494   -10.911        0.201        0.0109
# 1          0.708   0.832    -4.964        0.318        0.0200
# 2          0.782   0.597    -6.399        0.335        0.0568
# 3          0.658   0.936    -5.105        0.300        0.1720
# 4          0.783   0.633    -6.983        0.291        0.0969
# ..           ...     ...       ...          ...           ...
# 60         0.837   0.774    -8.707        0.265        0.0267
# 61         0.577   0.643    -4.707        0.402        0.0836
# 62         0.526   0.893    -6.111        0.418        0.1700
# 63         0.715   0.510    -9.829        0.349        0.6750
# 64         0.903   0.423    -5.829        0.235        0.4340
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000884    0.2050    0.341   95.284  671sDyeE398eD0sdGuVbZU
# 1           0.000003    0.1890    0.618   92.428  4kxAgnWw4GKmqcuUiXn60o
# 2           0.000000    0.5820    0.528   94.631  61VlApj8p2ZaP0WTunTrKT
# 3           0.000000    0.3210    0.711   95.439  3qRPc4QpHGNwKFAzCdqwxA
# 4           0.000994    0.1540    0.913  100.428  6sWZn6kTuTrBkbOEQFoB3a
# ..               ...       ...      ...      ...                     ...
# 60          0.000000    0.3650    0.671   91.174  4TyOdHslAsrWZyXuStT2Ay
# 61          0.000000    0.1240    0.808  163.948  4OQvulvhRQvLM9riefpJMn
# 62          0.000000    0.1860    0.440  174.555  2AeVg9Nf6dAHweYkDowG1J
# 63          0.000000    0.0886    0.552  139.724  102cqOBzuFurH4pucMp7QY
# 64          0.000001    0.0859    0.512   96.612  0GmhAVyyHwaX6jfCbPmaoB
#
#     duration_ms
# 0        191533
# 1        252600
# 2        243133
# 3        203000
# 4        174800
# ..          ...
# 60       293627
# 61       238157
# 62       209093
# 63       154280
# 64       169373
#
# [65 rows x 11 columns]

# %% [markdown]
# ## Next Playlist (5)

# %%
#https://open.spotify.com/playlist/37i9dQZF1DX661EjJOj3Tu?si=a217bedb17e94978
def get_playlist_tracks5(username, playlist_id):
    results5 = sp.user_playlist_tracks5(username,playlist_id,market="DE")
    tracks5 = results5['items']
    while results5['next']:
        results5 = sp.next(results5)
        tracks5.extend(results5['items'])
    return tracks5

# %%
tracks5=get_playlist_tracks("spotify", "37i9dQZF1DX661EjJOj3Tu")

# %%
playlist5 = sp.user_playlist_tracks("spotify","7vh1suA9zJijFNLGGu96oc",market="DE")

# %%
list_of_audio_features5=[]
for item in range(0,100):
    list_of_audio_features5.append(sp.audio_features(tracks5[item]["track"]["id"])[0])

# %%
df5=pd.DataFrame(list_of_audio_features5)    
df5=df5[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df5
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.652   0.377   -14.848       0.1760         0.845
# 1          0.547   0.200   -16.734       0.0392         0.826
# 2          0.793   0.372   -15.491       0.0509         0.687
# 3          0.572   0.152   -15.658       0.0408         0.961
# 4          0.835   0.378   -13.510       0.0392         0.761
# ..           ...     ...       ...          ...           ...
# 95         0.717   0.732    -6.683       0.0486         0.550
# 96         0.748   0.683    -8.834       0.0529         0.138
# 97         0.357   0.257   -14.582       0.0361         0.705
# 98         0.722   0.560   -10.566       0.0564         0.211
# 99         0.405   0.246   -14.352       0.0462         0.932
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.000001    0.1030    0.506  143.767  1y7OxO5i6sfrHXAmUM77YG
# 1           0.000038    0.1350    0.551   91.768  3eg6Yi9x0gN3k4nD4h6il3
# 2           0.573000    0.1050    0.482  120.134  209ucYTS6vWEV5iydrHiOt
# 3           0.000432    0.1360    0.339  127.497  4SrJyRdyHYxxkcVMQ3QkGE
# 4           0.162000    0.0803    0.673  125.023  28xiVJLGLwEHNFDzXKUIdY
# ..               ...       ...      ...      ...                     ...
# 95          0.000000    0.3460    0.885  169.999  56Bd82ndrBY1JQ8r3oQzVl
# 96          0.005890    0.0858    0.960  117.969  6kp4npBzshDFMNDJhC0uRH
# 97          0.006580    0.1030    0.446  166.569  3EuORO2yfaSCohhkqOg6DI
# 98          0.863000    0.0681    0.915  123.362  7IzKaEpu718xiAyPhMMmHg
# 99          0.872000    0.0981    0.639   80.242  2fKIOUrSKTpI6LlRRELZ7a
#
#     duration_ms
# 0        212493
# 1        182973
# 2        233544
# 3        254667
# 4        211192
# ..          ...
# 95       261881
# 96       290847
# 97       376546
# 98       357120
# 99       289987
#
# [100 rows x 11 columns]

# %% [markdown]
# ## Next Playlist (6)

# %%
#https://open.spotify.com/playlist/3Gl6lTWGIZKGRh0bg1gztN?si=f6e976e5fec24a24
def get_playlist_tracks6(username, playlist_id):
    results6 = sp.user_playlist_tracks6(username,playlist_id,market="DE")
    tracks6 = results6['items']
    while results6['next']:
        results6 = sp.next(results6)
        tracks6.extend(results6['items'])
    return tracks6

# %%
tracks6=get_playlist_tracks("spotify", "3Gl6lTWGIZKGRh0bg1gztN")

# %%
playlist6 = sp.user_playlist_tracks("spotify","3Gl6lTWGIZKGRh0bg1gztN",market="DE")

# %%
list_of_audio_features6=[]
for item in range(0,607):
    list_of_audio_features6.append(sp.audio_features(tracks6[item]["track"]["id"])[0])

# %%
df6=pd.DataFrame(list_of_audio_features6)    
df6=df6[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df6
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.726   0.505   -11.545       0.0452       0.81900
# 1           0.707   0.802    -7.022       0.0445       0.01500
# 2           0.721   0.915    -9.087       0.0424       0.00290
# 3           0.739   0.750    -6.916       0.0489       0.06810
# 4           0.600   0.641   -10.415       0.0463       0.00608
# ..            ...     ...       ...          ...           ...
# 602         0.688   0.756    -6.248       0.0313       0.15000
# 603         0.884   0.770   -10.746       0.0582       0.02010
# 604         0.828   0.681    -9.571       0.0477       0.05540
# 605         0.652   0.756    -8.988       0.0365       0.01710
# 606         0.589   0.804    -6.105       0.0320       0.02430
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0               0.049    0.1250    0.303  129.916  63dWZKazdxf9Q2zfwNHHD1
# 1               0.173    0.2860    0.919  105.001  3ixglmGBPthnKVeNHANi5Z
# 2               0.805    0.0806    0.406  105.005  0IFkKWlkRUs6QAy7Z4tVeV
# 3               0.418    0.1270    0.752  119.980  08dxa01tat82thev4QO2iu
# 4               0.827    0.1490    0.166  110.937  1Az6HNj6W3kckEFYPHD8d5
# ..                ...       ...      ...      ...                     ...
# 602             0.815    0.0758    0.611   99.988  5acFePxQYax9Qkejb1avDe
# 603             0.888    0.0956    0.448  118.786  64oayzrVAe57AE4IIPKKOf
# 604             0.908    0.0713    0.687  109.995  4HshooUWGfFp0jlzqfCnsO
# 605             0.831    0.2120    0.841  111.109  1yAXD9x09EhJHlq2qQCyuD
# 606             0.929    0.1390    0.925  123.031  1GnJW3lwWbUKmiGHbA1dvr
#
#      duration_ms
# 0         165747
# 1         400823
# 2         498022
# 3         524164
# 4         617628
# ..           ...
# 602       340800
# 603       329293
# 604       302111
# 605       371875
# 606       334299
#
# [607 rows x 11 columns]

# %% [markdown]
# ## Next Playlist (7)

# %%
#https://open.spotify.com/playlist/1h0CEZCm6IbFTbxThn6Xcs?si=513dc069bc44481b
def get_playlist_tracks6(username, playlist_id):
    results7 = sp.user_playlist_tracks7(username,playlist_id,market="DE")
    tracks7 = results7['items']
    while results7['next']:
        results7 = sp.next(results7)
        tracks7.extend(results7['items'])
    return tracks7

# %%
tracks7=get_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs")

# %%
playlist7 = sp.user_playlist_tracks("spotify","1h0CEZCm6IbFTbxThn6Xcs",market="DE")

# %%
list_of_audio_features7=[]
for item in range(0,160):
    list_of_audio_features7.append(sp.audio_features(tracks7[item]["track"]["id"])[0])

# %%
df7=pd.DataFrame(list_of_audio_features7)    
df7=df7[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df7
# Out:
#      danceability   energy  loudness  speechiness  acousticness  \
# 0           0.213  0.06560   -24.810       0.0467         0.992
# 1           0.330  0.00357   -33.142       0.0339         0.995
# 2           0.368  0.00363   -36.759       0.0350         0.993
# 3           0.320  0.00501   -33.366       0.0455         0.993
# 4           0.701  0.34100   -12.260       0.0418         0.499
# ..            ...      ...       ...          ...           ...
# 155         0.217  0.04080   -26.146       0.0379         0.994
# 156         0.209  0.01520   -32.064       0.0573         0.996
# 157         0.162  0.06820   -21.254       0.0393         0.989
# 158         0.130  0.08600   -21.920       0.0373         0.932
# 159         0.176  0.00600   -42.238       0.0384         0.899
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.969000    0.0699   0.0384   65.023  3U8Fx7zNTQrctytkj6Gqgd
# 1            0.953000    0.0989   0.1210  100.741  6MzbO6YS0M6tjwT93hjAl0
# 2            0.922000    0.1370   0.0850   69.363  1L4NadMj3Jj7YgGaikyhfr
# 3            0.919000    0.0618   0.0383   68.947  3hCPh4oVVjaM8tv9sFH8cx
# 4            0.903000    0.3590   0.1630  105.513  5xbuJuQsTVheVZvX2AJVIv
# ..                ...       ...      ...      ...                     ...
# 155          0.912000    0.0553   0.0614  159.179  11kFCPT3e5GGpDQhX6d4sD
# 156          0.961000    0.0894   0.1490   84.292  536wHI10jgntsG8BaeiIog
# 157          0.475000    0.1160   0.0358  144.568  2TOUdZaG9w8pbGVoH0GohP
# 158          0.912000    0.1080   0.0375   90.223  3Sy6wgTNEp6vSgLs4EyXAf
# 159          0.000032    0.1050   0.0383   71.477  4wudbbceOZKjRlhTtbHvAs
#
#      duration_ms
# 0         150147
# 1         216213
# 2         254000
# 3         294960
# 4         151507
# ..           ...
# 155       260973
# 156        73000
# 157       228013
# 158       391160
# 159       636000
#
# [160 rows x 11 columns]

# %% [markdown]
# # Concatenating all the 7 playlists dataframes

# %%
df_all_playlists = pd.concat([df, df2, df3, df4, df5, df6, df7])
df_all_playlists
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.566  0.6640    -5.303       0.0464        0.6340
# 1           0.768  0.8200    -4.630       0.0474        0.1790
# 2           0.558  0.5590    -9.222       0.0959        0.3710
# 3           0.679  0.7150    -6.383       0.0407        0.0755
# 4           0.778  0.8240    -5.892       0.0707        0.2840
# ..            ...     ...       ...          ...           ...
# 155         0.217  0.0408   -26.146       0.0379        0.9940
# 156         0.209  0.0152   -32.064       0.0573        0.9960
# 157         0.162  0.0682   -21.254       0.0393        0.9890
# 158         0.130  0.0860   -21.920       0.0373        0.9320
# 159         0.176  0.0060   -42.238       0.0384        0.8990
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.1160   0.4370  128.945  3dYD57lRAUcMHufyqn9GcI
# 1            0.000000    0.6890   0.6250  129.965  2V4bv1fNWfTcyRJKmej6Sj
# 2            0.000007    0.1090   0.6200   78.558  7KA4W4McWYRpgf0fWsJZWB
# 3            0.000000    0.2710   0.5710  127.435  4Ub8UsjWuewQrPhuepfVpd
# 4            0.000000    0.4050   0.7580  100.024  3ZFTkvIE7kyPt6Nu3PEa7V
# ..                ...       ...      ...      ...                     ...
# 155          0.912000    0.0553   0.0614  159.179  11kFCPT3e5GGpDQhX6d4sD
# 156          0.961000    0.0894   0.1490   84.292  536wHI10jgntsG8BaeiIog
# 157          0.475000    0.1160   0.0358  144.568  2TOUdZaG9w8pbGVoH0GohP
# 158          0.912000    0.1080   0.0375   90.223  3Sy6wgTNEp6vSgLs4EyXAf
# 159          0.000032    0.1050   0.0383   71.477  4wudbbceOZKjRlhTtbHvAs
#
#      duration_ms
# 0         241688
# 1         213293
# 2         180387
# 3         214148
# 4         218093
# ..           ...
# 155       260973
# 156        73000
# 157       228013
# 158       391160
# 159       636000
#
# [2120 rows x 11 columns]

# %% [markdown]
# # Cleaning the dataframe

# %% [markdown]
# ## Finding duplicates rows

# %%
print(df_all_playlists.duplicated().sum())
# Out:
# 70

# %% [markdown]
# ## Getting rid of the duplicates

# %%
df_all_playlists= df_all_playlists.drop_duplicates()

# %%
df_all_playlists
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.566  0.6640    -5.303       0.0464        0.6340
# 1           0.768  0.8200    -4.630       0.0474        0.1790
# 2           0.558  0.5590    -9.222       0.0959        0.3710
# 3           0.679  0.7150    -6.383       0.0407        0.0755
# 4           0.778  0.8240    -5.892       0.0707        0.2840
# ..            ...     ...       ...          ...           ...
# 155         0.217  0.0408   -26.146       0.0379        0.9940
# 156         0.209  0.0152   -32.064       0.0573        0.9960
# 157         0.162  0.0682   -21.254       0.0393        0.9890
# 158         0.130  0.0860   -21.920       0.0373        0.9320
# 159         0.176  0.0060   -42.238       0.0384        0.8990
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.000000    0.1160   0.4370  128.945  3dYD57lRAUcMHufyqn9GcI
# 1            0.000000    0.6890   0.6250  129.965  2V4bv1fNWfTcyRJKmej6Sj
# 2            0.000007    0.1090   0.6200   78.558  7KA4W4McWYRpgf0fWsJZWB
# 3            0.000000    0.2710   0.5710  127.435  4Ub8UsjWuewQrPhuepfVpd
# 4            0.000000    0.4050   0.7580  100.024  3ZFTkvIE7kyPt6Nu3PEa7V
# ..                ...       ...      ...      ...                     ...
# 155          0.912000    0.0553   0.0614  159.179  11kFCPT3e5GGpDQhX6d4sD
# 156          0.961000    0.0894   0.1490   84.292  536wHI10jgntsG8BaeiIog
# 157          0.475000    0.1160   0.0358  144.568  2TOUdZaG9w8pbGVoH0GohP
# 158          0.912000    0.1080   0.0375   90.223  3Sy6wgTNEp6vSgLs4EyXAf
# 159          0.000032    0.1050   0.0383   71.477  4wudbbceOZKjRlhTtbHvAs
#
#      duration_ms
# 0         241688
# 1         213293
# 2         180387
# 3         214148
# 4         218093
# ..           ...
# 155       260973
# 156        73000
# 157       228013
# 158       391160
# 159       636000
#
# [2050 rows x 11 columns]

# %% [markdown]
# ## Saving dataframe in a csv version

# %%
df_all_playlists.to_csv('df_all_playlists.csv')
