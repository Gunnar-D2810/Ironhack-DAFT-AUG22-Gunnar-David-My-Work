# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# In order to use the Spotify API (SpotiPy) we will have to create an account in Spotify and follow these steps. Once we have done it we will start initializing the API and look at the search method for which we can introduce a "query" q, in this example we will try it with Lady Gaga:

# %%
##!conda install -c conda-forge spotipy

# %% [markdown]
# ## Loading credentials from another config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q="Lose yourself",limit=3,market="GB")
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['external_urls']["spotify"]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#      'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#      'id': '1rfORa9iYmocEsnnZGMVC4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#        'width': 64}],
#      'name': 'Just Lose It',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 322226,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#     'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#     'id': '1v7L65Lzy0j0vdpRjJewt1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#     'popularity': 79,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3CjuTytLZz3G9znXt2rJgU'},
#      'href': 'https://api.spotify.com/v1/albums/3CjuTytLZz3G9znXt2rJgU',
#      'id': '3CjuTytLZz3G9znXt2rJgU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f66b5b49ccea004a5ef0db2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f66b5b49ccea004a5ef0db2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f66b5b49ccea004a5ef0db2',
#        'width': 64}],
#      'name': 'SHADYXV',
#      'release_date': '2014-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:3CjuTytLZz3G9znXt2rJgU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 2,
#     'duration_ms': 320626,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MJQ9Nfxzh8LPZ9e9u68Fq'},
#     'href': 'https://api.spotify.com/v1/tracks/7MJQ9Nfxzh8LPZ9e9u68Fq',
#     'id': '7MJQ9Nfxzh8LPZ9e9u68Fq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself',
#     'popularity': 74,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7MJQ9Nfxzh8LPZ9e9u68Fq'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/353HFOqGHySp027oyr3aGs'},
#      'href': 'https://api.spotify.com/v1/albums/353HFOqGHySp027oyr3aGs',
#      'id': '353HFOqGHySp027oyr3aGs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27352ab2c1657a3e548ff021411',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0252ab2c1657a3e548ff021411',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485152ab2c1657a3e548ff021411',
#        'width': 64}],
#      'name': '8 Mile (Music From And Inspired By The Motion Picture)',
#      'release_date': '2002-10-29',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:353HFOqGHySp027oyr3aGs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 320293,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6GkTKjv1XbFVdI2D8vvDPu'},
#     'href': 'https://api.spotify.com/v1/tracks/6GkTKjv1XbFVdI2D8vvDPu',
#     'id': '6GkTKjv1XbFVdI2D8vvDPu',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6GkTKjv1XbFVdI2D8vvDPu'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 4311}}

# %%
results["tracks"]["items"][0]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'

# %%
track_id=track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '1v7L65Lzy0j0vdpRjJewt1'

# %% [markdown]
# ## Embeded track player

# %% [markdown]
# {'spotify': https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"
track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3hgl7EQwTutSm6PESsB7gZ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %% [markdown]
# <b> navigating through the dictionary..

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks']["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# <b> more readable version

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=1',
#             'items': [{'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#                                               'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#                                               'id': '7dGJo4pcD2V6oG8kP0tJRR',
#                                               'name': 'Eminem',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#                                  'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#                                  'id': '1rfORa9iYmocEsnnZGMVC4',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#                                              'width': 64}],
#                                  'name': 'Just Lose It',
#                                  'release_date': '2004-01-01',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 2,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#                                     'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#                                     'id': '7dGJo4pcD2V6oG8kP0tJRR',
#                                     'name': 'Eminem',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#                        'disc_number': 1,
#                        'duration_ms': 322226,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USIR10211559'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#                        'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#                        'id': '1v7L65Lzy0j0vdpRjJewt1',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#                        'popularity': 77,
#                        'preview_url': None,
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}],
#             'limit': 1,
#             'next': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=1&limit=1',
#             'offset': 0,
#             'previous': None,
#             'total': 4233}}

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#     'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#     'id': '7dGJo4pcD2V6oG8kP0tJRR',
#     'name': 'Eminem',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#   'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#   'id': '1rfORa9iYmocEsnnZGMVC4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#     'width': 64}],
#   'name': 'Just Lose It',
#   'release_date': '2004-01-01',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#    'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#    'id': '7dGJo4pcD2V6oG8kP0tJRR',
#    'name': 'Eminem',
#    'type': 'artist',
#    'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#  'disc_number': 1,
#  'duration_ms': 322226,
#  'explicit': True,
#  'external_ids': {'isrc': 'USIR10211559'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#  'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#  'id': '1v7L65Lzy0j0vdpRjJewt1',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#  'popularity': 77,
#  'preview_url': None,
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# <b> getting the track id

# %%
results['tracks']['items'][0]['id']
# Out:
# '1v7L65Lzy0j0vdpRjJewt1'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Lose Yourself - From "8 Mile" Soundtrack' and the id is: 1v7L65Lzy0j0vdpRjJewt1
# The name of song is: 'Lose Yourself' and the id is: 7MJQ9Nfxzh8LPZ9e9u68Fq
# The name of song is: 'Lose Yourself' and the id is: 6GkTKjv1XbFVdI2D8vvDPu

# %%
import pandas as pd

song = sp.search(q="Bad Guy", limit=50,market="GB") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bad+Guy&type=track&market=GB&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#      'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#      'id': '0S0KGZnfBGSIssfF54WSJh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#        'width': 64}],
#      'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Fxmhks0bxGSBdJ92vM42m'},
#     'href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#     'id': '2Fxmhks0bxGSBdJ92vM42m',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 84,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lMlX68jJrx67hiCqdiDvW'},
#      'href': 'https://api.spotify.com/v1/albums/6lMlX68jJrx67hiCqdiDvW',
#      'id': '6lMlX68jJrx67hiCqdiDvW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a69b8b111a5fb8cb1c97e8eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a69b8b111a5fb8cb1c97e8eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a69b8b111a5fb8cb1c97e8eb',
#        'width': 64}],
#      'name': 'bad guy (with Justin Bieber)',
#      'release_date': '2019-07-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6lMlX68jJrx67hiCqdiDvW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'disc_number': 1,
#     'duration_ms': 194839,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71912813'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3yNZ5r3LKfdmjoS3gkhUCT'},
#     'href': 'https://api.spotify.com/v1/tracks/3yNZ5r3LKfdmjoS3gkhUCT',
#     'id': '3yNZ5r3LKfdmjoS3gkhUCT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy (with Justin Bieber)',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3yNZ5r3LKfdmjoS3gkhUCT'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6AugscLeajzm3pnamBGdOz'},
#      'href': 'https://api.spotify.com/v1/albums/6AugscLeajzm3pnamBGdOz',
#      'id': '6AugscLeajzm3pnamBGdOz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737fffa0a1302a6cadc5ca32eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027fffa0a1302a6cadc5ca32eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517fffa0a1302a6cadc5ca32eb',
#        'width': 64}],
#      'name': '4th of July Pop Edition',
#      'release_date': '2022-06-23',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:6AugscLeajzm3pnamBGdOz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2s5krQtudVMNZetgxGHNBG'},
#     'href': 'https://api.spotify.com/v1/tracks/2s5krQtudVMNZetgxGHNBG',
#     'id': '2s5krQtudVMNZetgxGHNBG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 6,
#     'preview_url': None,
#     'track_number': 27,
#     'type': 'track',
#     'uri': 'spotify:track:2s5krQtudVMNZetgxGHNBG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#        'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#        'id': '3f626JSVauIhTQgatsFcs4',
#        'name': 'Paul Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Je0MVXBcSsJ3dhXXjYJpv'},
#      'href': 'https://api.spotify.com/v1/albums/4Je0MVXBcSsJ3dhXXjYJpv',
#      'id': '4Je0MVXBcSsJ3dhXXjYJpv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bec3afb4a8379d8adf24b1a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bec3afb4a8379d8adf24b1a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bec3afb4a8379d8adf24b1a2',
#        'width': 64}],
#      'name': 'Bugsy Malone (From "Bugsy Malone" Original Motion Picture Soundtrack)',
#      'release_date': '1976-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4Je0MVXBcSsJ3dhXXjYJpv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#       'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#       'id': '3f626JSVauIhTQgatsFcs4',
#       'name': 'Paul Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#     'disc_number': 1,
#     'duration_ms': 136133,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAKW7600475'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3gZoHbFt5W3HltDGcnbDrD'},
#     'href': 'https://api.spotify.com/v1/tracks/3gZoHbFt5W3HltDGcnbDrD',
#     'id': '3gZoHbFt5W3HltDGcnbDrD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys - From "Bugsy Malone" Original Motion Picture Soundtrack',
#     'popularity': 39,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3gZoHbFt5W3HltDGcnbDrD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6DN7GcZF1HywzrkGN6Eeqk'},
#      'href': 'https://api.spotify.com/v1/albums/6DN7GcZF1HywzrkGN6Eeqk',
#      'id': '6DN7GcZF1HywzrkGN6Eeqk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb66bcc14c6f857c127d5969',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb66bcc14c6f857c127d5969',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb66bcc14c6f857c127d5969',
#        'width': 64}],
#      'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6DN7GcZF1HywzrkGN6Eeqk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 434077,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71314073'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3IaAYtmN8T0YIYVqnxNnVz'},
#     'href': 'https://api.spotify.com/v1/tracks/3IaAYtmN8T0YIYVqnxNnVz',
#     'id': '3IaAYtmN8T0YIYVqnxNnVz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 60,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3IaAYtmN8T0YIYVqnxNnVz'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6dcMsF4Ou2UckayU6ycNhY'},
#      'href': 'https://api.spotify.com/v1/albums/6dcMsF4Ou2UckayU6ycNhY',
#      'id': '6dcMsF4Ou2UckayU6ycNhY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c4fb66a0cc22ad9d1989270f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c4fb66a0cc22ad9d1989270f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c4fb66a0cc22ad9d1989270f',
#        'width': 64}],
#      'name': 'BBQ Party 2022',
#      'release_date': '2022-06-29',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:6dcMsF4Ou2UckayU6ycNhY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6x3jFFNMbYIz8hUTIWS1Eo'},
#     'href': 'https://api.spotify.com/v1/tracks/6x3jFFNMbYIz8hUTIWS1Eo',
#     'id': '6x3jFFNMbYIz8hUTIWS1Eo',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 2,
#     'preview_url': None,
#     'track_number': 30,
#     'type': 'track',
#     'uri': 'spotify:track:6x3jFFNMbYIz8hUTIWS1Eo'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#        'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#        'id': '6MERXsiRbur2oJZFgYRDKz',
#        'name': 'Vitamin String Quartet',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wWBoQpcybsDVpouFubTqZ'},
#        'href': 'https://api.spotify.com/v1/artists/2wWBoQpcybsDVpouFubTqZ',
#        'id': '2wWBoQpcybsDVpouFubTqZ',
#        'name': 'Kris Bowers',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wWBoQpcybsDVpouFubTqZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5dhbc8LcvYmiI2CQhByaBR'},
#        'href': 'https://api.spotify.com/v1/artists/5dhbc8LcvYmiI2CQhByaBR',
#        'id': '5dhbc8LcvYmiI2CQhByaBR',
#        'name': 'Duomo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dhbc8LcvYmiI2CQhByaBR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5zdSoEL5yn9hXs7bJQdnqe'},
#      'href': 'https://api.spotify.com/v1/albums/5zdSoEL5yn9hXs7bJQdnqe',
#      'id': '5zdSoEL5yn9hXs7bJQdnqe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a40f30c4800e43a7df2aa1a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a40f30c4800e43a7df2aa1a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a40f30c4800e43a7df2aa1a7',
#        'width': 64}],
#      'name': 'Bridgerton (Covers from the Netflix Original Series)',
#      'release_date': '2020-12-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5zdSoEL5yn9hXs7bJQdnqe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#       'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#       'id': '6MERXsiRbur2oJZFgYRDKz',
#       'name': 'Vitamin String Quartet',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#     'disc_number': 1,
#     'duration_ms': 193226,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1990865'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qOsHMitiWT4Zhx9ICzmjW'},
#     'href': 'https://api.spotify.com/v1/tracks/1qOsHMitiWT4Zhx9ICzmjW',
#     'id': '1qOsHMitiWT4Zhx9ICzmjW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4ff5c9a72ebd59de2cf41fe83644834456e989d5?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1qOsHMitiWT4Zhx9ICzmjW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#        'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#        'id': '5ND0mGcL9SKSjWIjPd0xIb',
#        'name': 'Bowling For Soup',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2safYwJ4j0WKLcQUwEBQEi'},
#      'href': 'https://api.spotify.com/v1/albums/2safYwJ4j0WKLcQUwEBQEi',
#      'id': '2safYwJ4j0WKLcQUwEBQEi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27397ed7b212715424daac8c600',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0297ed7b212715424daac8c600',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485197ed7b212715424daac8c600',
#        'width': 64}],
#      'name': 'Drunk Enough To Dance',
#      'release_date': '2002',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:2safYwJ4j0WKLcQUwEBQEi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#       'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#       'id': '5ND0mGcL9SKSjWIjPd0xIb',
#       'name': 'Bowling For Soup',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'}],
#     'disc_number': 1,
#     'duration_ms': 197800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10200080'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KqyBk4aVT88TEqBIC8mAP'},
#     'href': 'https://api.spotify.com/v1/tracks/0KqyBk4aVT88TEqBIC8mAP',
#     'id': '0KqyBk4aVT88TEqBIC8mAP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Girl All the Bad Guys Want',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5bcc19208807576006348dce8e193cb1ad3b6b60?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0KqyBk4aVT88TEqBIC8mAP'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25Maank76ry2Tmbi2Ql1SF'},
#        'href': 'https://api.spotify.com/v1/artists/25Maank76ry2Tmbi2Ql1SF',
#        'id': '25Maank76ry2Tmbi2Ql1SF',
#        'name': 'The Interrupters',
#        'type': 'artist',
#        'uri': 'spotify:artist:25Maank76ry2Tmbi2Ql1SF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2oU2YsoVW3KG0jIlDXWIkx'},
#      'href': 'https://api.spotify.com/v1/albums/2oU2YsoVW3KG0jIlDXWIkx',
#      'id': '2oU2YsoVW3KG0jIlDXWIkx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a33fad32ad43b17010154e0a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a33fad32ad43b17010154e0a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a33fad32ad43b17010154e0a',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2019-10-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2oU2YsoVW3KG0jIlDXWIkx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25Maank76ry2Tmbi2Ql1SF'},
#       'href': 'https://api.spotify.com/v1/artists/25Maank76ry2Tmbi2Ql1SF',
#       'id': '25Maank76ry2Tmbi2Ql1SF',
#       'name': 'The Interrupters',
#       'type': 'artist',
#       'uri': 'spotify:artist:25Maank76ry2Tmbi2Ql1SF'}],
#     'disc_number': 1,
#     'duration_ms': 157831,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHEL1901003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iM1Ioz4N4p7MU1DKyqsov'},
#     'href': 'https://api.spotify.com/v1/tracks/0iM1Ioz4N4p7MU1DKyqsov',
#     'id': '0iM1Ioz4N4p7MU1DKyqsov',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/974dd5be76f18bb66527a454269473f8410a0ba0?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iM1Ioz4N4p7MU1DKyqsov'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#        'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#        'id': '3bn93QEHOITZ4ARuiZdfRA',
#        'name': 'Morrisson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#        'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#        'id': '5VNMclLseLzRnVhvkrqdpn',
#        'name': 'Loski',
#        'type': 'artist',
#        'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1lHttlzArtuCKOvxe12DN3'},
#      'href': 'https://api.spotify.com/v1/albums/1lHttlzArtuCKOvxe12DN3',
#      'id': '1lHttlzArtuCKOvxe12DN3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a4dfd9835c62bf673851d87',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a4dfd9835c62bf673851d87',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a4dfd9835c62bf673851d87',
#        'width': 64}],
#      'name': 'Bad Guy (feat. Loski)',
#      'release_date': '2020-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1lHttlzArtuCKOvxe12DN3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#       'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#       'id': '3bn93QEHOITZ4ARuiZdfRA',
#       'name': 'Morrisson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#       'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#       'id': '5VNMclLseLzRnVhvkrqdpn',
#       'name': 'Loski',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#     'disc_number': 1,
#     'duration_ms': 221560,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBARL2001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VQKKey9XgeYOm6rd1Aje8'},
#     'href': 'https://api.spotify.com/v1/tracks/1VQKKey9XgeYOm6rd1Aje8',
#     'id': '1VQKKey9XgeYOm6rd1Aje8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (feat. Loski)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3c19b91f49ba7119a446109268c2fda8b9b55a16?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1VQKKey9XgeYOm6rd1Aje8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CmaKO2zEGJ1NWpS1yfVGz'},
#        'href': 'https://api.spotify.com/v1/artists/2CmaKO2zEGJ1NWpS1yfVGz',
#        'id': '2CmaKO2zEGJ1NWpS1yfVGz',
#        'name': 'Falling In Reverse',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CmaKO2zEGJ1NWpS1yfVGz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KwwS07TEbKS8r1rU4UUe4'},
#      'href': 'https://api.spotify.com/v1/albums/1KwwS07TEbKS8r1rU4UUe4',
#      'id': '1KwwS07TEbKS8r1rU4UUe4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a4546ed22694f4297f6bdb9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a4546ed22694f4297f6bdb9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a4546ed22694f4297f6bdb9',
#        'width': 64}],
#      'name': 'The Drug In Me Is You',
#      'release_date': '2011-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1KwwS07TEbKS8r1rU4UUe4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CmaKO2zEGJ1NWpS1yfVGz'},
#       'href': 'https://api.spotify.com/v1/artists/2CmaKO2zEGJ1NWpS1yfVGz',
#       'id': '2CmaKO2zEGJ1NWpS1yfVGz',
#       'name': 'Falling In Reverse',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CmaKO2zEGJ1NWpS1yfVGz'}],
#     'disc_number': 1,
#     'duration_ms': 195373,
#     'explicit': True,
#     'external_ids': {'isrc': 'USEP41118005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78ML3F5Lz3KiNkpnFAaR3q'},
#     'href': 'https://api.spotify.com/v1/tracks/78ML3F5Lz3KiNkpnFAaR3q',
#     'id': '78ML3F5Lz3KiNkpnFAaR3q',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Good Girls Bad Guys',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b6fa3c43bb7d890eb178328ac784168611ee2262?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:78ML3F5Lz3KiNkpnFAaR3q'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47XRL63LCDh1LkOq7W69WA'},
#        'href': 'https://api.spotify.com/v1/artists/47XRL63LCDh1LkOq7W69WA',
#        'id': '47XRL63LCDh1LkOq7W69WA',
#        'name': 'Clay K Slider',
#        'type': 'artist',
#        'uri': 'spotify:artist:47XRL63LCDh1LkOq7W69WA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UBK7oymoowTKxYBz8VGeU'},
#      'href': 'https://api.spotify.com/v1/albums/0UBK7oymoowTKxYBz8VGeU',
#      'id': '0UBK7oymoowTKxYBz8VGeU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db1cf1c1ed30dd12a79afcac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db1cf1c1ed30dd12a79afcac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db1cf1c1ed30dd12a79afcac',
#        'width': 64}],
#      'name': 'KK Slider Covers',
#      'release_date': '2019-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:0UBK7oymoowTKxYBz8VGeU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47XRL63LCDh1LkOq7W69WA'},
#       'href': 'https://api.spotify.com/v1/artists/47XRL63LCDh1LkOq7W69WA',
#       'id': '47XRL63LCDh1LkOq7W69WA',
#       'name': 'Clay K Slider',
#       'type': 'artist',
#       'uri': 'spotify:artist:47XRL63LCDh1LkOq7W69WA'}],
#     'disc_number': 1,
#     'duration_ms': 135882,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHN91936038'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4I1ypegnI8R0HlsAF5rZYn'},
#     'href': 'https://api.spotify.com/v1/tracks/4I1ypegnI8R0HlsAF5rZYn',
#     'id': '4I1ypegnI8R0HlsAF5rZYn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53a3945235c96f14155525e42aac712fb4540d8c?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4I1ypegnI8R0HlsAF5rZYn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oYuKMBiaAc0W8Gt7FVIjb'},
#        'href': 'https://api.spotify.com/v1/artists/5oYuKMBiaAc0W8Gt7FVIjb',
#        'id': '5oYuKMBiaAc0W8Gt7FVIjb',
#        'name': 'We Three',
#        'type': 'artist',
#        'uri': 'spotify:artist:5oYuKMBiaAc0W8Gt7FVIjb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7trgJ2APR947xPbysXVx8n'},
#      'href': 'https://api.spotify.com/v1/albums/7trgJ2APR947xPbysXVx8n',
#      'id': '7trgJ2APR947xPbysXVx8n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d9aa20143667f19089e9e5c7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d9aa20143667f19089e9e5c7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d9aa20143667f19089e9e5c7',
#        'width': 64}],
#      'name': 'Happy',
#      'release_date': '2022-05-27',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7trgJ2APR947xPbysXVx8n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oYuKMBiaAc0W8Gt7FVIjb'},
#       'href': 'https://api.spotify.com/v1/artists/5oYuKMBiaAc0W8Gt7FVIjb',
#       'id': '5oYuKMBiaAc0W8Gt7FVIjb',
#       'name': 'We Three',
#       'type': 'artist',
#       'uri': 'spotify:artist:5oYuKMBiaAc0W8Gt7FVIjb'}],
#     'disc_number': 1,
#     'duration_ms': 152969,
#     'explicit': True,
#     'external_ids': {'isrc': 'GB5ZK2100025'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6O0yvfx7qeE16s0UyhxOVT'},
#     'href': 'https://api.spotify.com/v1/tracks/6O0yvfx7qeE16s0UyhxOVT',
#     'id': '6O0yvfx7qeE16s0UyhxOVT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4cc6fe4a201a24b8b9a5e77a853dfee9912eda0?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6O0yvfx7qeE16s0UyhxOVT'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#      'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#      'id': '0S0KGZnfBGSIssfF54WSJh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#        'width': 64}],
#      'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 196077,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71815958'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/43zdsphuZLzwA9k4DJhU0I'},
#     'href': 'https://api.spotify.com/v1/tracks/43zdsphuZLzwA9k4DJhU0I',
#     'id': '43zdsphuZLzwA9k4DJhU0I',
#     'is_local': False,
#     'is_playable': True,
#     'name': "when the party's over",
#     'popularity': 82,
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:43zdsphuZLzwA9k4DJhU0I'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kART38d9tWb1yOcSO40YH'},
#        'href': 'https://api.spotify.com/v1/artists/6kART38d9tWb1yOcSO40YH',
#        'id': '6kART38d9tWb1yOcSO40YH',
#        'name': 'Eklipse',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kART38d9tWb1yOcSO40YH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jgCENuww6WXc03Gpm3bKe'},
#      'href': 'https://api.spotify.com/v1/albums/7jgCENuww6WXc03Gpm3bKe',
#      'id': '7jgCENuww6WXc03Gpm3bKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a4bfa1801605c62c6d102346',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a4bfa1801605c62c6d102346',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a4bfa1801605c62c6d102346',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2020-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7jgCENuww6WXc03Gpm3bKe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kART38d9tWb1yOcSO40YH'},
#       'href': 'https://api.spotify.com/v1/artists/6kART38d9tWb1yOcSO40YH',
#       'id': '6kART38d9tWb1yOcSO40YH',
#       'name': 'Eklipse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kART38d9tWb1yOcSO40YH'}],
#     'disc_number': 1,
#     'duration_ms': 191974,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEPI82010434'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FH0jT9o0mz71s7AtMkAa4'},
#     'href': 'https://api.spotify.com/v1/tracks/2FH0jT9o0mz71s7AtMkAa4',
#     'id': '2FH0jT9o0mz71s7AtMkAa4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0c2e321a33e79373b4452b181292df3f51557383?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2FH0jT9o0mz71s7AtMkAa4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#      'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#      'id': '0JGOiO34nwfUdDrD612dOp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#        'width': 64}],
#      'name': 'Happier Than Ever',
#      'release_date': '2021-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 210232,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72104675'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4t2OeILB07eMGTXSUbMPEu'},
#     'href': 'https://api.spotify.com/v1/tracks/4t2OeILB07eMGTXSUbMPEu',
#     'id': '4t2OeILB07eMGTXSUbMPEu',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Oxytocin',
#     'popularity': 73,
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4t2OeILB07eMGTXSUbMPEu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10nO3EJJDMm6j6d2uK3Jah'},
#      'href': 'https://api.spotify.com/v1/albums/10nO3EJJDMm6j6d2uK3Jah',
#      'id': '10nO3EJJDMm6j6d2uK3Jah',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d12909c6ebc83cb4c6bef6f4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d12909c6ebc83cb4c6bef6f4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d12909c6ebc83cb4c6bef6f4',
#        'width': 64}],
#      'name': 'The Slim Shady LP (Expanded Edition)',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:10nO3EJJDMm6j6d2uK3Jah'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6DPYiyq5kWVQS4RGwxzPC7'},
#       'href': 'https://api.spotify.com/v1/artists/6DPYiyq5kWVQS4RGwxzPC7',
#       'id': '6DPYiyq5kWVQS4RGwxzPC7',
#       'name': 'Dr. Dre',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DPYiyq5kWVQS4RGwxzPC7'}],
#     'disc_number': 1,
#     'duration_ms': 279133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR19902296'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4KVVy0GeXO03ni8Cv4SWk8'},
#     'href': 'https://api.spotify.com/v1/tracks/4KVVy0GeXO03ni8Cv4SWk8',
#     'id': '4KVVy0GeXO03ni8Cv4SWk8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys Always Die - From "Wild Wild West" Soundtrack',
#     'popularity': 48,
#     'preview_url': None,
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:4KVVy0GeXO03ni8Cv4SWk8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28dC2QiilKWSn06mecinrD'},
#        'href': 'https://api.spotify.com/v1/artists/28dC2QiilKWSn06mecinrD',
#        'id': '28dC2QiilKWSn06mecinrD',
#        'name': 'Zeeteah Massiah',
#        'type': 'artist',
#        'uri': 'spotify:artist:28dC2QiilKWSn06mecinrD'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7h0cjF0PQQMRkr0lXIlMA7'},
#      'href': 'https://api.spotify.com/v1/albums/7h0cjF0PQQMRkr0lXIlMA7',
#      'id': '7h0cjF0PQQMRkr0lXIlMA7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334312ad890041f565b90ba37',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234312ad890041f565b90ba37',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134312ad890041f565b90ba37',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2022-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7h0cjF0PQQMRkr0lXIlMA7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28dC2QiilKWSn06mecinrD'},
#       'href': 'https://api.spotify.com/v1/artists/28dC2QiilKWSn06mecinrD',
#       'id': '28dC2QiilKWSn06mecinrD',
#       'name': 'Zeeteah Massiah',
#       'type': 'artist',
#       'uri': 'spotify:artist:28dC2QiilKWSn06mecinrD'}],
#     'disc_number': 1,
#     'duration_ms': 240000,
#     'explicit': False,
#     'external_ids': {'isrc': 'UK8MD1800036'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0OnmY8BGZsxzEhyZJ43ooZ'},
#     'href': 'https://api.spotify.com/v1/tracks/0OnmY8BGZsxzEhyZJ43ooZ',
#     'id': '0OnmY8BGZsxzEhyZJ43ooZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16ce56d034fd17bc508509e51a3a62eae5f6b54c?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0OnmY8BGZsxzEhyZJ43ooZ'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5njMahLKD1tLJ5bejvqseV'},
#        'href': 'https://api.spotify.com/v1/artists/5njMahLKD1tLJ5bejvqseV',
#        'id': '5njMahLKD1tLJ5bejvqseV',
#        'name': 'Workout Music ',
#        'type': 'artist',
#        'uri': 'spotify:artist:5njMahLKD1tLJ5bejvqseV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59kxWJDPhfg2yJUbOKabOb'},
#      'href': 'https://api.spotify.com/v1/albums/59kxWJDPhfg2yJUbOKabOb',
#      'id': '59kxWJDPhfg2yJUbOKabOb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733fa44238207932316a87a992',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023fa44238207932316a87a992',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513fa44238207932316a87a992',
#        'width': 64}],
#      'name': '100 New Year 2020! Fitness & Workout Collection',
#      'release_date': '2019-12-26',
#      'release_date_precision': 'day',
#      'total_tracks': 100,
#      'type': 'album',
#      'uri': 'spotify:album:59kxWJDPhfg2yJUbOKabOb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5njMahLKD1tLJ5bejvqseV'},
#       'href': 'https://api.spotify.com/v1/artists/5njMahLKD1tLJ5bejvqseV',
#       'id': '5njMahLKD1tLJ5bejvqseV',
#       'name': 'Workout Music ',
#       'type': 'artist',
#       'uri': 'spotify:artist:5njMahLKD1tLJ5bejvqseV'}],
#     'disc_number': 1,
#     'duration_ms': 281252,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUV401916719'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5v7OrTvBQNhXQwVzi3oXpb'},
#     'href': 'https://api.spotify.com/v1/tracks/5v7OrTvBQNhXQwVzi3oXpb',
#     'id': '5v7OrTvBQNhXQwVzi3oXpb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (Remix)',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c892ea2abad01db3252a57161eed43347f9fe90f?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5v7OrTvBQNhXQwVzi3oXpb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gvJCmaQhMlqFpXCaz9o3l'},
#        'href': 'https://api.spotify.com/v1/artists/7gvJCmaQhMlqFpXCaz9o3l',
#        'id': '7gvJCmaQhMlqFpXCaz9o3l',
#        'name': '7AM',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gvJCmaQhMlqFpXCaz9o3l'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Btky5ia7ihAQE8UEXPmbQ'},
#        'href': 'https://api.spotify.com/v1/artists/0Btky5ia7ihAQE8UEXPmbQ',
#        'id': '0Btky5ia7ihAQE8UEXPmbQ',
#        'name': 'DJ Boat',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Btky5ia7ihAQE8UEXPmbQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UMoEumdcdZdCjZChHIjBh'},
#      'href': 'https://api.spotify.com/v1/albums/2UMoEumdcdZdCjZChHIjBh',
#      'id': '2UMoEumdcdZdCjZChHIjBh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738445b0e6be4f5bcf897e48f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028445b0e6be4f5bcf897e48f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518445b0e6be4f5bcf897e48f5',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2021-09-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2UMoEumdcdZdCjZChHIjBh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gvJCmaQhMlqFpXCaz9o3l'},
#       'href': 'https://api.spotify.com/v1/artists/7gvJCmaQhMlqFpXCaz9o3l',
#       'id': '7gvJCmaQhMlqFpXCaz9o3l',
#       'name': '7AM',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gvJCmaQhMlqFpXCaz9o3l'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Btky5ia7ihAQE8UEXPmbQ'},
#       'href': 'https://api.spotify.com/v1/artists/0Btky5ia7ihAQE8UEXPmbQ',
#       'id': '0Btky5ia7ihAQE8UEXPmbQ',
#       'name': 'DJ Boat',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Btky5ia7ihAQE8UEXPmbQ'}],
#     'disc_number': 1,
#     'duration_ms': 150810,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZK6H2157492'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iXlgib8Sp7tU0tRdoUJYg'},
#     'href': 'https://api.spotify.com/v1/tracks/0iXlgib8Sp7tU0tRdoUJYg',
#     'id': '0iXlgib8Sp7tU0tRdoUJYg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a64d51d5fbe17a714cc078ca42c6eb2276981cd1?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iXlgib8Sp7tU0tRdoUJYg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#        'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#        'id': '3bn93QEHOITZ4ARuiZdfRA',
#        'name': 'Morrisson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6TJhrY1zpxLFbrKDAM5Nci'},
#      'href': 'https://api.spotify.com/v1/albums/6TJhrY1zpxLFbrKDAM5Nci',
#      'id': '6TJhrY1zpxLFbrKDAM5Nci',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d3824f87f0c4401bbba74087',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d3824f87f0c4401bbba74087',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d3824f87f0c4401bbba74087',
#        'width': 64}],
#      'name': 'Guilty',
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:6TJhrY1zpxLFbrKDAM5Nci'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#       'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#       'id': '3bn93QEHOITZ4ARuiZdfRA',
#       'name': 'Morrisson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#       'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#       'id': '5VNMclLseLzRnVhvkrqdpn',
#       'name': 'Loski',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#     'disc_number': 1,
#     'duration_ms': 221560,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBARL2001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vLzU22xRA0pz9A8Ch1NNl'},
#     'href': 'https://api.spotify.com/v1/tracks/7vLzU22xRA0pz9A8Ch1NNl',
#     'id': '7vLzU22xRA0pz9A8Ch1NNl',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (feat. Loski)',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/deaea57b23c2ae68962f9c758a4699a4b54e7060?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7vLzU22xRA0pz9A8Ch1NNl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06bDwgCHeMAwhgI8il4Y5k'},
#        'href': 'https://api.spotify.com/v1/artists/06bDwgCHeMAwhgI8il4Y5k',
#        'id': '06bDwgCHeMAwhgI8il4Y5k',
#        'name': 'Set It Off',
#        'type': 'artist',
#        'uri': 'spotify:artist:06bDwgCHeMAwhgI8il4Y5k'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mPWTksMsByAvomErPtJwK'},
#      'href': 'https://api.spotify.com/v1/albums/4mPWTksMsByAvomErPtJwK',
# ...
#     'href': 'https://api.spotify.com/v1/tracks/4SSnFejRGlZikf02HLewEF',
#     'id': '4SSnFejRGlZikf02HLewEF',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bury a friend',
#     'popularity': 76,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4SSnFejRGlZikf02HLewEF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1S4xN9nvW5vlFoRBisdxUL'},
#        'href': 'https://api.spotify.com/v1/artists/1S4xN9nvW5vlFoRBisdxUL',
#        'id': '1S4xN9nvW5vlFoRBisdxUL',
#        'name': 'Halocene',
#        'type': 'artist',
#        'uri': 'spotify:artist:1S4xN9nvW5vlFoRBisdxUL'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4s55DWm3NXYRDaLmPPVAzf'},
#      'href': 'https://api.spotify.com/v1/albums/4s55DWm3NXYRDaLmPPVAzf',
#      'id': '4s55DWm3NXYRDaLmPPVAzf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273070fa9828974babd7ddf9e64',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02070fa9828974babd7ddf9e64',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851070fa9828974babd7ddf9e64',
#        'width': 64}],
#      'name': "We've Got It Covered: Vol 6",
#      'release_date': '2019-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 23,
#      'type': 'album',
#      'uri': 'spotify:album:4s55DWm3NXYRDaLmPPVAzf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1S4xN9nvW5vlFoRBisdxUL'},
#       'href': 'https://api.spotify.com/v1/artists/1S4xN9nvW5vlFoRBisdxUL',
#       'id': '1S4xN9nvW5vlFoRBisdxUL',
#       'name': 'Halocene',
#       'type': 'artist',
#       'uri': 'spotify:artist:1S4xN9nvW5vlFoRBisdxUL'}],
#     'disc_number': 1,
#     'duration_ms': 193361,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZES81910643'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ER1r3QQOPfjj3x1UCa5pq'},
#     'href': 'https://api.spotify.com/v1/tracks/7ER1r3QQOPfjj3x1UCa5pq',
#     'id': '7ER1r3QQOPfjj3x1UCa5pq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c04976e140b03b1f2f065a388718396b534a485e?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7ER1r3QQOPfjj3x1UCa5pq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4M1FpEWs2PeYfJe7xxJfhH'},
#        'href': 'https://api.spotify.com/v1/artists/4M1FpEWs2PeYfJe7xxJfhH',
#        'id': '4M1FpEWs2PeYfJe7xxJfhH',
#        'name': 'Freddie Mercury',
#        'type': 'artist',
#        'uri': 'spotify:artist:4M1FpEWs2PeYfJe7xxJfhH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5FfDjZOCUOH4viaDqB6ZPF'},
#      'href': 'https://api.spotify.com/v1/albums/5FfDjZOCUOH4viaDqB6ZPF',
#      'id': '5FfDjZOCUOH4viaDqB6ZPF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb9b9159e1ecb0614c2fc945',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb9b9159e1ecb0614c2fc945',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb9b9159e1ecb0614c2fc945',
#        'width': 64}],
#      'name': 'Mr Bad Guy (Special Edition)',
#      'release_date': '2019-10-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5FfDjZOCUOH4viaDqB6ZPF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4M1FpEWs2PeYfJe7xxJfhH'},
#       'href': 'https://api.spotify.com/v1/artists/4M1FpEWs2PeYfJe7xxJfhH',
#       'id': '4M1FpEWs2PeYfJe7xxJfhH',
#       'name': 'Freddie Mercury',
#       'type': 'artist',
#       'uri': 'spotify:artist:4M1FpEWs2PeYfJe7xxJfhH'}],
#     'disc_number': 1,
#     'duration_ms': 225100,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71903064'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0otmxJEwq9JI1CidrcYEq4'},
#     'href': 'https://api.spotify.com/v1/tracks/0otmxJEwq9JI1CidrcYEq4',
#     'id': '0otmxJEwq9JI1CidrcYEq4',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Love Me Like There's No Tomorrow - Special Edition",
#     'popularity': 57,
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:0otmxJEwq9JI1CidrcYEq4'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63bCkf4n15jiKjHhLV7kSZ'},
#        'href': 'https://api.spotify.com/v1/artists/63bCkf4n15jiKjHhLV7kSZ',
#        'id': '63bCkf4n15jiKjHhLV7kSZ',
#        'name': 'Niykee Heaton',
#        'type': 'artist',
#        'uri': 'spotify:artist:63bCkf4n15jiKjHhLV7kSZ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ZWlheyrmKAaNoaa1dsq5T'},
#      'href': 'https://api.spotify.com/v1/albums/1ZWlheyrmKAaNoaa1dsq5T',
#      'id': '1ZWlheyrmKAaNoaa1dsq5T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27356e1e5fe96b03fe6a6da1e02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0256e1e5fe96b03fe6a6da1e02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485156e1e5fe96b03fe6a6da1e02',
#        'width': 64}],
#      'name': 'Starting Over',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1ZWlheyrmKAaNoaa1dsq5T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63bCkf4n15jiKjHhLV7kSZ'},
#       'href': 'https://api.spotify.com/v1/artists/63bCkf4n15jiKjHhLV7kSZ',
#       'id': '63bCkf4n15jiKjHhLV7kSZ',
#       'name': 'Niykee Heaton',
#       'type': 'artist',
#       'uri': 'spotify:artist:63bCkf4n15jiKjHhLV7kSZ'}],
#     'disc_number': 1,
#     'duration_ms': 213553,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71813688'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34LbYwWS8Vxr6dsdZ64OXd'},
#     'href': 'https://api.spotify.com/v1/tracks/34LbYwWS8Vxr6dsdZ64OXd',
#     'id': '34LbYwWS8Vxr6dsdZ64OXd',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 47,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:34LbYwWS8Vxr6dsdZ64OXd'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#        'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#        'id': '3f626JSVauIhTQgatsFcs4',
#        'name': 'Paul Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Je0MVXBcSsJ3dhXXjYJpv'},
#      'href': 'https://api.spotify.com/v1/albums/4Je0MVXBcSsJ3dhXXjYJpv',
#      'id': '4Je0MVXBcSsJ3dhXXjYJpv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bec3afb4a8379d8adf24b1a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bec3afb4a8379d8adf24b1a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bec3afb4a8379d8adf24b1a2',
#        'width': 64}],
#      'name': 'Bugsy Malone (From "Bugsy Malone" Original Motion Picture Soundtrack)',
#      'release_date': '1976-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4Je0MVXBcSsJ3dhXXjYJpv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#       'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#       'id': '3f626JSVauIhTQgatsFcs4',
#       'name': 'Paul Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#     'disc_number': 1,
#     'duration_ms': 234106,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAKW7600481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69XnaNHFaYiND63w3tUoga'},
#     'href': 'https://api.spotify.com/v1/tracks/69XnaNHFaYiND63w3tUoga',
#     'id': '69XnaNHFaYiND63w3tUoga',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'You Give A Little Love - From "Bugsy Malone" Original Motion Picture Soundtrack',
#     'popularity': 41,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:69XnaNHFaYiND63w3tUoga'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aLQtm6eoBgUhsbHvgAJPF'},
#        'href': 'https://api.spotify.com/v1/artists/5aLQtm6eoBgUhsbHvgAJPF',
#        'id': '5aLQtm6eoBgUhsbHvgAJPF',
#        'name': 'The Cog is Dead',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aLQtm6eoBgUhsbHvgAJPF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PnVFIKBAfThVW4eb16GQn'},
#      'href': 'https://api.spotify.com/v1/albums/5PnVFIKBAfThVW4eb16GQn',
#      'id': '5PnVFIKBAfThVW4eb16GQn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734bed57d8c8dbc65f957ceea0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024bed57d8c8dbc65f957ceea0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514bed57d8c8dbc65f957ceea0',
#        'width': 64}],
#      'name': 'Incognito: Cog Covers, Vol. 1',
#      'release_date': '2020-12-04',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5PnVFIKBAfThVW4eb16GQn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aLQtm6eoBgUhsbHvgAJPF'},
#       'href': 'https://api.spotify.com/v1/artists/5aLQtm6eoBgUhsbHvgAJPF',
#       'id': '5aLQtm6eoBgUhsbHvgAJPF',
#       'name': 'The Cog is Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aLQtm6eoBgUhsbHvgAJPF'}],
#     'disc_number': 1,
#     'duration_ms': 194061,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZGWW1962098'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tRLfrfy692qlbT2cECgQS'},
#     'href': 'https://api.spotify.com/v1/tracks/6tRLfrfy692qlbT2cECgQS',
#     'id': '6tRLfrfy692qlbT2cECgQS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e55a06fb60bcecb332c9bad80f6d24c87153eb3b?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6tRLfrfy692qlbT2cECgQS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4cyL40CdreXwIw00c8RX'},
#        'href': 'https://api.spotify.com/v1/artists/7n4cyL40CdreXwIw00c8RX',
#        'id': '7n4cyL40CdreXwIw00c8RX',
#        'name': 'Ben Schuller',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n4cyL40CdreXwIw00c8RX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/40e1LUjt5mFUmSL1mNp0Av'},
#      'href': 'https://api.spotify.com/v1/albums/40e1LUjt5mFUmSL1mNp0Av',
#      'id': '40e1LUjt5mFUmSL1mNp0Av',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e1c9c789963afd53b5f70b6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e1c9c789963afd53b5f70b6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e1c9c789963afd53b5f70b6',
#        'width': 64}],
#      'name': 'Cover Sessions',
#      'release_date': '2017-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:40e1LUjt5mFUmSL1mNp0Av'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4cyL40CdreXwIw00c8RX'},
#       'href': 'https://api.spotify.com/v1/artists/7n4cyL40CdreXwIw00c8RX',
#       'id': '7n4cyL40CdreXwIw00c8RX',
#       'name': 'Ben Schuller',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n4cyL40CdreXwIw00c8RX'}],
#     'disc_number': 1,
#     'duration_ms': 239480,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4DW1623700'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4G1FKyLsB8xcTdVEXgwcix'},
#     'href': 'https://api.spotify.com/v1/tracks/4G1FKyLsB8xcTdVEXgwcix',
#     'id': '4G1FKyLsB8xcTdVEXgwcix',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Once I Was 7 Years Old',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/79b7c4a2dda8a47e8b2e2966bbde8c5298ab9397?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4G1FKyLsB8xcTdVEXgwcix'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfmnXYxa9yh0RkUBPjSwZ'},
#        'href': 'https://api.spotify.com/v1/artists/2kfmnXYxa9yh0RkUBPjSwZ',
#        'id': '2kfmnXYxa9yh0RkUBPjSwZ',
#        'name': 'Dan Berk',
#        'type': 'artist',
#        'uri': 'spotify:artist:2kfmnXYxa9yh0RkUBPjSwZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5KFXAufcOTSKibMfLnmyYC'},
#        'href': 'https://api.spotify.com/v1/artists/5KFXAufcOTSKibMfLnmyYC',
#        'id': '5KFXAufcOTSKibMfLnmyYC',
#        'name': 'Lance Allen',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KFXAufcOTSKibMfLnmyYC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PuPKfAW5lJKLmpZisa9ob'},
#      'href': 'https://api.spotify.com/v1/albums/4PuPKfAW5lJKLmpZisa9ob',
#      'id': '4PuPKfAW5lJKLmpZisa9ob',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d75a5742b9fc4532b8275e6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d75a5742b9fc4532b8275e6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d75a5742b9fc4532b8275e6',
#        'width': 64}],
#      'name': 'bad guy (Acoustic)',
#      'release_date': '2020-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4PuPKfAW5lJKLmpZisa9ob'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfmnXYxa9yh0RkUBPjSwZ'},
#       'href': 'https://api.spotify.com/v1/artists/2kfmnXYxa9yh0RkUBPjSwZ',
#       'id': '2kfmnXYxa9yh0RkUBPjSwZ',
#       'name': 'Dan Berk',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kfmnXYxa9yh0RkUBPjSwZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5KFXAufcOTSKibMfLnmyYC'},
#       'href': 'https://api.spotify.com/v1/artists/5KFXAufcOTSKibMfLnmyYC',
#       'id': '5KFXAufcOTSKibMfLnmyYC',
#       'name': 'Lance Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KFXAufcOTSKibMfLnmyYC'}],
#     'disc_number': 1,
#     'duration_ms': 183240,
#     'explicit': False,
#     'external_ids': {'isrc': 'UK42F2000051'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1zQ2PdP4hpA9gaWiaMMoJy'},
#     'href': 'https://api.spotify.com/v1/tracks/1zQ2PdP4hpA9gaWiaMMoJy',
#     'id': '1zQ2PdP4hpA9gaWiaMMoJy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy - Acoustic',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/263775a5f3e947c534d6a5095e7de5acf6de852b?cid=d4726b15e5b34b0fa3c825aaea90d658',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1zQ2PdP4hpA9gaWiaMMoJy'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Bad+Guy&type=track&market=GB&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 10062}}

# %%
song["tracks"]["items"][2]
# Out:
# {'album': {'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6AugscLeajzm3pnamBGdOz'},
#   'href': 'https://api.spotify.com/v1/albums/6AugscLeajzm3pnamBGdOz',
#   'id': '6AugscLeajzm3pnamBGdOz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737fffa0a1302a6cadc5ca32eb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027fffa0a1302a6cadc5ca32eb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517fffa0a1302a6cadc5ca32eb',
#     'width': 64}],
#   'name': '4th of July Pop Edition',
#   'release_date': '2022-06-23',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:6AugscLeajzm3pnamBGdOz'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#    'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#    'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#    'name': 'Billie Eilish',
#    'type': 'artist',
#    'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#  'disc_number': 1,
#  'duration_ms': 194087,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUM71900764'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2s5krQtudVMNZetgxGHNBG'},
#  'href': 'https://api.spotify.com/v1/tracks/2s5krQtudVMNZetgxGHNBG',
#  'id': '2s5krQtudVMNZetgxGHNBG',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'bad guy',
#  'popularity': 6,
#  'preview_url': None,
#  'track_number': 27,
#  'type': 'track',
#  'uri': 'spotify:track:2s5krQtudVMNZetgxGHNBG'}

# %%
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'

# %% [markdown]
# # Understanding the json

# %% [markdown]
# Understanding the hierachy of a JSON can make you mad. Therefore you can cosider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# So, copy the json output from the previous query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.

# %% [markdown]
# Let's get used to the json at hand.

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=1
# The song's info is contained in:  [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'}, 'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4', 'id': '1rfORa9iYmocEsnnZGMVC4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec', 'width': 64}], 'name': 'Just Lose It', 'release_date': '2004-01-01', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'disc_number': 1, 'duration_ms': 322226, 'explicit': True, 'external_ids': {'isrc': 'USIR10211559'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'}, 'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1', 'id': '1v7L65Lzy0j0vdpRjJewt1', 'is_local': False, 'is_playable': True, 'name': 'Lose Yourself - From "8 Mile" Soundtrack', 'popularity': 77, 'preview_url': None, 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}]
# The limit of the query we've made is:  1
# The next page if any:  https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=1&limit=1
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  4233

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print("****************\n")
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("****************\n")
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
# Out:
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'}, 'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4', 'id': '1rfORa9iYmocEsnnZGMVC4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec', 'width': 64}], 'name': 'Just Lose It', 'release_date': '2004-01-01', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'}
# ****************
#
# ['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# ****************
#
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}]
# ****************
#
# The album ID is:  1rfORa9iYmocEsnnZGMVC4
# ****************
#
# Just Lose It

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'

# %% [markdown]
# # Getting the Audio feature of a song

# %%
results["tracks"]["items"][0]["id"]
# Out:
# '1v7L65Lzy0j0vdpRjJewt1'

# %%
sp.audio_features(results["tracks"]["items"][0]["id"] )
# Out:
# [{'danceability': 0.686,
#   'energy': 0.735,
#   'key': 2,
#   'loudness': -4.616,
#   'mode': 1,
#   'speechiness': 0.264,
#   'acousticness': 0.00921,
#   'instrumentalness': 0.00066,
#   'liveness': 0.342,
#   'valence': 0.0596,
#   'tempo': 171.355,
#   'type': 'audio_features',
#   'id': '1v7L65Lzy0j0vdpRjJewt1',
#   'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1',
#   'track_href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1v7L65Lzy0j0vdpRjJewt1',
#   'duration_ms': 322227,
#   'time_signature': 4}]

# %%
## example of bethoven song
sp.audio_features("1Y25uib0Cu5kYTtNuRqyRU")
# Out:
# [{'danceability': 0.403,
#   'energy': 0.171,
#   'key': 5,
#   'loudness': -21.561,
#   'mode': 0,
#   'speechiness': 0.0359,
#   'acousticness': 0.991,
#   'instrumentalness': 0.906,
#   'liveness': 0.0809,
#   'valence': 0.14,
#   'tempo': 98.886,
#   'type': 'audio_features',
#   'id': '1Y25uib0Cu5kYTtNuRqyRU',
#   'uri': 'spotify:track:1Y25uib0Cu5kYTtNuRqyRU',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Y25uib0Cu5kYTtNuRqyRU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y25uib0Cu5kYTtNuRqyRU',
#   'duration_ms': 271587,
#   'time_signature': 4}]

# %% [markdown]
# ## building Data frame of audio features

# %%
sp.audio_features(song["tracks"]["items"][0]["uri"])
# Out:
# [{'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2Fxmhks0bxGSBdJ92vM42m',
#   'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#   'duration_ms': 194088,
#   'time_signature': 4}]

# %%
list_of_songs
# Out:
# [{'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2Fxmhks0bxGSBdJ92vM42m',
#   'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#   'duration_ms': 194088,
#   'time_signature': 4},
#  {'danceability': 0.67,
#   'energy': 0.453,
#   'key': 0,
#   'loudness': -11.265,
#   'mode': 1,
#   'speechiness': 0.295,
#   'acousticness': 0.252,
#   'instrumentalness': 0.33,
#   'liveness': 0.117,
#   'valence': 0.68,
#   'tempo': 135.055,
#   'type': 'audio_features',
#   'id': '3yNZ5r3LKfdmjoS3gkhUCT',
#   'uri': 'spotify:track:3yNZ5r3LKfdmjoS3gkhUCT',
#   'track_href': 'https://api.spotify.com/v1/tracks/3yNZ5r3LKfdmjoS3gkhUCT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3yNZ5r3LKfdmjoS3gkhUCT',
#   'duration_ms': 194840,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '2s5krQtudVMNZetgxGHNBG',
#   'uri': 'spotify:track:2s5krQtudVMNZetgxGHNBG',
#   'track_href': 'https://api.spotify.com/v1/tracks/2s5krQtudVMNZetgxGHNBG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2s5krQtudVMNZetgxGHNBG',
#   'duration_ms': 194088,
#   'time_signature': 4},
#  {'danceability': 0.811,
#   'energy': 0.748,
#   'key': 1,
#   'loudness': -10.298,
#   'mode': 1,
#   'speechiness': 0.0682,
#   'acousticness': 0.553,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.883,
#   'tempo': 108.816,
#   'type': 'audio_features',
#   'id': '3gZoHbFt5W3HltDGcnbDrD',
#   'uri': 'spotify:track:3gZoHbFt5W3HltDGcnbDrD',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gZoHbFt5W3HltDGcnbDrD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gZoHbFt5W3HltDGcnbDrD',
#   'duration_ms': 136133,
#   'time_signature': 4},
#  {'danceability': 0.612,
#   'energy': 0.797,
#   'key': 1,
#   'loudness': -3.648,
#   'mode': 1,
#   'speechiness': 0.448,
#   'acousticness': 0.064,
#   'instrumentalness': 0,
#   'liveness': 0.257,
#   'valence': 0.358,
#   'tempo': 81.086,
#   'type': 'audio_features',
#   'id': '3IaAYtmN8T0YIYVqnxNnVz',
#   'uri': 'spotify:track:3IaAYtmN8T0YIYVqnxNnVz',
#   'track_href': 'https://api.spotify.com/v1/tracks/3IaAYtmN8T0YIYVqnxNnVz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3IaAYtmN8T0YIYVqnxNnVz',
#   'duration_ms': 434077,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.425,
#   'key': 7,
#   'loudness': -10.965,
#   'mode': 1,
#   'speechiness': 0.375,
#   'acousticness': 0.328,
#   'instrumentalness': 0.13,
#   'liveness': 0.1,
#   'valence': 0.562,
#   'tempo': 135.128,
#   'type': 'audio_features',
#   'id': '6x3jFFNMbYIz8hUTIWS1Eo',
#   'uri': 'spotify:track:6x3jFFNMbYIz8hUTIWS1Eo',
#   'track_href': 'https://api.spotify.com/v1/tracks/6x3jFFNMbYIz8hUTIWS1Eo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6x3jFFNMbYIz8hUTIWS1Eo',
#   'duration_ms': 194088,
#   'time_signature': 4},
#  {'danceability': 0.698,
#   'energy': 0.323,
#   'key': 5,
#   'loudness': -9.98,
#   'mode': 1,
#   'speechiness': 0.178,
#   'acousticness': 0.914,
#   'instrumentalness': 0.037,
#   'liveness': 0.0991,
#   'valence': 0.67,
#   'tempo': 135.069,
#   'type': 'audio_features',
#   'id': '1qOsHMitiWT4Zhx9ICzmjW',
#   'uri': 'spotify:track:1qOsHMitiWT4Zhx9ICzmjW',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qOsHMitiWT4Zhx9ICzmjW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qOsHMitiWT4Zhx9ICzmjW',
#   'duration_ms': 193227,
#   'time_signature': 4},
#  {'danceability': 0.582,
#   'energy': 0.829,
#   'key': 2,
#   'loudness': -5.688,
#   'mode': 1,
#   'speechiness': 0.0465,
#   'acousticness': 0.000517,
#   'instrumentalness': 0,
#   'liveness': 0.266,
#   'valence': 0.867,
#   'tempo': 130.969,
#   'type': 'audio_features',
#   'id': '0KqyBk4aVT88TEqBIC8mAP',
#   'uri': 'spotify:track:0KqyBk4aVT88TEqBIC8mAP',
#   'track_href': 'https://api.spotify.com/v1/tracks/0KqyBk4aVT88TEqBIC8mAP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KqyBk4aVT88TEqBIC8mAP',
#   'duration_ms': 197800,
#   'time_signature': 4},
#  {'danceability': 0.563,
#   'energy': 0.814,
#   'key': 7,
#   'loudness': -4.219,
#   'mode': 0,
#   'speechiness': 0.0558,
#   'acousticness': 0.00983,
#   'instrumentalness': 0.0437,
#   'liveness': 0.0732,
#   'valence': 0.796,
#   'tempo': 140.615,
#   'type': 'audio_features',
#   'id': '0iM1Ioz4N4p7MU1DKyqsov',
#   'uri': 'spotify:track:0iM1Ioz4N4p7MU1DKyqsov',
#   'track_href': 'https://api.spotify.com/v1/tracks/0iM1Ioz4N4p7MU1DKyqsov',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iM1Ioz4N4p7MU1DKyqsov',
#   'duration_ms': 157832,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.779,
#   'key': 2,
#   'loudness': -5.975,
#   'mode': 1,
#   'speechiness': 0.257,
#   'acousticness': 0.196,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.704,
#   'tempo': 142.175,
#   'type': 'audio_features',
#   'id': '1VQKKey9XgeYOm6rd1Aje8',
#   'uri': 'spotify:track:1VQKKey9XgeYOm6rd1Aje8',
#   'track_href': 'https://api.spotify.com/v1/tracks/1VQKKey9XgeYOm6rd1Aje8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1VQKKey9XgeYOm6rd1Aje8',
#   'duration_ms': 221560,
#   'time_signature': 4},
#  {'danceability': 0.474,
#   'energy': 0.948,
#   'key': 3,
#   'loudness': -2.592,
#   'mode': 1,
#   'speechiness': 0.122,
#   'acousticness': 0.0223,
#   'instrumentalness': 0,
#   'liveness': 0.43,
#   'valence': 0.611,
#   'tempo': 146.46,
#   'type': 'audio_features',
#   'id': '78ML3F5Lz3KiNkpnFAaR3q',
#   'uri': 'spotify:track:78ML3F5Lz3KiNkpnFAaR3q',
#   'track_href': 'https://api.spotify.com/v1/tracks/78ML3F5Lz3KiNkpnFAaR3q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78ML3F5Lz3KiNkpnFAaR3q',
#   'duration_ms': 195373,
#   'time_signature': 4},
#  {'danceability': 0.829,
#   'energy': 0.327,
#   'key': 0,
#   'loudness': -11.346,
#   'mode': 0,
#   'speechiness': 0.104,
#   'acousticness': 0.0402,
#   'instrumentalness': 0.545,
#   'liveness': 0.105,
#   'valence': 0.723,
#   'tempo': 135.984,
#   'type': 'audio_features',
#   'id': '4I1ypegnI8R0HlsAF5rZYn',
#   'uri': 'spotify:track:4I1ypegnI8R0HlsAF5rZYn',
#   'track_href': 'https://api.spotify.com/v1/tracks/4I1ypegnI8R0HlsAF5rZYn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4I1ypegnI8R0HlsAF5rZYn',
#   'duration_ms': 135882,
#   'time_signature': 4},
#  {'danceability': 0.801,
#   'energy': 0.685,
#   'key': 0,
#   'loudness': -5.515,
#   'mode': 0,
#   'speechiness': 0.0656,
#   'acousticness': 0.42,
#   'instrumentalness': 0,
#   'liveness': 0.1,
#   'valence': 0.777,
#   'tempo': 108.024,
#   'type': 'audio_features',
#   'id': '6O0yvfx7qeE16s0UyhxOVT',
#   'uri': 'spotify:track:6O0yvfx7qeE16s0UyhxOVT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6O0yvfx7qeE16s0UyhxOVT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6O0yvfx7qeE16s0UyhxOVT',
#   'duration_ms': 152970,
#   'time_signature': 4},
#  {'danceability': 0.367,
#   'energy': 0.111,
#   'key': 4,
#   'loudness': -14.084,
#   'mode': 1,
#   'speechiness': 0.0972,
#   'acousticness': 0.978,
#   'instrumentalness': 3.97e-05,
#   'liveness': 0.0897,
#   'valence': 0.198,
#   'tempo': 82.642,
#   'type': 'audio_features',
#   'id': '43zdsphuZLzwA9k4DJhU0I',
#   'uri': 'spotify:track:43zdsphuZLzwA9k4DJhU0I',
#   'track_href': 'https://api.spotify.com/v1/tracks/43zdsphuZLzwA9k4DJhU0I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43zdsphuZLzwA9k4DJhU0I',
#   'duration_ms': 196077,
#   'time_signature': 4},
#  {'danceability': 0.698,
#   'energy': 0.429,
#   'key': 0,
#   'loudness': -9.246,
#   'mode': 0,
#   'speechiness': 0.0416,
#   'acousticness': 0.148,
#   'instrumentalness': 0.691,
#   'liveness': 0.101,
#   'valence': 0.54,
#   'tempo': 134.946,
#   'type': 'audio_features',
#   'id': '2FH0jT9o0mz71s7AtMkAa4',
#   'uri': 'spotify:track:2FH0jT9o0mz71s7AtMkAa4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2FH0jT9o0mz71s7AtMkAa4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2FH0jT9o0mz71s7AtMkAa4',
#   'duration_ms': 191975,
#   'time_signature': 4},
#  {'danceability': 0.757,
#   'energy': 0.598,
#   'key': 11,
#   'loudness': -7.777,
#   'mode': 1,
#   'speechiness': 0.058,
#   'acousticness': 0.0904,
#   'instrumentalness': 0.551,
#   'liveness': 0.15,
#   'valence': 0.18,
#   'tempo': 124.951,
#   'type': 'audio_features',
#   'id': '4t2OeILB07eMGTXSUbMPEu',
#   'uri': 'spotify:track:4t2OeILB07eMGTXSUbMPEu',
#   'track_href': 'https://api.spotify.com/v1/tracks/4t2OeILB07eMGTXSUbMPEu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4t2OeILB07eMGTXSUbMPEu',
#   'duration_ms': 210233,
#   'time_signature': 4},
#  {'danceability': 0.722,
#   'energy': 0.747,
#   'key': 2,
#   'loudness': -3.483,
#   'mode': 1,
#   'speechiness': 0.0509,
#   'acousticness': 0.0249,
#   'instrumentalness': 4.5e-06,
#   'liveness': 0.197,
#   'valence': 0.343,
#   'tempo': 95.866,
#   'type': 'audio_features',
#   'id': '4KVVy0GeXO03ni8Cv4SWk8',
#   'uri': 'spotify:track:4KVVy0GeXO03ni8Cv4SWk8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KVVy0GeXO03ni8Cv4SWk8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KVVy0GeXO03ni8Cv4SWk8',
#   'duration_ms': 279133,
#   'time_signature': 4},
#  {'danceability': 0.842,
#   'energy': 0.623,
#   'key': 7,
#   'loudness': -5.678,
#   'mode': 0,
#   'speechiness': 0.0869,
#   'acousticness': 0.0545,
#   'instrumentalness': 7.88e-05,
#   'liveness': 0.0434,
#   'valence': 0.845,
#   'tempo': 136.0,
#   'type': 'audio_features',
#   'id': '0OnmY8BGZsxzEhyZJ43ooZ',
#   'uri': 'spotify:track:0OnmY8BGZsxzEhyZJ43ooZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0OnmY8BGZsxzEhyZJ43ooZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0OnmY8BGZsxzEhyZJ43ooZ',
#   'duration_ms': 240000,
#   'time_signature': 4},
#  {'danceability': 0.843,
#   'energy': 0.658,
#   'key': 11,
#   'loudness': -7.072,
#   'mode': 0,
#   'speechiness': 0.0678,
#   'acousticness': 0.00456,
#   'instrumentalness': 0.73,
#   'liveness': 0.0673,
#   'valence': 0.562,
#   'tempo': 131.01,
#   'type': 'audio_features',
#   'id': '5v7OrTvBQNhXQwVzi3oXpb',
#   'uri': 'spotify:track:5v7OrTvBQNhXQwVzi3oXpb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5v7OrTvBQNhXQwVzi3oXpb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5v7OrTvBQNhXQwVzi3oXpb',
#   'duration_ms': 281253,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.516,
#   'key': 10,
#   'loudness': -7.748,
#   'mode': 0,
#   'speechiness': 0.0426,
#   'acousticness': 0.0622,
#   'instrumentalness': 6.37e-06,
#   'liveness': 0.12,
#   'valence': 0.342,
#   'tempo': 91.975,
#   'type': 'audio_features',
#   'id': '0iXlgib8Sp7tU0tRdoUJYg',
#   'uri': 'spotify:track:0iXlgib8Sp7tU0tRdoUJYg',
#   'track_href': 'https://api.spotify.com/v1/tracks/0iXlgib8Sp7tU0tRdoUJYg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iXlgib8Sp7tU0tRdoUJYg',
#   'duration_ms': 150811,
#   'time_signature': 4},
#  {'danceability': 0.695,
#   'energy': 0.779,
#   'key': 2,
#   'loudness': -5.975,
#   'mode': 1,
#   'speechiness': 0.257,
#   'acousticness': 0.196,
#   'instrumentalness': 0,
#   'liveness': 0.11,
#   'valence': 0.704,
#   'tempo': 142.175,
#   'type': 'audio_features',
#   'id': '7vLzU22xRA0pz9A8Ch1NNl',
#   'uri': 'spotify:track:7vLzU22xRA0pz9A8Ch1NNl',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vLzU22xRA0pz9A8Ch1NNl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vLzU22xRA0pz9A8Ch1NNl',
#   'duration_ms': 221560,
#   'time_signature': 4},
#  {'danceability': 0.643,
#   'energy': 0.786,
#   'key': 0,
#   'loudness': -3.976,
#   'mode': 1,
#   'speechiness': 0.0302,
#   'acousticness': 0.00255,
#   'instrumentalness': 0,
#   'liveness': 0.0462,
#   'valence': 0.52,
#   'tempo': 107.005,
#   'type': 'audio_features',
#   'id': '760frpppJAxqsVBuiOt1yL',
#   'uri': 'spotify:track:760frpppJAxqsVBuiOt1yL',
#   'track_href': 'https://api.spotify.com/v1/tracks/760frpppJAxqsVBuiOt1yL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/760frpppJAxqsVBuiOt1yL',
#   'duration_ms': 189227,
#   'time_signature': 4},
#  {'danceability': 0.444,
#   'energy': 0.309,
#   'key': 8,
#   'loudness': -10.956,
#   'mode': 1,
#   'speechiness': 0.062,
#   'acousticness': 0.795,
#   'instrumentalness': 0.132,
#   'liveness': 0.352,
#   'valence': 0.0875,
#   'tempo': 104.745,
#   'type': 'audio_features',
#   'id': '2ygvZOXrIeVL4xZmAWJT2C',
#   'uri': 'spotify:track:2ygvZOXrIeVL4xZmAWJT2C',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ygvZOXrIeVL4xZmAWJT2C',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ygvZOXrIeVL4xZmAWJT2C',
#   'duration_ms': 208155,
#   'time_signature': 4},
#  {'danceability': 0.847,
#   'energy': 0.491,
#   'key': 4,
#   'loudness': -8.025,
#   'mode': 0,
#   'speechiness': 0.436,
#   'acousticness': 0.386,
#   'instrumentalness': 6.71e-05,
#   'liveness': 0.119,
#   'valence': 0.623,
#   'tempo': 139.947,
#   'type': 'audio_features',
#   'id': '7emJRAhUHhLtBtvzjDpjMC',
#   'uri': 'spotify:track:7emJRAhUHhLtBtvzjDpjMC',
#   'track_href': 'https://api.spotify.com/v1/tracks/7emJRAhUHhLtBtvzjDpjMC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7emJRAhUHhLtBtvzjDpjMC',
#   'duration_ms': 192400,
#   'time_signature': 4},
#  {'danceability': 0.575,
#   'energy': 0.843,
#   'key': 2,
#   'loudness': -4.402,
#   'mode': 1,
#   'speechiness': 0.0518,
#   'acousticness': 0.000743,
#   'instrumentalness': 0,
#   'liveness': 0.315,
#   'valence': 0.843,
#   'tempo': 130.982,
#   'type': 'audio_features',
#   'id': '5R4UtkoueIomI2z3Ei8B38',
#   'uri': 'spotify:track:5R4UtkoueIomI2z3Ei8B38',
#   'track_href': 'https://api.spotify.com/v1/tracks/5R4UtkoueIomI2z3Ei8B38',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5R4UtkoueIomI2z3Ei8B38',
#   'duration_ms': 197613,
#   'time_signature': 4},
#  {'danceability': 0.807,
#   'energy': 0.893,
#   'key': 11,
#   'loudness': -3.745,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'acousticness': 0.0451,
#   'instrumentalness': 2.79e-05,
#   'liveness': 0.366,
#   'valence': 0.537,
#   'tempo': 126.011,
#   'type': 'audio_features',
#   'id': '3rmo8F54jFF8OgYsqTxm5d',
#   'uri': 'spotify:track:3rmo8F54jFF8OgYsqTxm5d',
#   'track_href': 'https://api.spotify.com/v1/tracks/3rmo8F54jFF8OgYsqTxm5d',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rmo8F54jFF8OgYsqTxm5d',
#   'duration_ms': 230747,
#   'time_signature': 4},
#  {'danceability': 0.824,
#   'energy': 0.77,
#   'key': 5,
#   'loudness': -7.281,
#   'mode': 0,
#   'speechiness': 0.177,
#   'acousticness': 0.142,
#   'instrumentalness': 0,
#   'liveness': 0.112,
#   'valence': 0.327,
#   'tempo': 119.887,
#   'type': 'audio_features',
#   'id': '408if5LwFlG8lsyYkSGjJn',
#   'uri': 'spotify:track:408if5LwFlG8lsyYkSGjJn',
#   'track_href': 'https://api.spotify.com/v1/tracks/408if5LwFlG8lsyYkSGjJn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/408if5LwFlG8lsyYkSGjJn',
#   'duration_ms': 228500,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.71,
#   'key': 7,
#   'loudness': -3.976,
#   'mode': 1,
#   'speechiness': 0.0448,
#   'acousticness': 0.0842,
#   'instrumentalness': 0,
#   'liveness': 0.346,
#   'valence': 0.544,
#   'tempo': 114.946,
#   'type': 'audio_features',
#   'id': '5XYNCCkYoFLegWZcQU9ecn',
#   'uri': 'spotify:track:5XYNCCkYoFLegWZcQU9ecn',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XYNCCkYoFLegWZcQU9ecn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XYNCCkYoFLegWZcQU9ecn',
#   'duration_ms': 221253,
#   'time_signature': 4},
#  {'danceability': 0.656,
#   'energy': 0.465,
#   'key': 0,
#   'loudness': -12.132,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.368,
#   'instrumentalness': 0,
#   'liveness': 0.155,
#   'valence': 0.778,
#   'tempo': 96.93,
#   'type': 'audio_features',
#   'id': '4FoRp17jtblWkNCfPe9QEU',
#   'uri': 'spotify:track:4FoRp17jtblWkNCfPe9QEU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4FoRp17jtblWkNCfPe9QEU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4FoRp17jtblWkNCfPe9QEU',
#   'duration_ms': 144170,
#   'time_signature': 4},
#  {'danceability': 0.83,
#   'energy': 0.405,
#   'key': 1,
#   'loudness': -8.484,
#   'mode': 1,
#   'speechiness': 0.411,
#   'acousticness': 0.0158,
#   'instrumentalness': 8.61e-06,
#   'liveness': 0.241,
#   'valence': 0.188,
#   'tempo': 147.07,
#   'type': 'audio_features',
#   'id': '5TvdhNXoHbeGeWtjCYhFuy',
#   'uri': 'spotify:track:5TvdhNXoHbeGeWtjCYhFuy',
#   'track_href': 'https://api.spotify.com/v1/tracks/5TvdhNXoHbeGeWtjCYhFuy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5TvdhNXoHbeGeWtjCYhFuy',
#   'duration_ms': 169493,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.71,
#   'key': 7,
#   'loudness': -3.976,
#   'mode': 1,
#   'speechiness': 0.0448,
#   'acousticness': 0.0841,
#   'instrumentalness': 0,
#   'liveness': 0.341,
#   'valence': 0.544,
#   'tempo': 114.949,
#   'type': 'audio_features',
#   'id': '4g077yizjVdMB5HFl3rJRo',
#   'uri': 'spotify:track:4g077yizjVdMB5HFl3rJRo',
#   'track_href': 'https://api.spotify.com/v1/tracks/4g077yizjVdMB5HFl3rJRo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4g077yizjVdMB5HFl3rJRo',
#   'duration_ms': 221253,
#   'time_signature': 4},
#  {'danceability': 0.781,
#   'energy': 0.722,
#   'key': 7,
#   'loudness': -8.376,
#   'mode': 1,
#   'speechiness': 0.0667,
#   'acousticness': 0.236,
#   'instrumentalness': 0.000398,
#   'liveness': 0.077,
#   'valence': 0.533,
#   'tempo': 87.858,
#   'type': 'audio_features',
#   'id': '0qeKzbUsW0V4ZWRJrHNiD3',
#   'uri': 'spotify:track:0qeKzbUsW0V4ZWRJrHNiD3',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qeKzbUsW0V4ZWRJrHNiD3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qeKzbUsW0V4ZWRJrHNiD3',
#   'duration_ms': 229375,
#   'time_signature': 4},
#  {'danceability': 0.736,
#   'energy': 0.468,
#   'key': 3,
#   'loudness': -8.572,
#   'mode': 0,
#   'speechiness': 0.195,
#   'acousticness': 0.11,
#   'instrumentalness': 0,
#   'liveness': 0.107,
#   'valence': 0.417,
#   'tempo': 80.505,
#   'type': 'audio_features',
#   'id': '5w4enr0FN8ZTwxmfnACz2f',
#   'uri': 'spotify:track:5w4enr0FN8ZTwxmfnACz2f',
#   'track_href': 'https://api.spotify.com/v1/tracks/5w4enr0FN8ZTwxmfnACz2f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5w4enr0FN8ZTwxmfnACz2f',
#   'duration_ms': 146773,
#   'time_signature': 4},
#  {'danceability': 0.526,
#   'energy': 0.639,
#   'key': 7,
#   'loudness': -6.14,
#   'mode': 1,
#   'speechiness': 0.104,
#   'acousticness': 0.0106,
#   'instrumentalness': 2.2e-05,
#   'liveness': 0.12,
#   'valence': 0.717,
#   'tempo': 135.012,
#   'type': 'audio_features',
#   'id': '3UCQwTclMnDYtS0uVjNTGO',
#   'uri': 'spotify:track:3UCQwTclMnDYtS0uVjNTGO',
#   'track_href': 'https://api.spotify.com/v1/tracks/3UCQwTclMnDYtS0uVjNTGO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UCQwTclMnDYtS0uVjNTGO',
#   'duration_ms': 191806,
#   'time_signature': 4},
#  {'danceability': 0.8,
#   'energy': 0.948,
#   'key': 9,
#   'loudness': -2.34,
#   'mode': 0,
#   'speechiness': 0.192,
#   'acousticness': 0.00321,
#   'instrumentalness': 0,
#   'liveness': 0.08,
#   'valence': 0.924,
#   'tempo': 104.971,
#   'type': 'audio_features',
#   'id': '6ST6x5sSLYArqrh30p3KBs',
#   'uri': 'spotify:track:6ST6x5sSLYArqrh30p3KBs',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ST6x5sSLYArqrh30p3KBs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ST6x5sSLYArqrh30p3KBs',
#   'duration_ms': 188817,
#   'time_signature': 4},
#  {'danceability': 0.945,
#   'energy': 0.858,
#   'key': 7,
#   'loudness': -10.271,
#   'mode': 1,
#   'speechiness': 0.404,
#   'acousticness': 0.0521,
#   'instrumentalness': 0.143,
#   'liveness': 0.0494,
#   'valence': 0.632,
#   'tempo': 134.992,
#   'type': 'audio_features',
#   'id': '2uqN75iYEOcDQEtpCg65Ms',
#   'uri': 'spotify:track:2uqN75iYEOcDQEtpCg65Ms',
#   'track_href': 'https://api.spotify.com/v1/tracks/2uqN75iYEOcDQEtpCg65Ms',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2uqN75iYEOcDQEtpCg65Ms',
#   'duration_ms': 152940,
#   'time_signature': 4},
#  {'danceability': 0.785,
#   'energy': 0.671,
#   'key': 11,
#   'loudness': -7.108,
#   'mode': 0,
#   'speechiness': 0.0505,
#   'acousticness': 0.448,
#   'instrumentalness': 1.81e-05,
#   'liveness': 0.225,
#   'valence': 0.588,
#   'tempo': 124.899,
#   'type': 'audio_features',
#   'id': '1O8BgvuH9SMVddb3MQINwp',
#   'uri': 'spotify:track:1O8BgvuH9SMVddb3MQINwp',
#   'track_href': 'https://api.spotify.com/v1/tracks/1O8BgvuH9SMVddb3MQINwp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1O8BgvuH9SMVddb3MQINwp',
#   'duration_ms': 159360,
#   'time_signature': 4},
#  {'danceability': 0.612,
#   'energy': 0.521,
#   'key': 10,
#   'loudness': -7.137,
#   'mode': 1,
#   'speechiness': 0.0331,
#   'acousticness': 0.519,
#   'instrumentalness': 0,
#   'liveness': 0.166,
#   'valence': 0.368,
#   'tempo': 92.988,
#   'type': 'audio_features',
#   'id': '6BZuf8iLTI18rN8L8WarzL',
#   'uri': 'spotify:track:6BZuf8iLTI18rN8L8WarzL',
#   'track_href': 'https://api.spotify.com/v1/tracks/6BZuf8iLTI18rN8L8WarzL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6BZuf8iLTI18rN8L8WarzL',
#   'duration_ms': 250000,
#   'time_signature': 4},
#  {'danceability': 0.511,
#   'energy': 0.363,
#   'key': 4,
#   'loudness': -7.65,
#   'mode': 0,
#   'speechiness': 0.041,
#   'acousticness': 0.816,
#   'instrumentalness': 0.0317,
#   'liveness': 0.084,
#   'valence': 0.169,
#   'tempo': 144.892,
#   'type': 'audio_features',
#   'id': '7hDVYcQq6MxkdJGweuCtl9',
#   'uri': 'spotify:track:7hDVYcQq6MxkdJGweuCtl9',
#   'track_href': 'https://api.spotify.com/v1/tracks/7hDVYcQq6MxkdJGweuCtl9',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hDVYcQq6MxkdJGweuCtl9',
#   'duration_ms': 200379,
#   'time_signature': 4},
#  {'danceability': 0.632,
#   'energy': 0.284,
#   'key': 9,
#   'loudness': -14.025,
#   'mode': 0,
#   'speechiness': 0.0801,
#   'acousticness': 0.932,
#   'instrumentalness': 0.000476,
#   'liveness': 0.233,
#   'valence': 0.208,
#   'tempo': 129.642,
#   'type': 'audio_features',
#   'id': '042Sl6Mn83JHyLEqdK7uI0',
#   'uri': 'spotify:track:042Sl6Mn83JHyLEqdK7uI0',
#   'track_href': 'https://api.spotify.com/v1/tracks/042Sl6Mn83JHyLEqdK7uI0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/042Sl6Mn83JHyLEqdK7uI0',
#   'duration_ms': 245897,
#   'time_signature': 4},
#  {'danceability': 0.7,
#   'energy': 0.693,
#   'key': 5,
#   'loudness': -5.092,
#   'mode': 1,
#   'speechiness': 0.201,
#   'acousticness': 0.129,
#   'instrumentalness': 0,
#   'liveness': 0.232,
#   'valence': 0.475,
#   'tempo': 146.109,
#   'type': 'audio_features',
#   'id': '4727RsuKMuY09HnC1ZD6yt',
#   'uri': 'spotify:track:4727RsuKMuY09HnC1ZD6yt',
#   'track_href': 'https://api.spotify.com/v1/tracks/4727RsuKMuY09HnC1ZD6yt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4727RsuKMuY09HnC1ZD6yt',
#   'duration_ms': 138082,
#   'time_signature': 4},
#  {'danceability': 0.585,
#   'energy': 0.717,
#   'key': 2,
#   'loudness': -5.055,
#   'mode': 1,
#   'speechiness': 0.0426,
#   'acousticness': 0.0097,
#   'instrumentalness': 0.0313,
#   'liveness': 0.0952,
#   'valence': 0.701,
#   'tempo': 174.019,
#   'type': 'audio_features',
#   'id': '5bnPew0sFrsFDUrkvVezRS',
#   'uri': 'spotify:track:5bnPew0sFrsFDUrkvVezRS',
#   'track_href': 'https://api.spotify.com/v1/tracks/5bnPew0sFrsFDUrkvVezRS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bnPew0sFrsFDUrkvVezRS',
#   'duration_ms': 181453,
#   'time_signature': 4},
#  {'danceability': 0.905,
#   'energy': 0.389,
#   'key': 8,
#   'loudness': -14.505,
#   'mode': 1,
#   'speechiness': 0.332,
#   'acousticness': 0.74,
#   'instrumentalness': 0.162,
#   'liveness': 0.106,
#   'valence': 0.196,
#   'tempo': 120.046,
#   'type': 'audio_features',
#   'id': '4SSnFejRGlZikf02HLewEF',
#   'uri': 'spotify:track:4SSnFejRGlZikf02HLewEF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4SSnFejRGlZikf02HLewEF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SSnFejRGlZikf02HLewEF',
#   'duration_ms': 193143,
#   'time_signature': 4},
#  {'danceability': 0.692,
#   'energy': 0.623,
#   'key': 7,
#   'loudness': -11.172,
#   'mode': 1,
#   'speechiness': 0.288,
#   'acousticness': 0.0303,
#   'instrumentalness': 1.45e-06,
#   'liveness': 0.0958,
#   'valence': 0.384,
#   'tempo': 134.987,
#   'type': 'audio_features',
#   'id': '7ER1r3QQOPfjj3x1UCa5pq',
#   'uri': 'spotify:track:7ER1r3QQOPfjj3x1UCa5pq',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ER1r3QQOPfjj3x1UCa5pq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ER1r3QQOPfjj3x1UCa5pq',
#   'duration_ms': 193361,
#   'time_signature': 4},
#  {'danceability': 0.516,
#   'energy': 0.587,
#   'key': 2,
#   'loudness': -5.756,
#   'mode': 1,
#   'speechiness': 0.0258,
#   'acousticness': 0.231,
#   'instrumentalness': 0,
#   'liveness': 0.108,
#   'valence': 0.237,
#   'tempo': 78.024,
#   'type': 'audio_features',
#   'id': '0otmxJEwq9JI1CidrcYEq4',
#   'uri': 'spotify:track:0otmxJEwq9JI1CidrcYEq4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0otmxJEwq9JI1CidrcYEq4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0otmxJEwq9JI1CidrcYEq4',
#   'duration_ms': 225101,
#   'time_signature': 4},
#  {'danceability': 0.764,
#   'energy': 0.488,
#   'key': 5,
#   'loudness': -6.017,
#   'mode': 1,
#   'speechiness': 0.0396,
#   'acousticness': 0.166,
#   'instrumentalness': 0,
#   'liveness': 0.0979,
#   'valence': 0.237,
#   'tempo': 124.923,
#   'type': 'audio_features',
#   'id': '34LbYwWS8Vxr6dsdZ64OXd',
#   'uri': 'spotify:track:34LbYwWS8Vxr6dsdZ64OXd',
#   'track_href': 'https://api.spotify.com/v1/tracks/34LbYwWS8Vxr6dsdZ64OXd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34LbYwWS8Vxr6dsdZ64OXd',
#   'duration_ms': 213554,
#   'time_signature': 4},
#  {'danceability': 0.535,
#   'energy': 0.579,
#   'key': 6,
#   'loudness': -11.918,
#   'mode': 1,
#   'speechiness': 0.0583,
#   'acousticness': 0.57,
#   'instrumentalness': 6.2e-05,
#   'liveness': 0.12,
#   'valence': 0.555,
#   'tempo': 109.536,
#   'type': 'audio_features',
#   'id': '69XnaNHFaYiND63w3tUoga',
#   'uri': 'spotify:track:69XnaNHFaYiND63w3tUoga',
#   'track_href': 'https://api.spotify.com/v1/tracks/69XnaNHFaYiND63w3tUoga',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/69XnaNHFaYiND63w3tUoga',
#   'duration_ms': 234107,
#   'time_signature': 4},
#  {'danceability': 0.604,
#   'energy': 0.564,
#   'key': 7,
#   'loudness': -6.875,
#   'mode': 1,
#   'speechiness': 0.24,
#   'acousticness': 0.0316,
#   'instrumentalness': 5.42e-06,
#   'liveness': 0.585,
#   'valence': 0.872,
#   'tempo': 135.973,
#   'type': 'audio_features',
#   'id': '6tRLfrfy692qlbT2cECgQS',
#   'uri': 'spotify:track:6tRLfrfy692qlbT2cECgQS',
#   'track_href': 'https://api.spotify.com/v1/tracks/6tRLfrfy692qlbT2cECgQS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tRLfrfy692qlbT2cECgQS',
#   'duration_ms': 194062,
#   'time_signature': 4},
#  {'danceability': 0.712,
#   'energy': 0.353,
#   'key': 7,
#   'loudness': -9.975,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.651,
#   'instrumentalness': 0,
#   'liveness': 0.0918,
#   'valence': 0.229,
#   'tempo': 118.059,
#   'type': 'audio_features',
#   'id': '4G1FKyLsB8xcTdVEXgwcix',
#   'uri': 'spotify:track:4G1FKyLsB8xcTdVEXgwcix',
#   'track_href': 'https://api.spotify.com/v1/tracks/4G1FKyLsB8xcTdVEXgwcix',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4G1FKyLsB8xcTdVEXgwcix',
#   'duration_ms': 239480,
#   'time_signature': 4},
#  {'danceability': 0.758,
#   'energy': 0.294,
#   'key': 9,
#   'loudness': -9.113,
#   'mode': 0,
#   'speechiness': 0.0459,
#   'acousticness': 0.829,
#   'instrumentalness': 9.32e-06,
#   'liveness': 0.0981,
#   'valence': 0.348,
#   'tempo': 120.041,
#   'type': 'audio_features',
#   'id': '1zQ2PdP4hpA9gaWiaMMoJy',
#   'uri': 'spotify:track:1zQ2PdP4hpA9gaWiaMMoJy',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zQ2PdP4hpA9gaWiaMMoJy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zQ2PdP4hpA9gaWiaMMoJy',
#   'duration_ms': 183241,
#   'time_signature': 4}]

# %%
#my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

list_of_songs=[]
for index in range(0,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.701   0.425   -10.965       0.3750      0.328000
# 1          0.670   0.453   -11.265       0.2950      0.252000
# 2          0.701   0.425   -10.965       0.3750      0.328000
# 3          0.811   0.748   -10.298       0.0682      0.553000
# 4          0.612   0.797    -3.648       0.4480      0.064000
# 5          0.701   0.425   -10.965       0.3750      0.328000
# 6          0.698   0.323    -9.980       0.1780      0.914000
# 7          0.582   0.829    -5.688       0.0465      0.000517
# 8          0.563   0.814    -4.219       0.0558      0.009830
# 9          0.695   0.779    -5.975       0.2570      0.196000
# 10         0.474   0.948    -2.592       0.1220      0.022300
# 11         0.829   0.327   -11.346       0.1040      0.040200
# 12         0.801   0.685    -5.515       0.0656      0.420000
# 13         0.367   0.111   -14.084       0.0972      0.978000
# 14         0.698   0.429    -9.246       0.0416      0.148000
# 15         0.757   0.598    -7.777       0.0580      0.090400
# 16         0.722   0.747    -3.483       0.0509      0.024900
# 17         0.842   0.623    -5.678       0.0869      0.054500
# 18         0.843   0.658    -7.072       0.0678      0.004560
# 19         0.652   0.516    -7.748       0.0426      0.062200
# 20         0.695   0.779    -5.975       0.2570      0.196000
# 21         0.643   0.786    -3.976       0.0302      0.002550
# 22         0.444   0.309   -10.956       0.0620      0.795000
# 23         0.847   0.491    -8.025       0.4360      0.386000
# 24         0.575   0.843    -4.402       0.0518      0.000743
# 25         0.807   0.893    -3.745       0.0347      0.045100
# 26         0.824   0.770    -7.281       0.1770      0.142000
# 27         0.730   0.710    -3.976       0.0448      0.084200
# 28         0.656   0.465   -12.132       0.0311      0.368000
# 29         0.830   0.405    -8.484       0.4110      0.015800
# 30         0.730   0.710    -3.976       0.0448      0.084100
# 31         0.781   0.722    -8.376       0.0667      0.236000
# 32         0.736   0.468    -8.572       0.1950      0.110000
# 33         0.526   0.639    -6.140       0.1040      0.010600
# 34         0.800   0.948    -2.340       0.1920      0.003210
# 35         0.945   0.858   -10.271       0.4040      0.052100
# 36         0.785   0.671    -7.108       0.0505      0.448000
# 37         0.612   0.521    -7.137       0.0331      0.519000
# 38         0.511   0.363    -7.650       0.0410      0.816000
# 39         0.632   0.284   -14.025       0.0801      0.932000
# 40         0.700   0.693    -5.092       0.2010      0.129000
# 41         0.585   0.717    -5.055       0.0426      0.009700
# 42         0.905   0.389   -14.505       0.3320      0.740000
# 43         0.692   0.623   -11.172       0.2880      0.030300
# 44         0.516   0.587    -5.756       0.0258      0.231000
# 45         0.764   0.488    -6.017       0.0396      0.166000
# 46         0.535   0.579   -11.918       0.0583      0.570000
# 47         0.604   0.564    -6.875       0.2400      0.031600
# 48         0.712   0.353    -9.975       0.0357      0.651000
# 49         0.758   0.294    -9.113       0.0459      0.829000
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.130000    0.1000   0.5620  135.128  2Fxmhks0bxGSBdJ92vM42m
# 1           0.330000    0.1170   0.6800  135.055  3yNZ5r3LKfdmjoS3gkhUCT
# 2           0.130000    0.1000   0.5620  135.128  2s5krQtudVMNZetgxGHNBG
# 3           0.000000    0.1100   0.8830  108.816  3gZoHbFt5W3HltDGcnbDrD
# 4           0.000000    0.2570   0.3580   81.086  3IaAYtmN8T0YIYVqnxNnVz
# 5           0.130000    0.1000   0.5620  135.128  6x3jFFNMbYIz8hUTIWS1Eo
# 6           0.037000    0.0991   0.6700  135.069  1qOsHMitiWT4Zhx9ICzmjW
# 7           0.000000    0.2660   0.8670  130.969  0KqyBk4aVT88TEqBIC8mAP
# 8           0.043700    0.0732   0.7960  140.615  0iM1Ioz4N4p7MU1DKyqsov
# 9           0.000000    0.1100   0.7040  142.175  1VQKKey9XgeYOm6rd1Aje8
# 10          0.000000    0.4300   0.6110  146.460  78ML3F5Lz3KiNkpnFAaR3q
# 11          0.545000    0.1050   0.7230  135.984  4I1ypegnI8R0HlsAF5rZYn
# 12          0.000000    0.1000   0.7770  108.024  6O0yvfx7qeE16s0UyhxOVT
# 13          0.000040    0.0897   0.1980   82.642  43zdsphuZLzwA9k4DJhU0I
# 14          0.691000    0.1010   0.5400  134.946  2FH0jT9o0mz71s7AtMkAa4
# 15          0.551000    0.1500   0.1800  124.951  4t2OeILB07eMGTXSUbMPEu
# 16          0.000005    0.1970   0.3430   95.866  4KVVy0GeXO03ni8Cv4SWk8
# 17          0.000079    0.0434   0.8450  136.000  0OnmY8BGZsxzEhyZJ43ooZ
# 18          0.730000    0.0673   0.5620  131.010  5v7OrTvBQNhXQwVzi3oXpb
# 19          0.000006    0.1200   0.3420   91.975  0iXlgib8Sp7tU0tRdoUJYg
# 20          0.000000    0.1100   0.7040  142.175  7vLzU22xRA0pz9A8Ch1NNl
# 21          0.000000    0.0462   0.5200  107.005  760frpppJAxqsVBuiOt1yL
# 22          0.132000    0.3520   0.0875  104.745  2ygvZOXrIeVL4xZmAWJT2C
# 23          0.000067    0.1190   0.6230  139.947  7emJRAhUHhLtBtvzjDpjMC
# 24          0.000000    0.3150   0.8430  130.982  5R4UtkoueIomI2z3Ei8B38
# 25          0.000028    0.3660   0.5370  126.011  3rmo8F54jFF8OgYsqTxm5d
# 26          0.000000    0.1120   0.3270  119.887  408if5LwFlG8lsyYkSGjJn
# 27          0.000000    0.3460   0.5440  114.946  5XYNCCkYoFLegWZcQU9ecn
# 28          0.000000    0.1550   0.7780   96.930  4FoRp17jtblWkNCfPe9QEU
# 29          0.000009    0.2410   0.1880  147.070  5TvdhNXoHbeGeWtjCYhFuy
# 30          0.000000    0.3410   0.5440  114.949  4g077yizjVdMB5HFl3rJRo
# 31          0.000398    0.0770   0.5330   87.858  0qeKzbUsW0V4ZWRJrHNiD3
# 32          0.000000    0.1070   0.4170   80.505  5w4enr0FN8ZTwxmfnACz2f
# 33          0.000022    0.1200   0.7170  135.012  3UCQwTclMnDYtS0uVjNTGO
# 34          0.000000    0.0800   0.9240  104.971  6ST6x5sSLYArqrh30p3KBs
# 35          0.143000    0.0494   0.6320  134.992  2uqN75iYEOcDQEtpCg65Ms
# 36          0.000018    0.2250   0.5880  124.899  1O8BgvuH9SMVddb3MQINwp
# 37          0.000000    0.1660   0.3680   92.988  6BZuf8iLTI18rN8L8WarzL
# 38          0.031700    0.0840   0.1690  144.892  7hDVYcQq6MxkdJGweuCtl9
# 39          0.000476    0.2330   0.2080  129.642  042Sl6Mn83JHyLEqdK7uI0
# 40          0.000000    0.2320   0.4750  146.109  4727RsuKMuY09HnC1ZD6yt
# 41          0.031300    0.0952   0.7010  174.019  5bnPew0sFrsFDUrkvVezRS
# 42          0.162000    0.1060   0.1960  120.046  4SSnFejRGlZikf02HLewEF
# 43          0.000001    0.0958   0.3840  134.987  7ER1r3QQOPfjj3x1UCa5pq
# 44          0.000000    0.1080   0.2370   78.024  0otmxJEwq9JI1CidrcYEq4
# 45          0.000000    0.0979   0.2370  124.923  34LbYwWS8Vxr6dsdZ64OXd
# 46          0.000062    0.1200   0.5550  109.536  69XnaNHFaYiND63w3tUoga
# 47          0.000005    0.5850   0.8720  135.973  6tRLfrfy692qlbT2cECgQS
# 48          0.000000    0.0918   0.2290  118.059  4G1FKyLsB8xcTdVEXgwcix
# 49          0.000009    0.0981   0.3480  120.041  1zQ2PdP4hpA9gaWiaMMoJy
#
#     duration_ms
# 0        194088
# 1        194840
# 2        194088
# 3        136133
# 4        434077
# 5        194088
# 6        193227
# 7        197800
# 8        157832
# 9        221560
# 10       195373
# 11       135882
# 12       152970
# 13       196077
# 14       191975
# 15       210233
# 16       279133
# 17       240000
# 18       281253
# 19       150811
# 20       221560
# 21       189227
# 22       208155
# 23       192400
# 24       197613
# 25       230747
# 26       228500
# 27       221253
# 28       144170
# 29       169493
# 30       221253
# 31       229375
# 32       146773
# 33       191806
# 34       188817
# 35       152940
# 36       159360
# 37       250000
# 38       200379
# 39       245897
# 40       138082
# 41       181453
# 42       193143
# 43       193361
# 44       225101
# 45       213554
# 46       234107
# 47       194062
# 48       239480
# 49       183241

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "7beGd4yYY1qpsBv6K3clFZ",market="GB")

# %%
playlist["items"][0]
# Out:
# {'added_at': '2020-09-18T11:03:07Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/qoh8oezhy6uxn8gd4vy7ddlty'},
#   'href': 'https://api.spotify.com/v1/users/qoh8oezhy6uxn8gd4vy7ddlty',
#   'id': 'qoh8oezhy6uxn8gd4vy7ddlty',
#   'type': 'user',
#   'uri': 'spotify:user:qoh8oezhy6uxn8gd4vy7ddlty'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6EVYTRG1drKdO8OnIQBeEj'},
#    'href': 'https://api.spotify.com/v1/albums/6EVYTRG1drKdO8OnIQBeEj',
#    'id': '6EVYTRG1drKdO8OnIQBeEj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273deec12a28d1e336c5052e9aa',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02deec12a28d1e336c5052e9aa',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851deec12a28d1e336c5052e9aa',
#      'width': 64}],
#    'name': 'My Everything (Deluxe)',
#    'release_date': '2014-08-25',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:6EVYTRG1drKdO8OnIQBeEj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#     'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#     'id': '66CXWjxzNUsdJxJ2JdwvnR',
#     'name': 'Ariana Grande',
#     'type': 'artist',
#     'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#   'disc_number': 1,
#   'duration_ms': 233720,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71409739'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3hgl7EQwTutSm6PESsB7gZ'},
#   'href': 'https://api.spotify.com/v1/tracks/3hgl7EQwTutSm6PESsB7gZ',
#   'id': '3hgl7EQwTutSm6PESsB7gZ',
#   'is_local': False,
#   'is_playable': True,
#   'name': "You Don't Know Me",
#   'popularity': 52,
#   'preview_url': None,
#   'track': True,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'},
#  'video_thumbnail': {'url': None}}

# %% [markdown]
# ## extracting a song from playlist

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '3hgl7EQwTutSm6PESsB7gZ'

# %%
play_song(playlist["items"][0]["track"]["id"])
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3hgl7EQwTutSm6PESsB7gZ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  4338
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %% [markdown]
# ## extracting the songs ids from playlist

# %%
list_of_audio_features=[]
for item in range(0,10):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df=pd.DataFrame(list_of_audio_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.566   0.664    -5.303       0.0464       0.63400
# 1         0.768   0.820    -4.630       0.0474       0.17900
# 2         0.558   0.559    -9.222       0.0959       0.37100
# 3         0.679   0.715    -6.383       0.0407       0.07550
# 4         0.778   0.824    -5.892       0.0707       0.28400
# 5         0.421   0.873    -4.343       0.0564       0.06540
# 6         0.497   0.865    -3.190       0.0644       0.03060
# 7         0.616   0.789    -4.874       0.0377       0.05300
# 8         0.751   0.783    -3.724       0.0859       0.00379
# 9         0.706   0.842    -4.628       0.0380       0.04760
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.000000     0.116    0.437  128.945  3dYD57lRAUcMHufyqn9GcI
# 1          0.000000     0.689    0.625  129.965  2V4bv1fNWfTcyRJKmej6Sj
# 2          0.000007     0.109    0.620   78.558  7KA4W4McWYRpgf0fWsJZWB
# 3          0.000000     0.271    0.571  127.435  4Ub8UsjWuewQrPhuepfVpd
# 4          0.000000     0.405    0.758  100.024  3ZFTkvIE7kyPt6Nu3PEa7V
# 5          0.000000     0.123    0.629   84.786  7wMq5n8mYSKlQIGECKUgTX
# 6          0.067900     0.443    0.595  125.960  78W8wiUIlQ2SnWY9TVowKZ
# 7          0.000000     0.142    0.621   83.066  6wJwkMo278iWVlWl1XQ4WA
# 8          0.000000     0.036    0.816  119.975  2CEgGE6aESpnmtfiZwYlbV
# 9          0.000000     0.134    0.818  104.958  71R6zJsrF3ffc3TBFHfivX
#
#    duration_ms
# 0       241688
# 1       213293
# 2       180387
# 3       214148
# 4       218093
# 5       202533
# 6       174203
# 7       227373
# 8       202613
# 9       224720

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['Cheek',
#  '',
#  'Logan Paul',
#  'Henna Narva',
#  'Cory Gunz',
#  'Kelly Rowland',
#  'Injury Reserve',
#  'Birdy',
#  'TobyMac',
#  'Madcon',
#  'Showtek',
#  'Carnage',
#  'Saara Aalto',
#  'CNCO',
#  'Dimitri Vegas & Like Mike',
#  'Queen',
#  'FlicFlac',
#  'Gasellit',
#  'Alissa Violet',
#  'MEDUZA',
#  'La Cream',
#  'Halestone',
#  'Kanye West',
#  'Farruko',
#  'Brendon Urie',
#  'RAYE',
#  'Adam Lambert',
#  'Train',
#  'Rune RK',
#  'Dirty Disco Youth',
#  'Years & Years',
#  'Santa Cruz',
#  'Breakbot',
#  'frzndisciple',
#  'Queen Key',
#  'Lloyd Banks',
#  'Irfane',
#  'Running Touch',
#  'Trisha Paytas',
#  'Sum 41',
#  'Tungevaag',
#  'Wheeler Walker Jr.',
#  'Bastille',
#  'Ulpu',
#  'Felix Jaehn',
#  'Lauriana Mae',
#  'Craig Xen',
#  'Madison Love',
#  'Dosdela',
#  'eli.',
#  'FÄIS',
#  'Mäkki',
#  'Leyla Blue',
#  'Roy English',
#  'SIDEPIECE',
#  'Morgan Page',
#  'Oh Wonder',
#  'Mike Posner',
#  'Lorde',
#  'Lewis Capaldi',
#  'Wale',
#  'Jenni Vartiainen',
#  'G Herbo',
#  'Outkast',
#  'Famous Dex',
#  'Sani',
#  'Nile Rodgers',
#  'Ski Mask The Slump God',
#  'Jeff Kush',
#  'Yö',
#  'Ephwurd',
#  'Larray',
#  'Arrhult',
#  'Don Toliver',
#  'SAYGRACE',
#  'Yung Pinch',
#  'Majid Jordan',
#  'Jontte Valosaari',
#  'Gettomasa',
#  'Timmies',
#  'Sonny Wilson',
#  'Tarrus Riley',
#  'Matoma',
#  'Sirena',
#  'YNW Melly',
#  'Tori Kelly',
#  'Kobe',
#  'Maiki',
#  'Noam Kaniel',
#  'Maty Noyes',
#  'GoonRock',
#  'MHD',
#  '916frosty',
#  'Günther',
#  'Pop Smoke',
#  'TisaKorean',
#  'Chivv',
#  'nothing,nowhere.',
#  'Karmin',
#  'Martin Garrix',
#  'Brent Faiyaz',
#  'Mikkel Øwre',
#  'Rita Ora',
#  'Chimamanda Ngozi Adichie',
#  'Egzod',
#  'Freddy Kalas',
#  'YB026',
#  'Justin Timberlake',
#  'Plustwo',
#  'Penelope Scott',
#  'Jack Ü',
#  'L.V.',
#  'Blac Youngsta',
#  'IKE',
#  'Frank Ocean',
#  'MGI',
#  'Ross Lynch',
#  'Skan',
#  'Khlaw',
#  'Kingston Crew',
#  'Kacey Musgraves',
#  'Benjamin Ingrosso',
#  'Eden Prince',
#  'Axwell /\\ Ingrosso',
#  "Ol' Dirty Bastard",
#  '90s allstars',
#  'DJ DX',
#  'Providers',
#  'Mikky Ekko',
#  'Paperi T',
#  'Lauri Haav',
#  'Kid Ink',
#  'Paramore',
#  'Slim Mill',
#  'The Corrs',
#  'Erin',
#  "Rag'n'Bone Man",
#  'LUCA',
#  'Måns Zelmerlöw',
#  'Swae Lee',
#  'The Lumineers',
#  'City Girls',
#  'Giorgio Tuinfort',
#  'Juulia',
#  'LILMozart',
#  'J Balvin',
#  'Yello',
#  'Emily Warren',
#  'Jessie Reyez',
#  'Duo',
#  'Zak Abel',
#  'Lil 2z',
#  'HesaÄijä',
#  'Aksel Kankaanranta',
#  'PNAU',
#  'Ciara',
#  'Young Nudy',
#  'Zacari',
#  'Death Cab for Cutie',
#  'Hayley Williams',
#  'Trouble',
#  'Russ',
#  'SEUNGRI',
#  'Stunna 4 Vegas',
#  'Ylvis',
#  'Natalie La Rose',
#  'Alfons',
#  'Cassie',
#  'William Singe',
#  'Dove Cameron',
#  'Moneybagg Yo',
#  'Frederik',
#  'Kenndog',
#  'Ella Mai',
#  'Zedd',
#  'Joyner Lucas',
#  'Scala & Kolacny Brothers',
#  'Foster The People',
#  'Yung Gleesh',
#  'Boney M.',
#  'Chisu',
#  'Talk Talk',
#  'Murda Beatz',
#  'ILARI',
#  'Landon Cube',
#  'Nicki Minaj',
#  'Killua the Pilgrim',
#  'DROELOE',
#  'Blasterjaxx',
#  'Nytrix',
#  'Matias',
#  'lentra',
#  'Stormzy',
#  'Alex Aris',
#  'Dingo',
#  'NAV',
#  'Kali Uchis',
#  'Rich Brian',
#  'Emily Roberts',
#  'Bogart Co.',
#  'Robin og Bugge',
#  'Quality Control',
#  'Sandro Cavazza',
#  'kent',
#  'HRVY',
#  'Tony Junior',
#  'Childish Gambino',
#  'Luis Fonsi',
#  'Maisie Peters',
#  'Clyde Taylor',
#  'blackbear',
#  'Megan Nicole',
#  'Jannika B',
#  'ADG Satch',
#  'Stepa',
#  'Kaleena Zanders',
#  'Tears For Fears',
#  'Mike Cervello',
#  'Majuri',
#  'Sam Fischer',
#  'Yasmine Yamajako',
#  'Tehosekoitin',
#  'Georgia Ku',
#  'Louisa',
#  'Smokepurpp',
#  'Grace Phipps',
#  'Solo Lucci',
#  'H.E.R.',
#  'Vesala',
#  'Drake Bell',
#  'Nick Bonin',
#  'Shiloh Dynasty',
#  'The Flint Chozen Choir',
#  'Redfoo',
#  'Like Mike',
#  'Chase Atlantic',
#  'Alexander Oscar',
#  'WhoHeem',
#  'Murcy',
#  'Shinedown',
#  'Arctic Monkeys',
#  'Lukas Graham',
#  'MØ',
#  'Chrisette Michele',
#  'Solid Base',
#  'Logic',
#  'DVBBS',
#  'Dr. Dre',
#  'Taylor Girlz',
#  '2Pac',
#  'Luniz',
#  'Mr Magic',
#  'Teddy',
#  'Zendaya',
#  '3robi',
#  'Mike Perry',
#  'Florence + The Machine',
#  'ARTY',
#  'Juelz Santana',
#  'Mascara',
#  'Magnace',
#  'Kranium',
#  'Sallitut Aineet',
#  'Alesso',
#  'Mac Miller',
#  'Eternal Flames',
#  'Joznez',
#  'High School Musical Cast',
#  'Labrinth',
#  'Becky Hill',
#  'Mr. Elämänpeli',
#  'A.G.',
#  'Lauren Bennett',
#  'Gunna',
#  'LVNDSCAPE',
#  'Bridgit Mendler',
#  'Michael Andrews',
#  'Dizzee Rascal',
#  'STIG',
#  'Stalking Gia',
#  'Handsome Luke',
#  'Baby Tate',
#  'Mura Masa',
#  'Seekae',
#  'Halsey',
#  'Happoradio',
#  'Frankie Knuckles',
#  'Anssi Kela',
#  'Aries',
#  'Soulja Boy',
#  'Cascada',
#  'Pää-äijät',
#  'Say Lou Lou',
#  "Why Don't We",
#  'Hannah Robinson',
#  'Olly James',
#  'Suurlähettiläät',
#  'Ricegum',
#  'Walt Ribeiro',
#  'Shenie Fogo',
#  'Jess Glynne',
#  'Selena Gomez & The Scene',
#  'Carlprit',
#  'Jason Agel',
#  'Cutting Crew',
#  'Young Thug',
#  'Backstreet Boys',
#  'Kristinia DeBarge',
#  'Chamillionaire',
#  'KSI',
#  'House Of Pain',
#  'Lil Gnar',
#  'Axwell',
#  'DEM',
#  'Hittman',
#  'Loud Luxury',
#  'A$AP Mob',
#  'J. Davi$',
#  'Juno',
#  'Sak Noel',
#  'Alex Aiono',
#  'Wynter Gordon',
#  'Lauri Tähkä',
#  'Baby Alice',
#  'Delaney Jane',
#  'Smith & Thell',
#  'Artem x Yonas',
#  'Cody Simpson',
#  'Panic! At The Disco',
#  'Duki',
#  'Olavi Uusivirta',
#  'Bag Raiders',
#  'Kovee',
#  'John Martin',
#  'VASSY',
#  'Mesto',
#  'Aloe Blacc',
#  'Horse Attack Sqwad',
#  'Alina Baraz',
#  'Janieck Devy',
#  'Beats And Styles',
#  'The Outlaws',
#  'Tuure Boelius',
#  'El Cata',
#  'TEN TIMES',
#  'Bhad Bhabie',
#  'Beyoncé',
#  'Jack McManus',
#  'The Cataracs',
#  'Stargate',
#  'The Greatest Showman Ensemble',
#  'Central Cee',
#  'Yellow Claw',
#  'Thomas Doherty',
#  'Gabry Ponte',
#  'Goodboys',
#  'Annabel Jones',
#  'WSTRN',
#  'Justin Stone',
#  'Neev',
#  'E-Type',
#  'Little Big',
#  'Shotgun Willy',
#  'Das EFX',
#  'Eyedress',
#  'costee',
#  'The Chordettes',
#  'Richi M.',
#  'Skee-Lo',
#  'Yung Berg',
#  'Master Blaster',
#  'P.Moody',
#  'Robyn',
#  'Poo Bear',
#  'Iyaz',
#  'Hardwell',
#  'Axel Kala',
#  'Rihanna',
#  'Harry Fraud',
#  'DNCE',
#  'Tango-Teemu',
#  'BESS',
#  'Ola',
#  'Sash!',
#  'Tierra Whack',
#  'Infernal',
#  'Tohtori Getto',
#  'Eve',
#  'Fat Joe',
#  "Colby O'Donis",
#  'Kardinal Offishall',
#  'Foreigner',
#  'Anne Mattila',
#  'Famous Ocean & KungFu',
#  'The Naked And Famous',
#  'Studio Killers',
#  'Alec Benjamin',
#  'Fokin Osk',
#  'Laurell',
#  'Two Feet',
#  'Kuwada',
#  'Danny',
#  'Molchat Doma',
#  '7ru7h',
#  'Leona Lewis',
#  'James Bay',
#  'Grace Grundy',
#  'WALK THE MOON',
#  'Röyksopp',
#  'Eppu Normaali',
#  'Everlast',
#  'Anna of the North',
#  'JVKE',
#  'Cimo Fränkel',
#  'Kylie Minogue',
#  'Evang',
#  'líue',
#  'LLusion',
#  'Karlyn',
#  'Robin',
#  'Pet Shop Boys',
#  'Luh Kel',
#  'Skizzy Mars',
#  'Mikko Pohjola',
#  'Zeeba',
#  'Nelly',
#  'WizKid',
#  'Bryn Christopher',
#  'Tee Grizzley',
#  'ilyTOMMY',
#  'Elastinen',
#  'Roy Jones Jr.',
#  'Matt Squire',
#  'iann dior',
#  'OG Ulla-Maija',
#  'Grouplove',
#  'Hätä-Miikka',
#  'Andy Marsh',
#  'Jon Bellion',
#  'Alex Joseph',
#  'Bebe Rexha',
#  'The Bangles',
#  'Portugal. The Man',
#  'Benny Sings',
#  'Lonely God',
#  'Diego Miranda',
#  'Auntie Hammy',
#  'Justin Mylo',
#  'The All-American Rejects',
#  'Lil Gotit',
#  'Lovely Peaches',
#  'James Brown & The Famous Flames',
#  'salem ilese',
#  'Digital Farm Animals',
#  'Tiagz',
#  'Rudimental',
#  'Ummet Ozcan',
#  'Jason Weaver',
#  'Ashnikko',
#  'Arizona Zervas',
#  'Flo Rida',
#  'Louis The Child',
#  'Kaptan',
#  'LeAnn Rimes',
#  'Little Sis Nora',
#  'Pitbull',
#  'Thirty Seconds To Mars',
#  'Mandi',
#  'Sofía Reyes',
#  'Jaden',
#  'Duke Dumont',
#  'Oliver Nelson',
#  'Tame Impala',
#  'Geto Boys',
#  'beabadoobee',
#  'Donny',
#  'P!nk',
#  'Lush & Simon',
#  'Far East Movement',
#  'Danny Avila',
#  'YG',
#  'LL Cool J',
#  'James Blake',
#  'Stromae',
#  'Lucenzo',
#  'Lil Jon',
#  'Speernorman',
#  'LunchMoney Lewis',
#  'Ashley Tisdale',
#  'Ben Morfitt (SquidPhysics)',
#  'DJ Sammy',
#  'Roope Salminen & Koirat',
#  'Ying Yang Twins',
#  'Kuselofte',
#  'benny blanco',
#  'Cashmere Cat',
#  'iSHi',
#  'Ant Saunders',
#  'BØRNS',
#  'SAMUEL',
#  'ABBA',
#  'Egotrippi',
#  'Mouhous',
#  'Skandaali',
#  'Wham!',
#  'SNBRN',
#  'Moon Taxi',
#  'Buddy',
#  'Rivers Cuomo',
#  'Gary Jules',
#  'Subvrbs',
#  'Slash',
#  'Nylon Beat',
#  'Pandora',
#  'Yo Gotti',
#  'Ultra Bra',
#  'Mariska',
#  'ZAYN',
#  'NextYoungin',
#  'Mike Candys',
#  'Rich Homie Quan',
#  'Anastacia',
#  'Apulanta',
#  'Travis Barker',
#  'The Boy Next Door',
#  'Megan Thee Stallion',
#  'Black Sabbath',
#  'Riki Sorsa',
#  'The Offspring',
#  'Mary Lambert',
#  'Smash Mouth',
#  'Savage Ga$p',
#  'Maisa',
#  'Samuli Edelmann',
#  'Arttu Wiskari',
#  'Popcaan',
#  'Shelley FKA DRAM',
#  'HEALTH',
#  'Cedric Gervais',
#  'PastoriPike',
#  'Peter Piffen',
#  'BeatKing',
#  'Shaun Frank',
#  'Aamupojat',
#  'KAROL G',
#  'Mac Beez',
#  'Conor Maynard',
#  'Saimaa',
#  'Sairas T',
#  'Lil Keed',
#  'Brandy',
#  'BACALL',
#  'Cash Cash',
#  'Brando',
#  'PnB Rock',
#  'ROSALÍA',
#  'Tom & Hills',
#  'Katy B',
#  'Frederic Riesterer',
#  'Disco Ensemble',
#  'Softengine',
#  'Spree Wilson',
#  'Ruben Haze',
#  'Cavallini & Shrty',
#  'Louis Tomlinson',
#  'MOGUAI',
#  'Dash Berlin',
#  'R. Kelly',
#  'YBN Nahmir',
#  'Anne-Marie',
#  'Ayo & Teo',
#  'Pikku G',
#  'DeezyDavid',
#  'Turisti',
#  'Jay Alvarrez',
#  'Dermot Kennedy',
#  'Bobby Shmurda',
#  'Ali Gatie',
#  'Jack Stauber',
#  'Molly',
#  'Spice Girls',
#  'Daya',
#  'Erika Vikman',
#  'Infinity',
#  'Boombox Cartel',
#  'Devin The Dude',
#  'Haddaway',
#  'SEB',
#  'Sia',
#  'Young Manager',
#  'Lil Nas X',
#  'girl in red',
#  'Alexander 23',
#  'Duran Duran',
#  'Danelle Sandoval',
#  'Big Ali',
#  'Aste',
#  'Aerosmith',
#  'Lil Tracy',
#  'Cledos',
#  'Denzel Curry',
#  '24kGoldn',
#  'MKTO',
#  'OBN Dev',
#  'Ginuwine',
#  'Dawin',
#  'Odette Christian',
#  'TWENTY88',
#  'fun.',
#  'Harry Styles',
#  'Sophie and the Giants',
#  'Profeetat',
#  'Faul & Wad',
#  'Niko Saarinen',
#  'DJ Antoine',
#  'Timeflies',
#  'Elley Duhé',
#  'Verdine White',
#  'Blaise',
#  'Dean Lewis',
#  'Jasiah',
#  'Rizzle Kicks',
#  'Mk.gee',
#  'Sasha Lopez',
#  'Emil Assergård',
#  'Edward Maya',
#  'BLACKPINK',
#  'The Lonely Island',
#  'Tunji Ige',
#  'Janne Ordén',
#  'KHEA',
#  'Kane Brown',
#  'GoldLink',
#  'Ruel',
#  'Sugarland',
#  'Costi',
#  'Ryan',
#  'MKDMSK',
#  'Dante Leon',
#  'JAY-Z',
#  'Anime',
#  'Vanessa Carlton',
#  'Comethazine',
#  "Rappin' 4-Tay",
#  'The Rasmus',
#  'Pasi ja Anssi',
#  'Marilii',
#  'Kid Francescoli',
#  'A Boogie Wit da Hoodie',
#  'Helena Bonham Carter',
#  'Q-Tip',
#  'Brayden',
#  'Lilli Paasikivi',
#  'Kid Cudi',
#  'Elonkerjuu',
#  'SOLANO',
#  'Asap Vergi',
#  'Naomi Scott',
#  'Anna Järvinen',
#  'HEDEGAARD',
#  'Crazy Town',
#  'Stephen',
#  'EDEN',
#  'DJ BL3ND',
#  'Jonna Tervomaa',
#  'Djuro',
#  'Erakossa',
#  'DEV',
#  'Joanna Jones',
#  'Ollie',
#  'Blush',
#  'Huncho',
#  'Krewella',
#  'Stryker Pose',
#  '6 Dogs',
#  'Luke Combs',
#  'Elena Coats',
#  'CALVO',
#  'Lil Peep',
#  'Kamatos',
#  'Pusha T',
#  'Migos',
#  'Rick Astley',
#  'Laleh',
#  'Ty Dolla $ign',
#  'Vula',
#  'Cal Chuchesta',
#  'Remy Ma',
#  'Ashley All Day',
#  'Dixie',
#  'Dani Poppitt',
#  'Mr. President',
#  'Night Lovell',
#  'Selena Gomez',
#  'Yung Gravy',
#  'Captain Jack',
#  'JACKBOYS',
#  'Shokk',
#  'Akon',
#  'Passenger',
#  'Paradisio',
#  'Ester Dean',
#  'Elias Gould',
#  'Duffy',
#  'Ghostemane',
#  'KAMASUTRA 9G',
#  'Carly Rae Jepsen',
#  'Dreezy',
#  'Cole Swindell',
#  'Ina Wroldsen',
#  'Hector',
#  'Karri Koira',
#  'Tea',
#  'BETWEEN FRIENDS',
#  'Villayn',
#  'Jay Rock',
#  'Lännen Liinein',
#  'SoMo',
#  'Tomppabeats',
#  'Parson James',
#  'Lakim',
#  'KANDY',
#  'Dorrough Music',
#  'PSY',
#  'The Moose',
#  'Moby',
#  'John Ryan',
#  'ROZES',
#  'Tyrone Briggs',
#  'Phoebe Ryan',
#  'Tim McMorris',
#  'Unghetto Mathieu',
#  'Surf Curse',
#  'HVME',
#  'Silentó',
#  'Lil Kapow',
#  'DJ Mental Theos Bazzheadz',
#  'Havana Brown',
#  'Kurupt',
#  'Dzeko',
#  'G-Eazy',
#  'Jari Sillanpää',
#  'Shawn Hook',
#  'Jonihey',
#  'Chris Brown',
#  'Filip Jenven',
#  'Afro Bros',
#  'Ralph Tresvant',
#  'Pihlaja',
#  'Oliver Tree',
#  'Jack & Jack',
#  'Bekuh Boom',
#  'Indiiana',
#  'Daniel Caesar',
#  'McCafferty',
#  'KSHMR',
#  'ABREU',
#  'Pekka Ruuska',
#  'Tuomas Holopainen',
#  'Kaash Paige',
#  'Adelén',
#  'Fousheé',
#  'Chris Lake',
#  'U96',
#  'Hayla',
#  'Doja Cat',
#  'A Great Big World',
#  'Ashe',
#  'Sean Paul',
#  'Jay Hardway',
#  'Joey Bada$$',
#  'Aaro630',
#  'Michel Teló',
#  'william',
#  'Dimitri Vegas',
#  'Live for the weekend',
#  'Sabi',
#  'Irina',
#  'Ryanning',
#  'Ella Henderson',
#  'Pariisin Kevät',
#  'Pink Guy',
#  'KajO',
#  'SAARA',
#  'Drake',
#  'Eiffel 65',
#  'Victorious Cast',
#  'Emma Hewitt',
#  'Fergie',
#  'Jesse McCartney',
#  'Ja Rule',
#  'Heretic Klick',
#  'OMC',
#  'Christopher',
#  'Kaoma',
#  'Nikke Ankara',
#  'Glass Animals',
#  'Cuban Doll',
#  'Jamie Foxx',
#  'Waka Flocka Flame',
#  'DJ Martin ElectroSpin',
#  'Foo Fighters',
#  'Static Major',
#  'FROIDZ',
#  'YOUNGHEARTED',
#  'Vedo',
#  '27CLUB',
#  'Jasmine Thompson',
#  'Death Grips',
#  'Indica',
#  'Ilsey',
#  'DaBaby',
#  'Lil Baby',
#  'Vance Joy',
#  'Zen Cafe',
#  'Yung Anime',
#  'Party Favor',
#  'ALMA',
#  'Powfu',
#  'KJ Apa',
#  'FRENSHIP',
#  'Starley',
#  'Snow Patrol',
#  'Marcus Vinicius Campos',
#  'Toro y Moi',
#  'Chrome Sparks',
#  'Don Diablo',
#  'Hendersin',
#  'Demi Lovato',
#  'Kuningasidea',
#  'All Time Low',
#  'LIFE',
#  'R.E.M.',
#  'Lil Uzi Vert',
#  'One Direction',
#  'CAZZETTE',
#  'FKi 1st',
#  'Camila Mendes',
#  'Are',
#  'N.E.R.D',
#  'Dimitri Vangelis & Wyman',
#  'Busy Signal',
#  'Ca$his',
#  'Lauri Tähkä & Elonkerjuu',
#  'Miranda',
#  'Becky G',
#  'mayklove',
#  'Jason Mraz',
#  'WILLOW',
#  'Särre',
#  'Lil Mosey',
#  'Kevin Gates',
#  'Surfaces',
#  'Journey',
#  'Ella Lymi',
#  'Sofia Carson',
#  'HIM',
#  'Sammie',
#  'Fifth Harmony',
#  'Annika Eklund',
#  'Bonn',
#  'Jordin Sparks',
#  'BEHM',
#  '50 Cent',
#  'E-Rotic',
#  'ZHU',
#  'MC Hammer',
#  'Eevil Stöö',
#  'Adizi X Typelik',
#  'Tay Money',
#  'China Anne McClain',
#  'Remy Boyz',
#  '9lokknine',
#  'Kamaiyah',
#  'Kerli',
#  'J. Karjalainen',
#  'will.i.am',
#  'Hugh Jackman',
#  'Pekka Kuusisto',
#  'Do',
#  'Lindsay Lohan',
#  'Bon Jovi',
#  'Lexi Jayde',
#  'Lit',
#  'Ida Paul & Kalle Lindroth',
#  'Sharpay Evans',
#  'Sapienza',
#  'Darin',
#  'Vika Jigulina',
#  'Sabrina Carpenter',
#  'Kat Dahlia',
#  'Desiigner',
#  'Ida Paul',
#  '3 Doors Down',
#  'Booboo Stewart',
#  'La Bouche',
#  'The Flexican',
#  'Blind Channel',
#  'Twenty One Pilots',
#  'Miranda Cosgrove',
#  'Bonnie Tyler',
#  'Thomas Rhett',
#  'Marc Stout',
#  'Crystal Castles',
#  'Richard Smitt',
#  'Jedidi',
#  'Ivone Cerdan',
#  'Jamie Lynn Spears',
#  'Rebecca Black',
#  'SHY Martin',
#  'Gryffin',
#  'Alanis Morissette',
#  'AREA21',
#  'Cher Lloyd',
#  'Jhené Aiko',
#  'Zara Larsson',
#  'Goody Grace',
#  'Sigrid',
#  'Troye Sivan',
#  'Alexander Tidebrink',
#  'Sara Kays',
#  'Rachel Platten',
#  'Vesa-Matti Loiri',
#  'Bass Modulators',
#  'Meek Mill',
#  'KStewart',
#  'Oasis',
#  'London On Da Track',
#  'Jay Psar',
#  'Raappana',
#  'Joel Corry',
#  'Meg & Dia',
#  'Jennifer Lawrence',
#  'V V Brown',
#  'Vastis',
#  'LMFAO',
#  'Ronya',
#  'dodie',
#  'VIIVI',
#  'Paul Rey',
#  'Black Gryph0n',
#  'Fabolous',
#  'Conan Gray',
#  'Sage The Gemini',
#  'Audien',
#  'Dominic Fike',
#  'Galantis',
#  'Sam Smith',
#  'Billie Eilish',
#  'Kesh Kesh',
#  'Facemask Time',
#  'Grimes',
#  'Aika',
#  'Sampha',
#  'Sophia Annello',
#  'Nost3 & Protro',
#  'Parliament Funkadelic',
#  'DubVision',
#  'Jamie Scott',
#  'Diamond D',
#  'Jessie J',
#  'Clean Bandit',
#  'Wallows',
#  'Keala Settle',
#  'Adam Levine',
#  'VIZE',
#  'Sexmane',
#  'Of Monsters and Men',
#  'BloodPop®',
#  'DJ Katch',
#  'Portion Boys',
#  'Cardi B',
#  '6LACK',
#  'Matisyahu',
#  'Jack Joseph Puig',
#  'Sammy Adams',
#  'Breathe Carolina',
#  'Cameron Boyce',
#  'Nate Dogg',
#  'XS Project',
#  'Shania Twain',
#  'Icona Pop',
#  'GAMPER & DADONI',
#  'Saweetie',
#  'CJ',
#  'Ethan Fields',
#  'Jonas Brothers',
#  'Mascolo',
#  'Freddo',
#  'Kris Kross Amsterdam',
#  'Boyat',
#  'Lee Marrow',
#  'Kymppilinja',
#  'Ella Eyre',
#  'Alli Simpson',
#  'TIX',
#  'Faydee',
#  'Lizzo',
#  'Jake Paul',
#  'LIOHN',
#  ...]

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Alyx Ander',
#  'BTS',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Banda de Música da Força Aérea',
#  'Coldplay',
#  'David Guetta',
#  'Galantis',
#  'Greta Bradman',
#  'Jon Hopkins',
#  'José Manuel Ferreira Brito',
#  'Ofenbach',
#  'Rihanna',
#  'Robin Schulz',
#  'SUGA',
#  'Seeb',
#  'Selena Gomez',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 60317
