# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '22700979708',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 273120,
#    'login': 'tsteur',
#    'display_login': 'tsteur',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tsteur',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/273120?'},
#   'repo': {'id': 1548202,
#    'name': 'matomo-org/matomo',
#    'url': 'https://api.github.com/repos/matomo-org/matomo'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907',
#     'repository_url': 'https://api.github.com/repos/matomo-org/matomo',
#     'labels_url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907/comments',
#     'events_url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907/events',
#     'html_url': 'https://github.com/matomo-org/matomo/issues/18907',
#     'id': 1163841595,
#     'node_id': 'I_kwDOABefqs5FXtA7',
#     'number': 18907,
#     'title': 'GTM template',
#     'user': {'login': 'yassine-ah',
#      'id': 18461154,
#      'node_id': 'MDQ6VXNlcjE4NDYxMTU0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/18461154?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/yassine-ah',
#      'html_url': 'https://github.com/yassine-ah',
#      'followers_url': 'https://api.github.com/users/yassine-ah/followers',
#      'following_url': 'https://api.github.com/users/yassine-ah/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/yassine-ah/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/yassine-ah/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/yassine-ah/subscriptions',
#      'organizations_url': 'https://api.github.com/users/yassine-ah/orgs',
#      'repos_url': 'https://api.github.com/users/yassine-ah/repos',
#      'events_url': 'https://api.github.com/users/yassine-ah/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/yassine-ah/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 112370560,
#       'node_id': 'MDU6TGFiZWwxMTIzNzA1NjA=',
#       'url': 'https://api.github.com/repos/matomo-org/matomo/labels/Enhancement',
#       'name': 'Enhancement',
#       'color': 'bfd4f2',
#       'default': False,
#       'description': "For new feature suggestions that for example enhance Matomo's cabapilities.."}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-03-09T11:51:28Z',
#     'updated_at': '2022-07-05T10:37:03Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': "Now that many European countries start banning or investigating GA, many companies have choose Matomo as alternative to respect RGPD.\r\n\r\nAn official Matomo template will help a lot in this transaction, we wouldn't need to recreate the triggers or tags and only change GA by Matomo for example and keep all our other integrations with others analytics tools that respect RGPD.\r\n\r\n**trackify.info** have already created a template for Matomo: https://tagmanager.google.com/gallery/#/owners/trackify-info/templates/GoogleTagManager-WebTemplate-Matomo\r\n\r\nBut unfortunately, we cannot trust it for an enterprise solution:\r\n- The domain is down.\r\n- No informations about the enterprise.\r\n- Risk of JS injection because the template load JS script from their domain.\r\n\r\n[source code](https://github.com/trackify-info/GoogleTagManager-WebTemplate-Matomo)\r\n\r\n## Your Environment\r\n* Matomo Version: Latest\r\n* PHP Version: Supported\r\n* Server Operating System: Linux\r\n* Additionally installed plugins: No\r\n\r\nProbably a duplication of https://github.com/matomo-org/matomo/issues/12165",
#     'reactions': {'url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907/reactions',
#      'total_count': 4,
#      '+1': 3,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 1},
#     'timeline_url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/matomo-org/matomo/issues/comments/1174905990',
#     'html_url': 'https://github.com/matomo-org/matomo/issues/18907#issuecomment-1174905990',
#     'issue_url': 'https://api.github.com/repos/matomo-org/matomo/issues/18907',
#     'id': 1174905990,
#     'node_id': 'IC_kwDOABefqs5GB6SG',
#     'user': {'login': 'tsteur',
#      'id': 273120,
#      'node_id': 'MDQ6VXNlcjI3MzEyMA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/273120?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tsteur',
#      'html_url': 'https://github.com/tsteur',
#      'followers_url': 'https://api.github.com/users/tsteur/followers',
#      'following_url': 'https://api.github.com/users/tsteur/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tsteur/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tsteur/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tsteur/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tsteur/orgs',
#      'repos_url': 'https://api.github.com/users/tsteur/repos',
#      'events_url': 'https://api.github.com/users/tsteur/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tsteur/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-07-05T10:37:03Z',
#     'updated_at': '2022-07-05T10:37:03Z',
#     'author_association': 'MEMBER',
#     'body': "@justinvelluppillai maybe we can close this issue since we're working on this in https://github.com/matomo-org/google-tag-manager-matomo-template ?",
#     'reactions': {'url': 'https://api.github.com/repos/matomo-org/matomo/issues/comments/1174905990/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z',
#   'org': {'id': 698038,
#    'login': 'matomo-org',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/matomo-org',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/698038?'}},
#  {'id': '22700979608',
#   'type': 'PushEvent',
#   'actor': {'id': 53743348,
#    'login': 'Tim-Abwao',
#    'display_login': 'Tim-Abwao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Tim-Abwao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53743348?'},
#   'repo': {'id': 332031682,
#    'name': 'Tim-Abwao/blog-projects',
#    'url': 'https://api.github.com/repos/Tim-Abwao/blog-projects'},
#   'payload': {'push_id': 10348820747,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '01d02de7f9b74ec6649aeeb18b5522189a60c00a',
#    'before': '89344644bb1e7912d1a9a699448935874028f529',
#    'commits': [{'sha': '01d02de7f9b74ec6649aeeb18b5522189a60c00a',
#      'author': {'email': 'abwaomusungu@gmail.com', 'name': 'Tim-Abwao'},
#      'message': 'Update basic-flask-app\n\nAdd docstrings and remove unnecessary white-space.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Tim-Abwao/blog-projects/commits/01d02de7f9b74ec6649aeeb18b5522189a60c00a'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979679',
#   'type': 'PushEvent',
#   'actor': {'id': 103568586,
#    'login': 'Septume',
#    'display_login': 'Septume',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Septume',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103568586?'},
#   'repo': {'id': 510019323,
#    'name': 'Septume/Hack-Block',
#    'url': 'https://api.github.com/repos/Septume/Hack-Block'},
#   'payload': {'push_id': 10348820811,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'af77afba7497d755d92b24e01c146bd380e9c67e',
#    'before': 'de4f8d61ae8cc13f3936faa83fd370b319ca4e5d',
#    'commits': [{'sha': 'af77afba7497d755d92b24e01c146bd380e9c67e',
#      'author': {'email': 'duchene.nico.som@gmail.com', 'name': 'septume'},
#      'message': 'Fin première partie du projet',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Septume/Hack-Block/commits/af77afba7497d755d92b24e01c146bd380e9c67e'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979659',
#   'type': 'CreateEvent',
#   'actor': {'id': 102275200,
#    'login': 'Burzhir',
#    'display_login': 'Burzhir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Burzhir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102275200?'},
#   'repo': {'id': 510691281,
#    'name': 'Burzhir/git_test',
#    'url': 'https://api.github.com/repos/Burzhir/git_test'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'first git proj',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979654',
#   'type': 'DeleteEvent',
#   'actor': {'id': 53283457,
#    'login': 'ShaktiAhad',
#    'display_login': 'ShaktiAhad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ShaktiAhad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53283457?'},
#   'repo': {'id': 505905136,
#    'name': 'ShaktiAhad/Automation',
#    'url': 'https://api.github.com/repos/ShaktiAhad/Automation'},
#   'payload': {'ref': 'v0.0.2', 'ref_type': 'tag', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979603',
#   'type': 'IssuesEvent',
#   'actor': {'id': 89514509,
#    'login': 'isabellechanclou',
#    'display_login': 'isabellechanclou',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/isabellechanclou',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/89514509?'},
#   'repo': {'id': 46706968,
#    'name': 'Orange-OpenSource/Orange-Boosted-Bootstrap',
#    'url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357',
#     'repository_url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap',
#     'labels_url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357/comments',
#     'events_url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357/events',
#     'html_url': 'https://github.com/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357',
#     'id': 1294116083,
#     'node_id': 'I_kwDOAsixGM5NIqTz',
#     'number': 1357,
#     'title': 'Docs > Content > Tables > With icons or thumbnails : Fix column height when contains an icon',
#     'user': {'login': 'isabellechanclou',
#      'id': 89514509,
#      'node_id': 'MDQ6VXNlcjg5NTE0NTA5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/89514509?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/isabellechanclou',
#      'html_url': 'https://github.com/isabellechanclou',
#      'followers_url': 'https://api.github.com/users/isabellechanclou/followers',
#      'following_url': 'https://api.github.com/users/isabellechanclou/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/isabellechanclou/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/isabellechanclou/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/isabellechanclou/subscriptions',
#      'organizations_url': 'https://api.github.com/users/isabellechanclou/orgs',
#      'repos_url': 'https://api.github.com/users/isabellechanclou/repos',
#      'events_url': 'https://api.github.com/users/isabellechanclou/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/isabellechanclou/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 290426382,
#       'node_id': 'MDU6TGFiZWwyOTA0MjYzODI=',
#       'url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/labels/bug',
#       'name': 'bug',
#       'color': 'fc2929',
#       'default': True,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2022-07-05T10:37:02Z',
#     'updated_at': '2022-07-05T10:37:02Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'body': '### Prerequisites\n\n- [X] I have [searched](https://github.com/Orange-OpenSource/Orange-Boosted-Bootstrap/issues?utf8=%E2%9C%93&q=is%3Aissue) for duplicate or closed issues\n- [X] I have [validated](https://html5.validator.nu/) any HTML to avoid common problems\n- [X] I have read the [contributing guidelines](https://github.com/Orange-OpenSource/Orange-Boosted-Bootstrap/blob/main/.github/CONTRIBUTING.md)\n\n### Describe the issue\n\nThis issue comes from the work done in Issue https://github.com/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1201 List in all the doc the incompatibility with ODS in which all Boosted components (variants included) have been inspected in order to identify the ones that do not respect ODS specifications and therefore need an alert message saying "Do not use in ODS".\r\nDoing this work, design bugs were noticed.\r\n\r\n**Design bug to be corrected**:\r\n- docs/v5.2/content/tables/with-icons-or-thumbnails:\r\n    - Lines with icons shall have a 40 px height when lines with thumbnails shall have a 50 px height. At the moment, both contents (icons and thumbnails) are in the same table, with a unique line height of 50px. To fix that, split the existing table into 2 different ones : one containing only icons and the other one containing only thumbnails. \r\nCheck that the line height will auto adjust depending on its content and then have the expected height. Otherwise, change the way it\'s coded.\r\nSuch modifications are OK for they impact Boosted only content.\n\n### Reduced test cases\n\nNA\n\n### What operating system(s) are you seeing the problem on?\n\nmacOS\n\n### What browser(s) are you seeing the problem on?\n\nChrome\n\n### What version of Boosted are you using?\n\nv5.1',
#     'reactions': {'url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/Orange-OpenSource/Orange-Boosted-Bootstrap/issues/1357/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z',
#   'org': {'id': 1506386,
#    'login': 'Orange-OpenSource',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Orange-OpenSource',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1506386?'}},
#  {'id': '22700979626',
#   'type': 'CreateEvent',
#   'actor': {'id': 63976300,
#    'login': 'joey-cracky',
#    'display_login': 'joey-cracky',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joey-cracky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63976300?'},
#   'repo': {'id': 510688037,
#    'name': 'joey-cracky/Images-gallery',
#    'url': 'https://api.github.com/repos/joey-cracky/Images-gallery'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Full stack application based on React and Python Flask',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979613',
#   'type': 'PushEvent',
#   'actor': {'id': 100749559,
#    'login': 'ning1604',
#    'display_login': 'ning1604',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ning1604',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100749559?'},
#   'repo': {'id': 510278964,
#    'name': 'dark40/cocktail-recipe-party-activity',
#    'url': 'https://api.github.com/repos/dark40/cocktail-recipe-party-activity'},
#   'payload': {'push_id': 10348820740,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/search-bar',
#    'head': '803c00a75611971da009a86aa7a45782721d87cd',
#    'before': '3ca9f745f072255f6551681b5c6262ee552f3d97',
#    'commits': [{'sha': '803c00a75611971da009a86aa7a45782721d87cd',
#      'author': {'email': 'ningzhawb@gmail.com', 'name': 'Ning'},
#      'message': 'removed bootstrap framework',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dark40/cocktail-recipe-party-activity/commits/803c00a75611971da009a86aa7a45782721d87cd'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979612',
#   'type': 'PushEvent',
#   'actor': {'id': 101706296,
#    'login': 'shahidCME',
#    'display_login': 'shahidCME',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shahidCME',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101706296?'},
#   'repo': {'id': 468718992,
#    'name': 'pratikcme/stagging',
#    'url': 'https://api.github.com/repos/pratikcme/stagging'},
#   'payload': {'push_id': 10348820779,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': '55c52a09358a417b2fd0b308bdd1389d680248e2',
#    'before': '9d76c611d01f102e185cb0612a5b99ac7d0df833',
#    'commits': [{'sha': '55c52a09358a417b2fd0b308bdd1389d680248e2',
#      'author': {'email': 'sahid.cmexpertise@gmail.com', 'name': 'shahidCME'},
#      'message': 'Update Product_model.php',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pratikcme/stagging/commits/55c52a09358a417b2fd0b308bdd1389d680248e2'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979596',
#   'type': 'PushEvent',
#   'actor': {'id': 43172514,
#    'login': 'qiu-tian01',
#    'display_login': 'qiu-tian01',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qiu-tian01',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43172514?'},
#   'repo': {'id': 406018136,
#    'name': 'qiu-tian01/fe_study_project',
#    'url': 'https://api.github.com/repos/qiu-tian01/fe_study_project'},
#   'payload': {'push_id': 10348820763,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '317e7d3a450a5911b3a7306da348cfc550d5b5e6',
#    'before': '552e22163c6357ef5e7c30ff4cd18c151196b1da',
#    'commits': [{'sha': '317e7d3a450a5911b3a7306da348cfc550d5b5e6',
#      'author': {'email': '', 'name': 'qiutian'},
#      'message': '增加video和audio笔记',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/qiu-tian01/fe_study_project/commits/317e7d3a450a5911b3a7306da348cfc550d5b5e6'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979602',
#   'type': 'PushEvent',
#   'actor': {'id': 45274640,
#    'login': 'partiid',
#    'display_login': 'partiid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/partiid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45274640?'},
#   'repo': {'id': 510313975,
#    'name': 'partiid/omnibusDirective',
#    'url': 'https://api.github.com/repos/partiid/omnibusDirective'},
#   'payload': {'push_id': 10348820776,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '2848314eb1e2bc10afdd03c3709855595c48056c',
#    'before': '3317fb00e8b3bc4f43ab3f791a7e8f61bf4168ca',
#    'commits': [{'sha': '2848314eb1e2bc10afdd03c3709855595c48056c',
#      'author': {'email': 'sarkowag@gmail.com', 'name': 'partiid'},
#      'message': 'fix vardump',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/partiid/omnibusDirective/commits/2848314eb1e2bc10afdd03c3709855595c48056c'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979624',
#   'type': 'PushEvent',
#   'actor': {'id': 93263998,
#    'login': 'boyslxj',
#    'display_login': 'boyslxj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/boyslxj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/93263998?'},
#   'repo': {'id': 510678812,
#    'name': 'boyslxj/MMS',
#    'url': 'https://api.github.com/repos/boyslxj/MMS'},
#   'payload': {'push_id': 10348820760,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '25f7a2fcc375ac340b0895d700f6022b275d06dc',
#    'before': '45103f7681a3cc9ee946df5a1722f6a221810a67',
#    'commits': [{'sha': '25f7a2fcc375ac340b0895d700f6022b275d06dc',
#      'author': {'email': '93263998+boyslxj@users.noreply.github.com',
#       'name': 'boyslxj'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/boyslxj/MMS/commits/25f7a2fcc375ac340b0895d700f6022b275d06dc'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979599',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 10947344,
#    'login': 'Kwasow',
#    'display_login': 'Kwasow',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kwasow',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10947344?'},
#   'repo': {'id': 130961487,
#    'name': 'software-mansion/react-native-reanimated',
#    'url': 'https://api.github.com/repos/software-mansion/react-native-reanimated'},
#   'payload': {'action': 'opened',
#    'number': 3363,
#    'pull_request': {'url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/3363',
#     'id': 987272304,
#     'node_id': 'PR_kwDOB85QT8462JRw',
#     'html_url': 'https://github.com/software-mansion/react-native-reanimated/pull/3363',
#     'diff_url': 'https://github.com/software-mansion/react-native-reanimated/pull/3363.diff',
#     'patch_url': 'https://github.com/software-mansion/react-native-reanimated/pull/3363.patch',
#     'issue_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/3363',
#     'number': 3363,
#     'state': 'open',
#     'locked': False,
#     'title': 'Added missing link and command in reanimated documentation',
#     'user': {'login': 'Kwasow',
#      'id': 10947344,
#      'node_id': 'MDQ6VXNlcjEwOTQ3MzQ0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/10947344?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Kwasow',
#      'html_url': 'https://github.com/Kwasow',
#      'followers_url': 'https://api.github.com/users/Kwasow/followers',
#      'following_url': 'https://api.github.com/users/Kwasow/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Kwasow/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Kwasow/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Kwasow/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Kwasow/orgs',
#      'repos_url': 'https://api.github.com/users/Kwasow/repos',
#      'events_url': 'https://api.github.com/users/Kwasow/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Kwasow/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '## Description\r\n\r\nThe `Install` section of the documentation was missing a link to the playground repo and a git clone command.\r\n\r\n## Changes\r\n\r\nThe link and command were added to the current documentation as well as version `2.5.x`.\r\n\r\n## Screenshots / GIFs\r\n\r\n<img width="979" alt="obraz" src="https://user-images.githubusercontent.com/10947344/177309686-23b16f5e-a5fb-4aee-b577-7fff39477a7f.png">\r\n\r\n## Test code and steps to reproduce\r\n\r\n`n/a`\r\n\r\n## Checklist\r\n\r\n- [ ] Included code example that can be used to test this change\r\n- [ ] Updated TS types\r\n- [ ] Added TS types tests\r\n- [ ] Added unit / integration tests\r\n- [ ] Updated documentation\r\n- [ ] Ensured that CI passes\r\n',
#     'created_at': '2022-07-05T10:37:02Z',
#     'updated_at': '2022-07-05T10:37:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/3363/commits',
#     'review_comments_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/3363/comments',
#     'review_comment_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/3363/comments',
#     'statuses_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/statuses/58d35f01b133b90f07b45a9b9d6696ddd1844a25',
#     'head': {'label': 'software-mansion:@kwasow/documentation_fix',
#      'ref': '@kwasow/documentation_fix',
#      'sha': '58d35f01b133b90f07b45a9b9d6696ddd1844a25',
#      'user': {'login': 'software-mansion',
#       'id': 56880679,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODgwNjc5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/56880679?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/software-mansion',
#       'html_url': 'https://github.com/software-mansion',
#       'followers_url': 'https://api.github.com/users/software-mansion/followers',
#       'following_url': 'https://api.github.com/users/software-mansion/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/software-mansion/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/software-mansion/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/software-mansion/subscriptions',
#       'organizations_url': 'https://api.github.com/users/software-mansion/orgs',
#       'repos_url': 'https://api.github.com/users/software-mansion/repos',
#       'events_url': 'https://api.github.com/users/software-mansion/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/software-mansion/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 130961487,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzA5NjE0ODc=',
#       'name': 'react-native-reanimated',
#       'full_name': 'software-mansion/react-native-reanimated',
#       'private': False,
#       'owner': {'login': 'software-mansion',
#        'id': 56880679,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODgwNjc5',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/56880679?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/software-mansion',
#        'html_url': 'https://github.com/software-mansion',
#        'followers_url': 'https://api.github.com/users/software-mansion/followers',
#        'following_url': 'https://api.github.com/users/software-mansion/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/software-mansion/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/software-mansion/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/software-mansion/subscriptions',
#        'organizations_url': 'https://api.github.com/users/software-mansion/orgs',
#        'repos_url': 'https://api.github.com/users/software-mansion/repos',
#        'events_url': 'https://api.github.com/users/software-mansion/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/software-mansion/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/software-mansion/react-native-reanimated',
#       'description': "React Native's Animated library reimplemented",
#       'fork': False,
#       'url': 'https://api.github.com/repos/software-mansion/react-native-reanimated',
#       'forks_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/forks',
#       'keys_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/teams',
#       'hooks_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/hooks',
#       'issue_events_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/events',
#       'assignees_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/tags',
#       'blobs_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/languages',
#       'stargazers_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/stargazers',
#       'contributors_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/contributors',
#       'subscribers_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/subscribers',
#       'subscription_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/subscription',
#       'commits_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/merges',
#       'archive_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/downloads',
#       'issues_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/deployments',
#       'created_at': '2018-04-25T06:35:29Z',
#       'updated_at': '2022-07-05T10:14:04Z',
#       'pushed_at': '2022-07-05T10:37:03Z',
#       'git_url': 'git://github.com/software-mansion/react-native-reanimated.git',
#       'ssh_url': 'git@github.com:software-mansion/react-native-reanimated.git',
#       'clone_url': 'https://github.com/software-mansion/react-native-reanimated.git',
#       'svn_url': 'https://github.com/software-mansion/react-native-reanimated',
#       'homepage': 'https://docs.swmansion.com/react-native-reanimated/',
#       'size': 82486,
#       'stargazers_count': 6253,
#       'watchers_count': 6253,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 898,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 238,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['animation', 'gesture', 'javascript', 'react-native'],
#       'visibility': 'public',
#       'forks': 898,
#       'open_issues': 238,
#       'watchers': 6253,
#       'default_branch': 'main'}},
#     'base': {'label': 'software-mansion:main',
#      'ref': 'main',
#      'sha': '930b2d1c15ff7e2a40009dfcc56e5c6a74679310',
#      'user': {'login': 'software-mansion',
#       'id': 56880679,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODgwNjc5',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/56880679?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/software-mansion',
#       'html_url': 'https://github.com/software-mansion',
#       'followers_url': 'https://api.github.com/users/software-mansion/followers',
#       'following_url': 'https://api.github.com/users/software-mansion/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/software-mansion/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/software-mansion/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/software-mansion/subscriptions',
#       'organizations_url': 'https://api.github.com/users/software-mansion/orgs',
#       'repos_url': 'https://api.github.com/users/software-mansion/repos',
#       'events_url': 'https://api.github.com/users/software-mansion/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/software-mansion/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 130961487,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzA5NjE0ODc=',
#       'name': 'react-native-reanimated',
#       'full_name': 'software-mansion/react-native-reanimated',
#       'private': False,
#       'owner': {'login': 'software-mansion',
#        'id': 56880679,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODgwNjc5',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/56880679?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/software-mansion',
#        'html_url': 'https://github.com/software-mansion',
#        'followers_url': 'https://api.github.com/users/software-mansion/followers',
#        'following_url': 'https://api.github.com/users/software-mansion/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/software-mansion/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/software-mansion/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/software-mansion/subscriptions',
#        'organizations_url': 'https://api.github.com/users/software-mansion/orgs',
#        'repos_url': 'https://api.github.com/users/software-mansion/repos',
#        'events_url': 'https://api.github.com/users/software-mansion/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/software-mansion/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/software-mansion/react-native-reanimated',
#       'description': "React Native's Animated library reimplemented",
#       'fork': False,
#       'url': 'https://api.github.com/repos/software-mansion/react-native-reanimated',
#       'forks_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/forks',
#       'keys_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/teams',
#       'hooks_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/hooks',
#       'issue_events_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/events',
#       'assignees_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/tags',
#       'blobs_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/languages',
#       'stargazers_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/stargazers',
#       'contributors_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/contributors',
#       'subscribers_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/subscribers',
#       'subscription_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/subscription',
#       'commits_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/merges',
#       'archive_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/downloads',
#       'issues_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/software-mansion/react-native-reanimated/deployments',
#       'created_at': '2018-04-25T06:35:29Z',
#       'updated_at': '2022-07-05T10:14:04Z',
#       'pushed_at': '2022-07-05T10:37:03Z',
#       'git_url': 'git://github.com/software-mansion/react-native-reanimated.git',
#       'ssh_url': 'git@github.com:software-mansion/react-native-reanimated.git',
#       'clone_url': 'https://github.com/software-mansion/react-native-reanimated.git',
#       'svn_url': 'https://github.com/software-mansion/react-native-reanimated',
#       'homepage': 'https://docs.swmansion.com/react-native-reanimated/',
#       'size': 82486,
#       'stargazers_count': 6253,
#       'watchers_count': 6253,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 898,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 238,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['animation', 'gesture', 'javascript', 'react-native'],
#       'visibility': 'public',
#       'forks': 898,
#       'open_issues': 238,
#       'watchers': 6253,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/3363'},
#      'html': {'href': 'https://github.com/software-mansion/react-native-reanimated/pull/3363'},
#      'issue': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/3363'},
#      'comments': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/issues/3363/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/3363/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/pulls/3363/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/software-mansion/react-native-reanimated/statuses/58d35f01b133b90f07b45a9b9d6696ddd1844a25'}},
#     'author_association': 'MEMBER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 10,
#     'deletions': 2,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z',
#   'org': {'id': 56880679,
#    'login': 'software-mansion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/software-mansion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56880679?'}},
#  {'id': '22700979590',
#   'type': 'WatchEvent',
#   'actor': {'id': 28755539,
#    'login': 'saeeddda',
#    'display_login': 'saeeddda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saeeddda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/28755539?'},
#   'repo': {'id': 415153802,
#    'name': 'pShariiati/EShop',
#    'url': 'https://api.github.com/repos/pShariiati/EShop'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979611',
#   'type': 'PushEvent',
#   'actor': {'id': 63638930,
#    'login': 'kornelkar',
#    'display_login': 'kornelkar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kornelkar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63638930?'},
#   'repo': {'id': 510690294,
#    'name': 'kornelkar/hello-word',
#    'url': 'https://api.github.com/repos/kornelkar/hello-word'},
#   'payload': {'push_id': 10348820743,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f524f9cb9360385c05f21c22f5c7b0462c49db1e',
#    'before': '47c68e1ea6552b110e53b852d79ef8138343bdab',
#    'commits': [{'sha': 'f524f9cb9360385c05f21c22f5c7b0462c49db1e',
#      'author': {'email': '63638930+kornelkar@users.noreply.github.com',
#       'name': 'Kornel Karasiński'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kornelkar/hello-word/commits/f524f9cb9360385c05f21c22f5c7b0462c49db1e'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979562',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 2306629,
#    'login': 'NateWr',
#    'display_login': 'NateWr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NateWr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2306629?'},
#   'repo': {'id': 316712,
#    'name': 'pkp/pkp-lib',
#    'url': 'https://api.github.com/repos/pkp/pkp-lib'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/pkp/pkp-lib/pulls/comments/913648647',
#     'pull_request_review_id': 1028419011,
#     'id': 913648647,
#     'node_id': 'PRRC_kwDOAATVKM42dSwH',
# ...
#      'sha': '6d277757d6f4193e837d743969027fa43aabe64b',
#      'user': {'login': 'Sekisback',
#       'id': 24872777,
#       'node_id': 'MDQ6VXNlcjI0ODcyNzc3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/24872777?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Sekisback',
#       'html_url': 'https://github.com/Sekisback',
#       'followers_url': 'https://api.github.com/users/Sekisback/followers',
#       'following_url': 'https://api.github.com/users/Sekisback/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Sekisback/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Sekisback/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Sekisback/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Sekisback/orgs',
#       'repos_url': 'https://api.github.com/users/Sekisback/repos',
#       'events_url': 'https://api.github.com/users/Sekisback/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Sekisback/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 323350564,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjMzNTA1NjQ=',
#       'name': 'OctoDash',
#       'full_name': 'Sekisback/OctoDash',
#       'private': False,
#       'owner': {'login': 'Sekisback',
#        'id': 24872777,
#        'node_id': 'MDQ6VXNlcjI0ODcyNzc3',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/24872777?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Sekisback',
#        'html_url': 'https://github.com/Sekisback',
#        'followers_url': 'https://api.github.com/users/Sekisback/followers',
#        'following_url': 'https://api.github.com/users/Sekisback/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Sekisback/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Sekisback/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Sekisback/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Sekisback/orgs',
#        'repos_url': 'https://api.github.com/users/Sekisback/repos',
#        'events_url': 'https://api.github.com/users/Sekisback/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Sekisback/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Sekisback/OctoDash',
#       'description': 'OctoDash is a simple, but beautiful dashboard for OctoPrint.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Sekisback/OctoDash',
#       'forks_url': 'https://api.github.com/repos/Sekisback/OctoDash/forks',
#       'keys_url': 'https://api.github.com/repos/Sekisback/OctoDash/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Sekisback/OctoDash/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Sekisback/OctoDash/teams',
#       'hooks_url': 'https://api.github.com/repos/Sekisback/OctoDash/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Sekisback/OctoDash/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Sekisback/OctoDash/events',
#       'assignees_url': 'https://api.github.com/repos/Sekisback/OctoDash/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Sekisback/OctoDash/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Sekisback/OctoDash/tags',
#       'blobs_url': 'https://api.github.com/repos/Sekisback/OctoDash/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Sekisback/OctoDash/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Sekisback/OctoDash/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Sekisback/OctoDash/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Sekisback/OctoDash/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Sekisback/OctoDash/languages',
#       'stargazers_url': 'https://api.github.com/repos/Sekisback/OctoDash/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Sekisback/OctoDash/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Sekisback/OctoDash/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Sekisback/OctoDash/subscription',
#       'commits_url': 'https://api.github.com/repos/Sekisback/OctoDash/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Sekisback/OctoDash/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Sekisback/OctoDash/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Sekisback/OctoDash/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Sekisback/OctoDash/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Sekisback/OctoDash/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Sekisback/OctoDash/merges',
#       'archive_url': 'https://api.github.com/repos/Sekisback/OctoDash/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Sekisback/OctoDash/downloads',
#       'issues_url': 'https://api.github.com/repos/Sekisback/OctoDash/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Sekisback/OctoDash/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Sekisback/OctoDash/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Sekisback/OctoDash/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Sekisback/OctoDash/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Sekisback/OctoDash/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Sekisback/OctoDash/deployments',
#       'created_at': '2020-12-21T13:53:55Z',
#       'updated_at': '2021-12-22T14:22:00Z',
#       'pushed_at': '2022-07-05T10:36:59Z',
#       'git_url': 'git://github.com/Sekisback/OctoDash.git',
#       'ssh_url': 'git@github.com:Sekisback/OctoDash.git',
#       'clone_url': 'https://github.com/Sekisback/OctoDash.git',
#       'svn_url': 'https://github.com/Sekisback/OctoDash',
#       'homepage': 'https://unchartedbull.github.io/OctoDash/index.html',
#       'size': 120865,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 15,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 15,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/pulls/246'},
#      'html': {'href': 'https://github.com/Sekisback/OctoDash/pull/246'},
#      'issue': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/issues/246'},
#      'comments': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/issues/246/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/pulls/246/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/pulls/246/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Sekisback/OctoDash/statuses/b9599617cb0a1f016153bb6093096d64ab72e019'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 2,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 387,
#     'deletions': 67,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979477',
#   'type': 'PushEvent',
#   'actor': {'id': 26987622,
#    'login': 'bj-white',
#    'display_login': 'bj-white',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bj-white',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26987622?'},
#   'repo': {'id': 510688028,
#    'name': 'bj-white/open-portal',
#    'url': 'https://api.github.com/repos/bj-white/open-portal'},
#   'payload': {'push_id': 10348820678,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '80ce16fb48ab7b48d32ca3224cc724642f7210a1',
#    'before': 'c480e032e4d3e0eb39e98f6d3c26ef7a5d028a30',
#    'commits': [{'sha': '80ce16fb48ab7b48d32ca3224cc724642f7210a1',
#      'author': {'email': 'baiww@glodon.com', 'name': 'GRANDSOFT\\baiww'},
#      'message': 'dsad',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bj-white/open-portal/commits/80ce16fb48ab7b48d32ca3224cc724642f7210a1'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979463',
#   'type': 'PushEvent',
#   'actor': {'id': 99116502,
#    'login': 'kglidiya',
#    'display_login': 'kglidiya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kglidiya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99116502?'},
#   'repo': {'id': 467540567,
#    'name': 'kglidiya/mesto-project',
#    'url': 'https://api.github.com/repos/kglidiya/mesto-project'},
#   'payload': {'push_id': 10348820708,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '276620f525037e33640bc0c0aa2f833c8dbd7bd2',
#    'before': 'd6291667bfb1929cf1ea4498969d9ceebef971d1',
#    'commits': [{'sha': '276620f525037e33640bc0c0aa2f833c8dbd7bd2',
#      'author': {'email': 'betysmith@yandex.ru', 'name': 'kglidiya'},
#      'message': 'Updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kglidiya/mesto-project/commits/276620f525037e33640bc0c0aa2f833c8dbd7bd2'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979445',
#   'type': 'CreateEvent',
#   'actor': {'id': 108721656,
#    'login': 'naba87',
#    'display_login': 'naba87',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/naba87',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/108721656?'},
#   'repo': {'id': 510639887,
#    'name': 'naba87/Naba-ORT',
#    'url': 'https://api.github.com/repos/naba87/Naba-ORT'},
#   'payload': {'ref': 'add-declared-python',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979450',
#   'type': 'CreateEvent',
#   'actor': {'id': 102275200,
#    'login': 'Burzhir',
#    'display_login': 'Burzhir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Burzhir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102275200?'},
#   'repo': {'id': 510691281,
#    'name': 'Burzhir/git_test',
#    'url': 'https://api.github.com/repos/Burzhir/git_test'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'first git proj',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z'},
#  {'id': '22700979482',
#   'type': 'PushEvent',
#   'actor': {'id': 54338069,
#    'login': 'vanminh1701',
#    'display_login': 'vanminh1701',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vanminh1701',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54338069?'},
#   'repo': {'id': 465620193,
#    'name': 'LIQNFT/candy-shop',
#    'url': 'https://api.github.com/repos/LIQNFT/candy-shop'},
#   'payload': {'push_id': 10348820698,
#    'size': 9,
#    'distinct_size': 1,
#    'ref': 'refs/heads/core/improve-filter-orders',
#    'head': 'd921622c595ea9df67738349f7582039ba80491b',
#    'before': '6ea6d74f01df864a0412d0177f16ab43ebe268a0',
#    'commits': [{'sha': 'd6f5c6a83ff71086bd8b1c4108d5ed5a06098b64',
#      'author': {'email': '93598467+RustySol@users.noreply.github.com',
#       'name': 'RustySol'},
#      'message': 'Bump core [ui] version (#271)\n\n@liqnft/candy-shop -> 0.5.6',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/d6f5c6a83ff71086bd8b1c4108d5ed5a06098b64'},
#     {'sha': 'e88a39740dcc04bf6fe3f2890f20f79100eb3f1c',
#      'author': {'email': '89616076+beepsaidblue@users.noreply.github.com',
#       'name': 'solmaker'},
#      'message': '[chore] add licenses (#269)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/e88a39740dcc04bf6fe3f2890f20f79100eb3f1c'},
#     {'sha': '50433feeef4438a71e921c153228cfda4c4585b4',
#      'author': {'email': '93598467+RustySol@users.noreply.github.com',
#       'name': 'RustySol'},
#      'message': 'Bump core [types] [sdk] [ui] version (#272)\n\n@liqnft/candy-shop-types -> 0.2.10\r\n@liqnft/candy-shop-sdk -> 0.5.11\r\n@liqnft/candy-shop -> 0.5.7',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/50433feeef4438a71e921c153228cfda4c4585b4'},
#     {'sha': 'a5011125fc575e8547398f34e9d1fa069ee88b86',
#      'author': {'email': '93598467+RustySol@users.noreply.github.com',
#       'name': 'RustySol'},
#      'message': 'Bump core [ui] version and add dep on candy-shop-types (#274)\n\n@liqnft/candy-shop -> 0.5.8',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/a5011125fc575e8547398f34e9d1fa069ee88b86'},
#     {'sha': '0d7281b2f723560e4b516b50d7272414219c6788',
#      'author': {'email': '62431052+vuvu2259@users.noreply.github.com',
#       'name': 'Teddy'},
#      'message': '[core/ui] LIQ-558 Expose Buy/Sell/Cancel Modal UI components in core/ui (#255)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/0d7281b2f723560e4b516b50d7272414219c6788'},
#     {'sha': 'c700db9eb2f54a55df381592cace7644702d3df9',
#      'author': {'email': '11007204+haVincy@users.noreply.github.com',
#       'name': 'SoloVerse(Wen)'},
#      'message': '[core] Update publish.sh for ui to update @liqnft/candy-shop-types (#275)\n\nAdd git tag in make_release_commit.sh',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/c700db9eb2f54a55df381592cace7644702d3df9'},
#     {'sha': 'e21a138aa89b3e2022b9f30b18248aa01070a0d8',
#      'author': {'email': 'tvminh1701@gmail.com', 'name': 'Minh'},
#      'message': 'LIQ-667 error when create, cancel auction with programId v2 (#277)\n\nCo-authored-by: tvminh <van-minh.tran@spiritlabs.co>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/e21a138aa89b3e2022b9f30b18248aa01070a0d8'},
#     {'sha': '637ca8050ad93ef116e8a8b529dfb3b3d34ac079',
#      'author': {'email': 'tvminh1701@gmail.com', 'name': 'Minh'},
#      'message': 'fix: wrong baseURl when calling api from sdk (#276)\n\nCo-authored-by: tvminh <van-minh.tran@spiritlabs.co>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/637ca8050ad93ef116e8a8b529dfb3b3d34ac079'},
#     {'sha': 'd921622c595ea9df67738349f7582039ba80491b',
#      'author': {'email': 'van-minh.tran@spiritlabs.co', 'name': 'tvminh'},
#      'message': 'LIQ-656 improve filter LIQNFT\n\nuncomment\n\nadd shop filter\n\nadd search hardcode\n\nbug\n\nupdate comment\n\nremove CollectionAPI file\n\nupdate file import',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LIQNFT/candy-shop/commits/d921622c595ea9df67738349f7582039ba80491b'}]},
#   'public': True,
#   'created_at': '2022-07-05T10:37:03Z',
#   'org': {'id': 96943769,
#    'login': 'LIQNFT',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/LIQNFT',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/96943769?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                           type  \
# 0   22700979708              IssueCommentEvent
# 1   22700979608                      PushEvent
# 2   22700979679                      PushEvent
# 3   22700979659                    CreateEvent
# 4   22700979654                    DeleteEvent
# 5   22700979603                    IssuesEvent
# 6   22700979626                    CreateEvent
# 7   22700979613                      PushEvent
# 8   22700979612                      PushEvent
# 9   22700979596                      PushEvent
# 10  22700979602                      PushEvent
# 11  22700979624                      PushEvent
# 12  22700979599               PullRequestEvent
# 13  22700979590                     WatchEvent
# 14  22700979611                      PushEvent
# 15  22700979562  PullRequestReviewCommentEvent
# 16  22700979600                    IssuesEvent
# 17  22700979571               PullRequestEvent
# 18  22700979563         PullRequestReviewEvent
# 19  22700979512               PullRequestEvent
# 20  22700979546                      PushEvent
# 21  22700979517                    IssuesEvent
# 22  22700979566               PullRequestEvent
# 23  22700979522               PullRequestEvent
# 24  22700979510               PullRequestEvent
# 25  22700979477                      PushEvent
# 26  22700979463                      PushEvent
# 27  22700979445                    CreateEvent
# 28  22700979450                    CreateEvent
# 29  22700979482                      PushEvent
#
#                                                 actor  \
# 0   {'id': 273120, 'login': 'tsteur', 'display_log...
# 1   {'id': 53743348, 'login': 'Tim-Abwao', 'displa...
# 2   {'id': 103568586, 'login': 'Septume', 'display...
# 3   {'id': 102275200, 'login': 'Burzhir', 'display...
# 4   {'id': 53283457, 'login': 'ShaktiAhad', 'displ...
# 5   {'id': 89514509, 'login': 'isabellechanclou', ...
# 6   {'id': 63976300, 'login': 'joey-cracky', 'disp...
# 7   {'id': 100749559, 'login': 'ning1604', 'displa...
# 8   {'id': 101706296, 'login': 'shahidCME', 'displ...
# 9   {'id': 43172514, 'login': 'qiu-tian01', 'displ...
# 10  {'id': 45274640, 'login': 'partiid', 'display_...
# 11  {'id': 93263998, 'login': 'boyslxj', 'display_...
# 12  {'id': 10947344, 'login': 'Kwasow', 'display_l...
# 13  {'id': 28755539, 'login': 'saeeddda', 'display...
# 14  {'id': 63638930, 'login': 'kornelkar', 'displa...
# 15  {'id': 2306629, 'login': 'NateWr', 'display_lo...
# 16  {'id': 2373721, 'login': 'MarkRS-UK', 'display...
# 17  {'id': 98512765, 'login': 'cosmin-oros', 'disp...
# 18  {'id': 2306629, 'login': 'NateWr', 'display_lo...
# 19  {'id': 41898282, 'login': 'github-actions[bot]...
# 20  {'id': 99489321, 'login': 'chhavid', 'display_...
# 21  {'id': 23722609, 'login': 'NiallRees', 'displa...
# 22  {'id': 84051498, 'login': 'EvanCWoods', 'displ...
# 23  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 24  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 25  {'id': 26987622, 'login': 'bj-white', 'display...
# 26  {'id': 99116502, 'login': 'kglidiya', 'display...
# 27  {'id': 108721656, 'login': 'naba87', 'display_...
# 28  {'id': 102275200, 'login': 'Burzhir', 'display...
# 29  {'id': 54338069, 'login': 'vanminh1701', 'disp...
#
#                                                  repo  \
# 0   {'id': 1548202, 'name': 'matomo-org/matomo', '...
# 1   {'id': 332031682, 'name': 'Tim-Abwao/blog-proj...
# 2   {'id': 510019323, 'name': 'Septume/Hack-Block'...
# 3   {'id': 510691281, 'name': 'Burzhir/git_test', ...
# 4   {'id': 505905136, 'name': 'ShaktiAhad/Automati...
# 5   {'id': 46706968, 'name': 'Orange-OpenSource/Or...
# 6   {'id': 510688037, 'name': 'joey-cracky/Images-...
# 7   {'id': 510278964, 'name': 'dark40/cocktail-rec...
# 8   {'id': 468718992, 'name': 'pratikcme/stagging'...
# 9   {'id': 406018136, 'name': 'qiu-tian01/fe_study...
# 10  {'id': 510313975, 'name': 'partiid/omnibusDire...
# 11  {'id': 510678812, 'name': 'boyslxj/MMS', 'url'...
# 12  {'id': 130961487, 'name': 'software-mansion/re...
# 13  {'id': 415153802, 'name': 'pShariiati/EShop', ...
# 14  {'id': 510690294, 'name': 'kornelkar/hello-wor...
# 15  {'id': 316712, 'name': 'pkp/pkp-lib', 'url': '...
# 16  {'id': 210767979, 'name': 'icerockdev/moko-tem...
# 17  {'id': 505395940, 'name': 'Capybara-Dev-Team/P...
# 18  {'id': 316712, 'name': 'pkp/pkp-lib', 'url': '...
# 19  {'id': 418848852, 'name': 'WolseyBankWitness/r...
# 20  {'id': 510264491, 'name': 'chhavid/Flip-Cards'...
# 21  {'id': 53548867, 'name': 'dbt-labs/dbt-core', ...
# 22  {'id': 505759840, 'name': 'EvanCWoods/Supermar...
# 23  {'id': 414534379, 'name': 'gramedia-digital-nu...
# 24  {'id': 323350564, 'name': 'Sekisback/OctoDash'...
# 25  {'id': 510688028, 'name': 'bj-white/open-porta...
# 26  {'id': 467540567, 'name': 'kglidiya/mesto-proj...
# 27  {'id': 510639887, 'name': 'naba87/Naba-ORT', '...
# 28  {'id': 510691281, 'name': 'Burzhir/git_test', ...
# 29  {'id': 465620193, 'name': 'LIQNFT/candy-shop',...
#
#                                               payload  public  \
# 0   {'action': 'created', 'issue': {'url': 'https:...    True
# 1   {'push_id': 10348820747, 'size': 1, 'distinct_...    True
# 2   {'push_id': 10348820811, 'size': 1, 'distinct_...    True
# 3   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 4   {'ref': 'v0.0.2', 'ref_type': 'tag', 'pusher_t...    True
# 5   {'action': 'opened', 'issue': {'url': 'https:/...    True
# 6   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 7   {'push_id': 10348820740, 'size': 1, 'distinct_...    True
# 8   {'push_id': 10348820779, 'size': 1, 'distinct_...    True
# 9   {'push_id': 10348820763, 'size': 1, 'distinct_...    True
# 10  {'push_id': 10348820776, 'size': 1, 'distinct_...    True
# 11  {'push_id': 10348820760, 'size': 1, 'distinct_...    True
# 12  {'action': 'opened', 'number': 3363, 'pull_req...    True
# 13                              {'action': 'started'}    True
# 14  {'push_id': 10348820743, 'size': 1, 'distinct_...    True
# 15  {'action': 'created', 'comment': {'url': 'http...    True
# 16  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 17  {'action': 'closed', 'number': 36, 'pull_reque...    True
# 18  {'action': 'created', 'review': {'id': 1028419...    True
# 19  {'action': 'closed', 'number': 238749, 'pull_r...    True
# 20  {'push_id': 10348820723, 'size': 1, 'distinct_...    True
# 21  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 22  {'action': 'closed', 'number': 2, 'pull_reques...    True
# 23  {'action': 'closed', 'number': 129, 'pull_requ...    True
# 24  {'action': 'closed', 'number': 246, 'pull_requ...    True
# 25  {'push_id': 10348820678, 'size': 1, 'distinct_...    True
# 26  {'push_id': 10348820708, 'size': 1, 'distinct_...    True
# 27  {'ref': 'add-declared-python', 'ref_type': 'br...    True
# 28  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 29  {'push_id': 10348820698, 'size': 9, 'distinct_...    True
#
#               created_at                                                org
# 0   2022-07-05T10:37:03Z  {'id': 698038, 'login': 'matomo-org', 'gravata...
# 1   2022-07-05T10:37:03Z                                                NaN
# 2   2022-07-05T10:37:03Z                                                NaN
# 3   2022-07-05T10:37:03Z                                                NaN
# 4   2022-07-05T10:37:03Z                                                NaN
# 5   2022-07-05T10:37:03Z  {'id': 1506386, 'login': 'Orange-OpenSource', ...
# 6   2022-07-05T10:37:03Z                                                NaN
# 7   2022-07-05T10:37:03Z                                                NaN
# 8   2022-07-05T10:37:03Z                                                NaN
# 9   2022-07-05T10:37:03Z                                                NaN
# 10  2022-07-05T10:37:03Z                                                NaN
# 11  2022-07-05T10:37:03Z                                                NaN
# 12  2022-07-05T10:37:03Z  {'id': 56880679, 'login': 'software-mansion', ...
# 13  2022-07-05T10:37:03Z                                                NaN
# 14  2022-07-05T10:37:03Z                                                NaN
# 15  2022-07-05T10:37:02Z  {'id': 130896, 'login': 'pkp', 'gravatar_id': ...
# 16  2022-07-05T10:37:03Z  {'id': 16201791, 'login': 'icerockdev', 'grava...
# 17  2022-07-05T10:37:03Z  {'id': 107308513, 'login': 'Capybara-Dev-Team'...
# 18  2022-07-05T10:37:03Z  {'id': 130896, 'login': 'pkp', 'gravatar_id': ...
# 19  2022-07-05T10:37:03Z                                                NaN
# 20  2022-07-05T10:37:03Z                                                NaN
# 21  2022-07-05T10:37:03Z  {'id': 18339788, 'login': 'dbt-labs', 'gravata...
# 22  2022-07-05T10:37:03Z                                                NaN
# 23  2022-07-05T10:37:03Z  {'id': 26515514, 'login': 'gramedia-digital-nu...
# 24  2022-07-05T10:37:03Z                                                NaN
# 25  2022-07-05T10:37:03Z                                                NaN
# 26  2022-07-05T10:37:03Z                                                NaN
# 27  2022-07-05T10:37:03Z                                                NaN
# 28  2022-07-05T10:37:03Z                                                NaN
# 29  2022-07-05T10:37:03Z  {'id': 96943769, 'login': 'LIQNFT', 'gravatar_...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id               type  public            created_at   actor.id  \
# 0   21475092000          PushEvent    True  2022-04-26T13:03:15Z   38650337
# 1   21475090914          PushEvent    True  2022-04-26T13:03:12Z  101595139
# 2   21475091289          PushEvent    True  2022-04-26T13:03:13Z   76687631
# 3   21475092014          PushEvent    True  2022-04-26T13:03:15Z    8057368
# 4   21475091288          PushEvent    True  2022-04-26T13:03:13Z   89585989
# 5   21475091635          PushEvent    True  2022-04-26T13:03:14Z    8084401
# 6   21475091981         WatchEvent    True  2022-04-26T13:03:15Z   18066733
# 7   21475091965   PullRequestEvent    True  2022-04-26T13:03:15Z   45442278
# 8   21475091652          PushEvent    True  2022-04-26T13:03:14Z  104293240
# 9   21475092332          PushEvent    True  2022-04-26T13:03:16Z  102516149
# 10  21475091638        IssuesEvent    True  2022-04-26T13:03:14Z   86326137
# 11  21475092287          PushEvent    True  2022-04-26T13:03:16Z   15671329
# 12  21475092660        CreateEvent    True  2022-04-26T13:03:17Z   49699333
# 13  21475091574          PushEvent    True  2022-04-26T13:03:14Z   41898282
# 14  21475092312   PullRequestEvent    True  2022-04-26T13:03:16Z   18140164
# 15  21475091596          PushEvent    True  2022-04-26T13:03:14Z   20303122
# 16  21475092654   PullRequestEvent    True  2022-04-26T13:03:17Z    2614900
# 17  21475092619          PushEvent    True  2022-04-26T13:03:17Z   10129688
# 18  21475092309          PushEvent    True  2022-04-26T13:03:16Z   12523742
# 19  21475091603          PushEvent    True  2022-04-26T13:03:14Z  103194481
# 20  21475091938          PushEvent    True  2022-04-26T13:03:15Z    9757926
# 21  21475091948          PushEvent    True  2022-04-26T13:03:15Z   41898282
# 22  21475092271          PushEvent    True  2022-04-26T13:03:16Z    9108538
# 23  21475091940          PushEvent    True  2022-04-26T13:03:15Z    2687598
# 24  21475091915  IssueCommentEvent    True  2022-04-26T13:03:15Z   40209326
# 25  21475091555        DeleteEvent    True  2022-04-26T13:03:14Z   71354125
# 26  21475091556        CreateEvent    True  2022-04-26T13:03:14Z   82694104
# 27  21475091507          PushEvent    True  2022-04-26T13:03:14Z   92665023
# 28  21475091875          PushEvent    True  2022-04-26T13:03:15Z   49699333
# 29  21475092222          PushEvent    True  2022-04-26T13:03:16Z   41898282
#
#                       actor.login       actor.display_login actor.gravatar_id  \
# 0                       Jambo2018                 Jambo2018
# 1                   Gransotto2002             Gransotto2002
# 2                     krithika117               krithika117
# 3                          monzta                    monzta
# 4                        Smrutthi                  Smrutthi
# 5                       famturiop                 famturiop
# 6                       chingdae1                 chingdae1
# 7                        tvardero                  tvardero
# 8                           ICTBg                     ICTBg
# 9                           shsto                     shsto
# 10                   bot-monkey-7              bot-monkey-7
# 11                           9dcw                      9dcw
# 12                dependabot[bot]                dependabot
# 13            github-actions[bot]            github-actions
# 14                        loaddss                   loaddss
# 15                          dvr16                     dvr16
# 16                        cyBerta                   cyBerta
# 17                        fanteos                   fanteos
# 18                    waittttting               waittttting
# 19                 KazantsevaJane            KazantsevaJane
# 20                       fsultani                  fsultani
# 21            github-actions[bot]            github-actions
# 22                          Annno                     Annno
# 23                      milesholt                 milesholt
# 24                   netlify[bot]                   netlify
# 25  aws-connector-for-github[bot]  aws-connector-for-github
# 26                   FateJacobson              FateJacobson
# 27                patilsayali9822           patilsayali9822
# 28                dependabot[bot]                dependabot
# 29            github-actions[bot]            github-actions
#
#                                             actor.url  \
# 0              https://api.github.com/users/Jambo2018
# 1          https://api.github.com/users/Gransotto2002
# 2            https://api.github.com/users/krithika117
# 3                 https://api.github.com/users/monzta
# 4               https://api.github.com/users/Smrutthi
# 5              https://api.github.com/users/famturiop
# 6              https://api.github.com/users/chingdae1
# 7               https://api.github.com/users/tvardero
# 8                  https://api.github.com/users/ICTBg
# 9                  https://api.github.com/users/shsto
# 10          https://api.github.com/users/bot-monkey-7
# 11                  https://api.github.com/users/9dcw
# 12       https://api.github.com/users/dependabot[bot]
# 13   https://api.github.com/users/github-actions[bot]
# 14               https://api.github.com/users/loaddss
# 15                 https://api.github.com/users/dvr16
# 16               https://api.github.com/users/cyBerta
# 17               https://api.github.com/users/fanteos
# 18           https://api.github.com/users/waittttting
# 19        https://api.github.com/users/KazantsevaJane
# 20              https://api.github.com/users/fsultani
# 21   https://api.github.com/users/github-actions[bot]
# 22                 https://api.github.com/users/Annno
# 23             https://api.github.com/users/milesholt
# 24          https://api.github.com/users/netlify[bot]
# 25  https://api.github.com/users/aws-connector-for...
# 26          https://api.github.com/users/FateJacobson
# 27       https://api.github.com/users/patilsayali9822
# 28       https://api.github.com/users/dependabot[bot]
# 29   https://api.github.com/users/github-actions[bot]
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/38650337?  ...
# 1   https://avatars.githubusercontent.com/u/101595...  ...
# 2   https://avatars.githubusercontent.com/u/76687631?  ...
# 3    https://avatars.githubusercontent.com/u/8057368?  ...
# 4   https://avatars.githubusercontent.com/u/89585989?  ...
# 5    https://avatars.githubusercontent.com/u/8084401?  ...
# 6   https://avatars.githubusercontent.com/u/18066733?  ...
# 7   https://avatars.githubusercontent.com/u/45442278?  ...
# 8   https://avatars.githubusercontent.com/u/104293...  ...
# 9   https://avatars.githubusercontent.com/u/102516...  ...
# 10  https://avatars.githubusercontent.com/u/86326137?  ...
# 11  https://avatars.githubusercontent.com/u/15671329?  ...
# 12  https://avatars.githubusercontent.com/u/49699333?  ...
# 13  https://avatars.githubusercontent.com/u/41898282?  ...
# 14  https://avatars.githubusercontent.com/u/18140164?  ...
# 15  https://avatars.githubusercontent.com/u/20303122?  ...
# 16   https://avatars.githubusercontent.com/u/2614900?  ...
# 17  https://avatars.githubusercontent.com/u/10129688?  ...
# 18  https://avatars.githubusercontent.com/u/12523742?  ...
# 19  https://avatars.githubusercontent.com/u/103194...  ...
# 20   https://avatars.githubusercontent.com/u/9757926?  ...
# 21  https://avatars.githubusercontent.com/u/41898282?  ...
# 22   https://avatars.githubusercontent.com/u/9108538?  ...
# 23   https://avatars.githubusercontent.com/u/2687598?  ...
# 24  https://avatars.githubusercontent.com/u/40209326?  ...
# 25  https://avatars.githubusercontent.com/u/71354125?  ...
# 26  https://avatars.githubusercontent.com/u/82694104?  ...
# 27  https://avatars.githubusercontent.com/u/92665023?  ...
# 28  https://avatars.githubusercontent.com/u/49699333?  ...
# 29  https://avatars.githubusercontent.com/u/41898282?  ...
#
#     payload.comment.reactions.total_count payload.comment.reactions.+1  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# 5                                     NaN                          NaN
# 6                                     NaN                          NaN
# 7                                     NaN                          NaN
# 8                                     NaN                          NaN
# 9                                     NaN                          NaN
# 10                                    NaN                          NaN
# 11                                    NaN                          NaN
# 12                                    NaN                          NaN
# 13                                    NaN                          NaN
# 14                                    NaN                          NaN
# 15                                    NaN                          NaN
# 16                                    NaN                          NaN
# 17                                    NaN                          NaN
# 18                                    NaN                          NaN
# 19                                    NaN                          NaN
# 20                                    NaN                          NaN
# 21                                    NaN                          NaN
# 22                                    NaN                          NaN
# 23                                    NaN                          NaN
# 24                                    0.0                          0.0
# 25                                    NaN                          NaN
# 26                                    NaN                          NaN
# 27                                    NaN                          NaN
# 28                                    NaN                          NaN
# 29                                    NaN                          NaN
#
#    payload.comment.reactions.-1  payload.comment.reactions.laugh  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# 5                           NaN                              NaN
# 6                           NaN                              NaN
# 7                           NaN                              NaN
# 8                           NaN                              NaN
# 9                           NaN                              NaN
# 10                          NaN                              NaN
# 11                          NaN                              NaN
# 12                          NaN                              NaN
# 13                          NaN                              NaN
# 14                          NaN                              NaN
# 15                          NaN                              NaN
# 16                          NaN                              NaN
# 17                          NaN                              NaN
# 18                          NaN                              NaN
# 19                          NaN                              NaN
# 20                          NaN                              NaN
# 21                          NaN                              NaN
# 22                          NaN                              NaN
# 23                          NaN                              NaN
# 24                          0.0                              0.0
# 25                          NaN                              NaN
# 26                          NaN                              NaN
# 27                          NaN                              NaN
# 28                          NaN                              NaN
# 29                          NaN                              NaN
#
#     payload.comment.reactions.hooray  payload.comment.reactions.confused  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
# 6                                NaN                                 NaN
# 7                                NaN                                 NaN
# 8                                NaN                                 NaN
# 9                                NaN                                 NaN
# 10                               NaN                                 NaN
# 11                               NaN                                 NaN
# 12                               NaN                                 NaN
# 13                               NaN                                 NaN
# 14                               NaN                                 NaN
# 15                               NaN                                 NaN
# 16                               NaN                                 NaN
# 17                               NaN                                 NaN
# 18                               NaN                                 NaN
# 19                               NaN                                 NaN
# 20                               NaN                                 NaN
# 21                               NaN                                 NaN
# 22                               NaN                                 NaN
# 23                               NaN                                 NaN
# 24                               0.0                                 0.0
# 25                               NaN                                 NaN
# 26                               NaN                                 NaN
# 27                               NaN                                 NaN
# 28                               NaN                                 NaN
# 29                               NaN                                 NaN
#
#    payload.comment.reactions.heart payload.comment.reactions.rocket  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# 5                              NaN                              NaN
# 6                              NaN                              NaN
# 7                              NaN                              NaN
# 8                              NaN                              NaN
# 9                              NaN                              NaN
# 10                             NaN                              NaN
# 11                             NaN                              NaN
# 12                             NaN                              NaN
# 13                             NaN                              NaN
# 14                             NaN                              NaN
# 15                             NaN                              NaN
# 16                             NaN                              NaN
# 17                             NaN                              NaN
# 18                             NaN                              NaN
# 19                             NaN                              NaN
# 20                             NaN                              NaN
# 21                             NaN                              NaN
# 22                             NaN                              NaN
# 23                             NaN                              NaN
# 24                             0.0                              0.0
# 25                             NaN                              NaN
# 26                             NaN                              NaN
# 27                             NaN                              NaN
# 28                             NaN                              NaN
# 29                             NaN                              NaN
#
#    payload.comment.reactions.eyes payload.comment.performed_via_github_app
# 0                             NaN                                      NaN
# 1                             NaN                                      NaN
# 2                             NaN                                      NaN
# 3                             NaN                                      NaN
# 4                             NaN                                      NaN
# 5                             NaN                                      NaN
# 6                             NaN                                      NaN
# 7                             NaN                                      NaN
# 8                             NaN                                      NaN
# 9                             NaN                                      NaN
# 10                            NaN                                      NaN
# 11                            NaN                                      NaN
# 12                            NaN                                      NaN
# 13                            NaN                                      NaN
# 14                            NaN                                      NaN
# 15                            NaN                                      NaN
# 16                            NaN                                      NaN
# 17                            NaN                                      NaN
# 18                            NaN                                      NaN
# 19                            NaN                                      NaN
# 20                            NaN                                      NaN
# 21                            NaN                                      NaN
# 22                            NaN                                      NaN
# 23                            NaN                                      NaN
# 24                            0.0                                      NaN
# 25                            NaN                                      NaN
# 26                            NaN                                      NaN
# 27                            NaN                                      NaN
# 28                            NaN                                      NaN
# 29                            NaN                                      NaN
#
# [30 rows x 438 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'timestamp': 1650978505,
#  'message': 'success',
#  'iss_position': {'longitude': '-111.7456', 'latitude': '49.4063'}}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1650978537,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 210, 'risetime': 1651022628},
#   {'duration': 580, 'risetime': 1651028180},
#   {'duration': 645, 'risetime': 1651033924},
#   {'duration': 652, 'risetime': 1651039720},
#   {'duration': 639, 'risetime': 1651045522}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')
