# %% [markdown]
# # Case Study: Customer Analysis Study [LAB] Week 2, Day 1,2

# %% [markdown]
# # Activites List
# It is highly encouraged to work in a group of two students for the lab of this case study.
# Important: for Activity 1, Activity 2 and Activity 3 , please use the files file1.csv, file2.csv and file3.csv from the Data folder.
# ## Activity 1 (Monday)

# %% [markdown]
# ### Aggregate data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

pd.options.display.max_rows = 100
## Install xlrd package to load Excel files
#!conda install openpyxl
#!conda install xlrd

# %%
file1 = pd.read_csv('Data/file1.csv')
file1.rename(columns={"ST":"state"}, inplace=True )
colFile1 = file1.columns.tolist()
print(colFile1)
# Out:
# ['Customer', 'state', 'GENDER', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']

# %%
file2 = pd.read_csv('Data/file2.csv')
file2.rename(columns={"ST":"state"}, inplace=True )

file2 = file2[colFile1]
file2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   996 non-null    object
#  1   state                      996 non-null    object
#  2   GENDER                     991 non-null    object
#  3   Education                  996 non-null    object
#  4   Customer Lifetime Value    992 non-null    object
#  5   Income                     996 non-null    int64
#  6   Monthly Premium Auto       996 non-null    int64
#  7   Number of Open Complaints  996 non-null    object
#  8   Policy Type                996 non-null    object
#  9   Vehicle Class              996 non-null    object
#  10  Total Claim Amount         996 non-null    float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
file3 = pd.read_csv('Data/file1.csv')
file3.rename(columns={"ST":"state","Gender":"GENDER"}, inplace=True )
file3 = file3[colFile1]
file3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   state                      1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
def load_original_data():
    return pd.concat([file1,file2,file3], axis=0)

complete_list = load_original_data()
complete_list
# Out:
#      Customer       state GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [9012 rows x 11 columns]

# %% [markdown]
# ### Standardizing header names

# %%
def standardNames(x):
    tempList = []
    for item in colFile1:
        tempList.append(item.lower())
    x.columns=tempList
    return x

# %%
mergedFiles = standardNames(complete_list)
mergedFiles
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [9012 rows x 11 columns]

# %% [markdown]
# ### Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data

# %%
len(mergedFiles[mergedFiles['customer'].isna()==True])  # number of missing values
# Out:
# 5874

# %%
len(mergedFiles[mergedFiles['customer lifetime value'].isna()==True])  # number of missing values
# Out:
# 5884

# %%
mergedFiles['customer'].value_counts(dropna=False)
# Out:
# NaN        5874
# MY31220       3
# CW49887       3
# GS98873       3
# RB50392       2
#            ...
# BC43958       1
# AI61368       1
# UF37831       1
# PO90615       1
# SA91515       1
# Name: customer, Length: 2065, dtype: int64

# %%
def drop_columns(x) :
    x.drop(columns=["customer"], inplace=True)
    return x

# %%
fileNC = drop_columns(mergedFiles)
fileNC
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 4003         NaN    NaN                   NaN                     NaN
# 4004         NaN    NaN                   NaN                     NaN
# 4005         NaN    NaN                   NaN                     NaN
# 4006         NaN    NaN                   NaN                     NaN
# 4007         NaN    NaN                   NaN                     NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 4003      NaN                   NaN                       NaN             NaN
# 4004      NaN                   NaN                       NaN             NaN
# 4005      NaN                   NaN                       NaN             NaN
# 4006      NaN                   NaN                       NaN             NaN
# 4007      NaN                   NaN                       NaN             NaN
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 4003            NaN                 NaN
# 4004            NaN                 NaN
# 4005            NaN                 NaN
# 4006            NaN                 NaN
# 4007            NaN                 NaN
#
# [9012 rows x 10 columns]

# %% [markdown]
# ### Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.

# %%
#fileNC["customer lifetime value"] = (fileNC["customer lifetime value"].apply(lambda x: float(x.strip("%"))/100 if isinstance(x,str) else x)
#fileNC

# %%
fileNC["customer lifetime value"] = (fileNC["customer lifetime value"].apply(lambda x: float(x.strip("%"))/100 if isinstance(x,str) else x))
fileNC
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                6979.5359
# 2         Nevada      F              Bachelor               12887.4317
# 3     California      M              Bachelor                7645.8618
# 4     Washington      M  High School or Below                5363.0765
# ...          ...    ...                   ...                      ...
# 4003         NaN    NaN                   NaN                      NaN
# 4004         NaN    NaN                   NaN                      NaN
# 4005         NaN    NaN                   NaN                      NaN
# 4006         NaN    NaN                   NaN                      NaN
# 4007         NaN    NaN                   NaN                      NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 4003      NaN                   NaN                       NaN             NaN
# 4004      NaN                   NaN                       NaN             NaN
# 4005      NaN                   NaN                       NaN             NaN
# 4006      NaN                   NaN                       NaN             NaN
# 4007      NaN                   NaN                       NaN             NaN
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 4003            NaN                 NaN
# 4004            NaN                 NaN
# 4005            NaN                 NaN
# 4006            NaN                 NaN
# 4007            NaN                 NaN
#
# [9012 rows x 10 columns]

# %%
fileNC["customer lifetime value"] = (fileNC["customer lifetime value"].apply(lambda x: float(x.strip("%"))/100 if isinstance(x,str) else x))
fileNC
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                6979.5359
# 2         Nevada      F              Bachelor               12887.4317
# 3     California      M              Bachelor                7645.8618
# 4     Washington      M  High School or Below                5363.0765
# ...          ...    ...                   ...                      ...
# 4003         NaN    NaN                   NaN                      NaN
# 4004         NaN    NaN                   NaN                      NaN
# 4005         NaN    NaN                   NaN                      NaN
# 4006         NaN    NaN                   NaN                      NaN
# 4007         NaN    NaN                   NaN                      NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 4003      NaN                   NaN                       NaN             NaN
# 4004      NaN                   NaN                       NaN             NaN
# 4005      NaN                   NaN                       NaN             NaN
# 4006      NaN                   NaN                       NaN             NaN
# 4007      NaN                   NaN                       NaN             NaN
#
#       vehicle class  total claim amount
# 0     Four-Door Car            2.704934
# 1     Four-Door Car         1131.464935
# 2      Two-Door Car          566.472247
# 3               SUV          529.881344
# 4     Four-Door Car           17.269323
# ...             ...                 ...
# 4003            NaN                 NaN
# 4004            NaN                 NaN
# 4005            NaN                 NaN
# 4006            NaN                 NaN
# 4007            NaN                 NaN
#
# [9012 rows x 10 columns]

# %% [markdown]
# ### Clean the number of open complaints and extract the middle number which is changing between records. pay attention that the number of open complaints is a categorical feature.

# %%
#fileNC.loc[(fileNC["gender"]>"f")]
# fileNC["gender"].value_counts()

# %%
fileNC["number of open complaints"]= fileNC["number of open complaints"].str[2:3]

# %%
fileNC["number of open complaints"] = (fileNC["number of open complaints"].apply(lambda x: float(x) if isinstance(x,str) else x))
fileNC
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      NaN
# 1        Arizona      F              Bachelor                6979.5359
# 2         Nevada      F              Bachelor               12887.4317
# 3     California      M              Bachelor                7645.8618
# 4     Washington      M  High School or Below                5363.0765
# ...          ...    ...                   ...                      ...
# 4003         NaN    NaN                   NaN                      NaN
# 4004         NaN    NaN                   NaN                      NaN
# 4005         NaN    NaN                   NaN                      NaN
# 4006         NaN    NaN                   NaN                      NaN
# 4007         NaN    NaN                   NaN                      NaN
#
#        income  monthly premium auto  number of open complaints  \
# 0         0.0                1000.0                        0.0
# 1         0.0                  94.0                        0.0
# 2     48767.0                 108.0                        0.0
# 3         0.0                 106.0                        0.0
# 4     36357.0                  68.0                        0.0
# ...       ...                   ...                        ...
# 4003      NaN                   NaN                        NaN
# 4004      NaN                   NaN                        NaN
# 4005      NaN                   NaN                        NaN
# 4006      NaN                   NaN                        NaN
# 4007      NaN                   NaN                        NaN
#
#          policy type  vehicle class  total claim amount
# 0      Personal Auto  Four-Door Car            2.704934
# 1      Personal Auto  Four-Door Car         1131.464935
# 2      Personal Auto   Two-Door Car          566.472247
# 3     Corporate Auto            SUV          529.881344
# 4      Personal Auto  Four-Door Car           17.269323
# ...              ...            ...                 ...
# 4003             NaN            NaN                 NaN
# 4004             NaN            NaN                 NaN
# 4005             NaN            NaN                 NaN
# 4006             NaN            NaN                 NaN
# 4007             NaN            NaN                 NaN
#
# [9012 rows x 10 columns]

# %%
fileNC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9012 entries, 0 to 4007
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      3138 non-null   object
#  1   gender                     2899 non-null   object
#  2   education                  3138 non-null   object
#  3   customer lifetime value    3128 non-null   float64
#  4   income                     3138 non-null   float64
#  5   monthly premium auto       3138 non-null   float64
#  6   number of open complaints  3138 non-null   float64
#  7   policy type                3138 non-null   object
#  8   vehicle class              3138 non-null   object
#  9   total claim amount         3138 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 774.5+ KB

# %% [markdown]
# ### Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns

# %%
fileNC['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
fileNC["state"] = fileNC["state"].replace("AZ", "Arizona")

# %%
fileNC["state"] = fileNC["state"].replace("WA", "Washington")

# %%
fileNC['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        nan], dtype=object)

# %% [markdown]
# ### Removing duplicates

# %%
fileNC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9012 entries, 0 to 4007
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      3138 non-null   object
#  1   gender                     2899 non-null   object
#  2   education                  3138 non-null   object
#  3   customer lifetime value    3128 non-null   float64
#  4   income                     3138 non-null   float64
#  5   monthly premium auto       3138 non-null   float64
#  6   number of open complaints  3138 non-null   float64
#  7   policy type                3138 non-null   object
#  8   vehicle class              3138 non-null   object
#  9   total claim amount         3138 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 774.5+ KB

# %%
fileNC = fileNC.drop_duplicates()

# %%
fileNC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2055 entries, 0 to 995
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2054 non-null   object
#  1   gender                     1932 non-null   object
#  2   education                  2054 non-null   object
#  3   customer lifetime value    2047 non-null   float64
#  4   income                     2054 non-null   float64
#  5   monthly premium auto       2054 non-null   float64
#  6   number of open complaints  2054 non-null   float64
#  7   policy type                2054 non-null   object
#  8   vehicle class              2054 non-null   object
#  9   total claim amount         2054 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 176.6+ KB

# %% [markdown]
# ## Activity 2 (Tuesday)
# - Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values) Hint: numpy.nan is considered of float64 data type.
#
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
#
# - (Optional) Standardizing the data – Use string functions to standardize the text data (lower case)

# %% [markdown]
# - Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values) Hint: numpy.nan is considered of float64 data type.

# %%
fileNC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2055 entries, 0 to 995
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2054 non-null   object
#  1   gender                     1932 non-null   object
#  2   education                  2054 non-null   object
#  3   customer lifetime value    2047 non-null   float64
#  4   income                     2054 non-null   float64
#  5   monthly premium auto       2054 non-null   float64
#  6   number of open complaints  2054 non-null   float64
#  7   policy type                2054 non-null   object
#  8   vehicle class              2054 non-null   object
#  9   total claim amount         2054 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 176.6+ KB

# %%
fileNC_num = fileNC.select_dtypes(include = ['float64','int64'])
fileNC_num.head()
# Out:
#    customer lifetime value   income  monthly premium auto  \
# 0                      NaN      0.0                1000.0
# 1                6979.5359      0.0                  94.0
# 2               12887.4317  48767.0                 108.0
# 3                7645.8618      0.0                 106.0
# 4                5363.0765  36357.0                  68.0
#
#    number of open complaints  total claim amount
# 0                        0.0            2.704934
# 1                        0.0         1131.464935
# 2                        0.0          566.472247
# 3                        0.0          529.881344
# 4                        0.0           17.269323

# %%
features = fileNC_num.columns.values.tolist()
print(features)
# Out:
# ['customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'total claim amount']

# %%
#fileNC_num = fileNC_num.loc[:,~fileNC_num.columns.duplicated()]

# %%
fileNC_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2055 entries, 0 to 995
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer lifetime value    2047 non-null   float64
#  1   income                     2054 non-null   float64
#  2   monthly premium auto       2054 non-null   float64
#  3   number of open complaints  2054 non-null   float64
#  4   total claim amount         2054 non-null   float64
# dtypes: float64(5)
# memory usage: 96.3 KB

# %%
for feature in features:
    fileNC_num[feature] = fileNC_num[feature].fillna(value=fileNC_num[feature].mean())
# Out:
# /Users/Gunnar/anaconda3/envs/IronhackDA/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#fileNC[feature] = fileNC[feature].fillna(value=fileNC[feature].mean())

# %%
fileNC_num["income"].unique()
# Out:
# array([    0., 48767., 36357., ..., 63513., 58161., 83640.])

# %%
#Validate fillnan() Check NaNs
for feature in fileNC_num:
    print(fileNC_num[feature].unique())
# Out:
# [ 7794.09368461  6979.5359     12887.4317     ...  5689.6441
#   3686.7238      3992.5839    ]
# [    0. 48767. 36357. ... 63513. 58161. 83640.]
# [ 1000.            94.           108.           106.
#     68.            69.            67.           101.
#     71.            93.           110.            70.
#     64.            72.            74.            79.
#     73.            61.           111.            80.
#     63.           237.            65.           130.
#     62.           117.            91.            90.
#     66.            99.           103.         35354.
#    172.            92.           104.           113.
#    124.           105.           100.           112.
#     97.            95.           102.            96.
#    186.            77.            76.           119.
#     87.           109.           107.            88.
#     85.          6464.           133.            86.
#     78.            89.           192.           118.
#    140.           127.           126.            82.
#    115.           217.           114.           138.
#     81.           255.           150.           123.
#    116.           190.            98.           159.
#     84.            83.           152.           136.
#    245.           135.          1005.           225.
#    132.           153.           121.           139.
#    154.           161.           156.           171.
#    244.           183.           176.           230.
#    129.           177.           181.           196.
#    131.           276.           253.           137.
#    180.           203.           147.           165.
#    198.           125.           193.           128.
#    271.           142.         10202.           206.
#    182.           189.           160.           295.
#    210.           134.         35353.           239.
#    188.           256.           173.           285.
#    148.           141.           197.           199.
#    166.59347614   214.           175.           167.
#    194.           164.           222.           215.
#    283.           169.           248.           223.
#    151.           213.           145.           185.
#    287.           297.          5353.           201.
#    149.           146.          7575.           235.
#    268.           211.           187.           168.
#    122.           143.        ]
# [0.         2.         1.         3.         5.         4.
#  0.37828627]
# [   2.704934 1131.464935  566.472247 ...  471.050488   28.460568
#   700.349052]

# %%
fileNC_num
# Out:
#      customer lifetime value   income  monthly premium auto  \
# 0                7794.093685      0.0                1000.0
# 1                6979.535900      0.0                  94.0
# 2               12887.431700  48767.0                 108.0
# 3                7645.861800      0.0                 106.0
# 4                5363.076500  36357.0                  68.0
# ..                       ...      ...                   ...
# 991              8471.417500  63513.0                  70.0
# 992              5431.219100  58161.0                  68.0
# 993              5689.644100  83640.0                  70.0
# 994              3686.723800      0.0                  96.0
# 995              3992.583900      0.0                 111.0
#
#      number of open complaints  total claim amount
# 0                          0.0            2.704934
# 1                          0.0         1131.464935
# 2                          0.0          566.472247
# 3                          0.0          529.881344
# 4                          0.0           17.269323
# ..                         ...                 ...
# 991                        0.0          185.667213
# 992                        0.0          140.747286
# 993                        0.0          471.050488
# 994                        0.0           28.460568
# 995                        0.0          700.349052
#
# [2055 rows x 5 columns]

# %%
fileNC = fileNC.drop(["customer lifetime value","income","monthly premium auto","total claim amount"], axis=1)
fileNC
# Out:
#           state gender             education  number of open complaints  \
# 0    Washington    NaN                Master                        0.0
# 1       Arizona      F              Bachelor                        0.0
# 2        Nevada      F              Bachelor                        0.0
# 3    California      M              Bachelor                        0.0
# 4    Washington      M  High School or Below                        0.0
# ..          ...    ...                   ...                        ...
# 991     Arizona      M                Master                        0.0
# 992     Arizona      F               College                        0.0
# 993      Nevada      F               College                        0.0
# 994  California      F                Master                        0.0
# 995  California      M              Bachelor                        0.0
#
#         policy type  vehicle class
# 0     Personal Auto  Four-Door Car
# 1     Personal Auto  Four-Door Car
# 2     Personal Auto   Two-Door Car
# 3    Corporate Auto            SUV
# 4     Personal Auto  Four-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [2055 rows x 6 columns]

# %%
fileNC_num = fileNC_num.drop(['number of open complaints'], axis=1)
fileNC_num
# Out:
#      customer lifetime value   income  monthly premium auto  \
# 0                7794.093685      0.0                1000.0
# 1                6979.535900      0.0                  94.0
# 2               12887.431700  48767.0                 108.0
# 3                7645.861800      0.0                 106.0
# 4                5363.076500  36357.0                  68.0
# ..                       ...      ...                   ...
# 991              8471.417500  63513.0                  70.0
# 992              5431.219100  58161.0                  68.0
# 993              5689.644100  83640.0                  70.0
# 994              3686.723800      0.0                  96.0
# 995              3992.583900      0.0                 111.0
#
#      total claim amount
# 0              2.704934
# 1           1131.464935
# 2            566.472247
# 3            529.881344
# 4             17.269323
# ..                  ...
# 991          185.667213
# 992          140.747286
# 993          471.050488
# 994           28.460568
# 995          700.349052
#
# [2055 rows x 4 columns]

# %%
fileNC_21 = pd.concat([fileNC, fileNC_num], axis=1) 
display(fileNC_21)
# Out:
#           state gender             education  number of open complaints  \
# 0    Washington    NaN                Master                        0.0
# 1       Arizona      F              Bachelor                        0.0
# 2        Nevada      F              Bachelor                        0.0
# 3    California      M              Bachelor                        0.0
# 4    Washington      M  High School or Below                        0.0
# ..          ...    ...                   ...                        ...
# 991     Arizona      M                Master                        0.0
# 992     Arizona      F               College                        0.0
# 993      Nevada      F               College                        0.0
# 994  California      F                Master                        0.0
# 995  California      M              Bachelor                        0.0
#
#         policy type  vehicle class  customer lifetime value   income  \
# 0     Personal Auto  Four-Door Car              7794.093685      0.0
# 1     Personal Auto  Four-Door Car              6979.535900      0.0
# 2     Personal Auto   Two-Door Car             12887.431700  48767.0
# 3    Corporate Auto            SUV              7645.861800      0.0
# 4     Personal Auto  Four-Door Car              5363.076500  36357.0
# ..              ...            ...                      ...      ...
# 991   Personal Auto  Four-Door Car              8471.417500  63513.0
# 992  Corporate Auto  Four-Door Car              5431.219100  58161.0
# 993  Corporate Auto   Two-Door Car              5689.644100  83640.0
# 994   Personal Auto   Two-Door Car              3686.723800      0.0
# 995   Personal Auto            SUV              3992.583900      0.0
#
#      monthly premium auto  total claim amount
# 0                  1000.0            2.704934
# 1                    94.0         1131.464935
# 2                   108.0          566.472247
# 3                   106.0          529.881344
# 4                    68.0           17.269323
# ..                    ...                 ...
# 991                  70.0          185.667213
# 992                  68.0          140.747286
# 993                  70.0          471.050488
# 994                  96.0           28.460568
# 995                 111.0          700.349052
#
# [2055 rows x 10 columns]

# %%
fileNC_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2055 entries, 0 to 995
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2054 non-null   object
#  1   gender                     1932 non-null   object
#  2   education                  2054 non-null   object
#  3   number of open complaints  2054 non-null   float64
#  4   policy type                2054 non-null   object
#  5   vehicle class              2054 non-null   object
#  6   customer lifetime value    2055 non-null   float64
#  7   income                     2055 non-null   float64
#  8   monthly premium auto       2055 non-null   float64
#  9   total claim amount         2055 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 176.6+ KB

# %%
#fileNC["customer lifetime value"]= fileNC[["customer lifetime value"]].fillna(value=fileNC["customer lifetime value"].mean())
#fileNC["income"]= fileNC[["income"]].fillna(value=fileNC["income"].mean())
#fileNC["income"]= fileNC[["income"]].fillna(value=fileNC["income"].mean())
#fileNC["monthly premium auto"]= fileNC[["monthly premium auto"]].fillna(value=fileNC["monthly premium auto"].mean())
#fileNC["total claim amount"]= fileNC[["total claim amount"]].fillna(value=fileNC["total claim amount"].mean())
#fileNC

# %%
#check the datatypes and search for NaNs -> datatypes correct ecxept"number of open complaints". NaNs; full dataset
fileNC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2055 entries, 0 to 995
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state                      2054 non-null   object
#  1   gender                     1932 non-null   object
#  2   education                  2054 non-null   object
#  3   number of open complaints  2054 non-null   float64
#  4   policy type                2054 non-null   object
#  5   vehicle class              2054 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 112.4+ KB

# %%
#check the values count
fileNC.state.value_counts()
# Out:
# Oregon        617
# California    485
# Arizona       401
# Nevada        222
# Washington    209
# Cali          120
# Name: state, dtype: int64

# %%
fileNC['state']
# Out:
# 0      Washington
# 1         Arizona
# 2          Nevada
# 3      California
# 4      Washington
#           ...
# 991       Arizona
# 992       Arizona
# 993        Nevada
# 994    California
# 995    California
# Name: state, Length: 2055, dtype: object

# %%
def rename_features_column(fileNC):
    fileNC.rename(columns={'controln':'id','hv1':'median_home_val',
                          'ic1':'median_household_income',"ic2":"med_fam_income", 
                          "ic3":"avg_household_income","ic4": "avg_fam_income",
                          "ic5":"per_capita_income"}, inplace=True )
    return hk_df
