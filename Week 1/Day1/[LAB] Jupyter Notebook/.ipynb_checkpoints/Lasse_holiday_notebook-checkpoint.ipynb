# %% [markdown]
# ## Lasse holiday preferences notebook
# This notebook displays the holiday preferences of my twin brother Lasse

# %%
#input function is used to prompt a user of this notebook to type in the defined persons's name
input('Please, enter the name of my twin brother: ')
# Out:
# Please, enter the name of my twin brother: Lasse
# 'Lasse'

# %%
#IPython.display is used to call a here locally saved image and return it with Image variable
from  IPython.display import Image
Image("/Users/Gunnar/Downloads/Screen Shot 2022-08-08 at 5.14.23 pm.png")

# %% [markdown]
# <b>Das ist mein Bruder Lasse

# %%
#IPython.display is used to call a here locally saved image and return it with Image variable
from  IPython.display import Image
Image("/Users/Gunnar/Downloads/Screen Shot 2022-08-08 at 5.27.05 pm.png")

# %%
from IPython.display import YouTubeVideo
# a talk full descent at Sa Calobra on Mallorca, Spain
# Video credit: Rob Parry
YouTubeVideo('F2HS6Lmtp5Y')

# %% [markdown]
# <b><i>Sa Calobra’s emblematic hairpins

# %% [markdown]
# These are the top 3 things Lasse does on <i>Mallorca<i>
# - TOP1: Mallorca 300km race across the island in one day
# - TOP2: Climbing <i>Sa Calobra<i> multiple time to train climbing race category
# - TOP3: Chill and relax on the beach, taking a cold dip

# %%
#* for italic in markdown instead of html <i>""<i>
