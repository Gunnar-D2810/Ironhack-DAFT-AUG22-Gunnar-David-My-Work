# %%
3+5
# Out:
# 8

# %%
print('hello world')
# Out:
# hello world

# %%
x = 12

# %%
x
# Out:
# 12

# %%
x
# Out:
# 12

# %% [markdown]
# #### this is header
# <b>, is a bold text<br>**is a bold text**
# - Item
# - Item2

# %%
from  IPython.display import Image
Image("https://fs-prod-cdn.nintendo-europe.com/media/images/10_share_images/games_15/nintendo_switch_download_software_1/H2x1_NSwitchDS_Cat_image1600w.jpg")
